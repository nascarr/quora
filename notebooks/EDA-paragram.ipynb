# %% [markdown]
# # EDA paramgram embedding and Spacy tokenizer

# %%
import os
import re
import pandas as pd
import spacy
from collections import Counter

# %%
def token_info(tokens):
    print('Number of tokens: ', len(tokens))
    print('First 10 tokens: ', tokens[:10])

# %%
def token_types(tokens):
    num_tokens = []
    symbol_tokens = []
    low_tokens = []
    up_tokens = []
    caps_tokens = []
    num_re = re.compile('[0-9]')
    low_re = re.compile('[a-z]')
    up_re = re.compile('[A-Z]')
    caps_re = re.compile('^[A-Z]*$')
    letnum_re = re.compile('[a-zA-Z0-9]')
    for t in tokens:
        if num_re.search(t):
            num_tokens.append(t)
        if not letnum_re.search(t):
            symbol_tokens.append(t)
        if low_re.match(t):
            low_tokens.append(t)
        if up_re.match(t):
            up_tokens.append(t)
        if caps_re.match(t):
            caps_tokens.append(t)
    print('Number of num tokens: ', len(num_tokens))
    print('Number of symbol tokens: ', len(symbol_tokens))
    print('Number of lowcase tokens: ' , len(low_tokens))
    print('Number of upper case tokens: ', len(up_tokens))
    print('Nubmer of capslock tokens: ' , len(caps_tokens))
    
    print('\n')
    
    print('Freq num tokens: ', num_tokens[:10])
    print('Rare num tokens: ', num_tokens[-10:], '\n')
    print('Freq symbol tokens: ', symbol_tokens[:10])
    print('Rare symbol tokens: ', symbol_tokens[-10:], '\n')
    print('Freq low tokens: ', low_tokens[:10])
    print('Rare low tokens: ', low_tokens[-10:], '\n')
    print('Freq up tokens: ', up_tokens[:10])
    print('Rare up tokens: ', up_tokens[-10:], '\n')
    print('Freq caps tokens: ', caps_tokens[:10])
    print('Rare caps tokens: ', caps_tokens[-10:])

# %% [markdown]
# ### Look at embedding

# %%
emb_path = 'embeddings/paragram_300_sl999/paragram_300_sl999.txt'
data_dir = cache = '../data'

train_csv = os.path.join(data_dir, 'train.csv')
test_csv = os.path.join(data_dir, 'test.csv')
emb_path = os.path.join(data_dir, emb_path)

# %%
# %%time
emb_tokens = []
with open(emb_path) as f:
    for line in f:
        tok = line.split()[0]
        emb_tokens.append(tok)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/anaconda3/envs/kaggle-kernel/lib/python3.6/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xbd in position 731: invalid start byte

# %%
token_info(emb_tokens)
# Out:
# Number of tokens:  97525
# First 10 tokens:  [',', '.', 'the', 'and', 'to', 'of', 'a', 'in', '"', ':']

# %%
token_types(emb_tokens)
# Out:
# Number of num tokens:  536635
# Number of symbol tokens:  2513
# Number of lowcase tokens:  653309
# Number of upper case tokens:  1089000
# Nubmer of capslock tokens:  153812
#
#
# Freq num tokens:  ['1', '2', '3', '4', '2012', '5', '2011', '10', '2010', '2009']
# Rare num tokens:  ['km/11', 'mono-2', 'otherjuicystar07', 'own36', 'p263', 'r91', 's9100', 'sarah123', 'v205', 'z/28']
#
# Freq symbol tokens:  [',', '.', '"', ':', ')', '(', '-', '...', '!', '?']
# Rare symbol tokens:  ['?!?!?!?!!', '?!?!?!?!?!?!?!?!?', 'ãƒˆã', 'ａ', '-------------------------------------------------------------------------------------------------------------------------------------------------', 'ɯ', 'вЂ', '回', 'ĵ', 'ÐÐ']
#
# Freq low tokens:  ['the', 'and', 'to', 'of', 'a', 'in', 'is', 'for', 'that', 'on']
# Rare low tokens:  ['work.Like', 'working.So', 'wried', 'wwent', 'xalisae', 'xtremecaffeine', 'yildirim', 'z/28', 'zipout', 'zulchzulu']
#
# Freq up tokens:  ['I', 'The', 'It', 'This', 'A', 'In', 'You', 'We', 'If', 'And']
# Rare up tokens:  ['Wozniaki', 'Xcode4', 'Yahne', 'Yes98', 'Yester-Me', 'YouMuhammad', 'Youli', 'ZNY', 'ZOELLICK', 'ZeitGeist']
#
# Freq caps tokens:  ['I', 'A', 'PM', 'AM', 'THE', 'US', 'TV', 'UK', 'OF', 'AND']
# Rare caps tokens:  ['TERRYK', 'TORSEN', 'VCDI', 'WEAO', 'WEDCO', 'WILLES', 'WMHK', 'WYLAM', 'ZNY', 'ZOELLICK']

# %% [markdown]
# ### Tokenize data and build vocab

# %%
train = pd.read_csv(train_csv)['question_text'].values.tolist()
test = pd.read_csv(test_csv)['question_text'].values.tolist()
data = train + test

# %%
# %%time
unknown_tokens = []
vocab = Counter()
spacy_en = spacy.load('en')
tokenizer = spacy_en.tokenizer
emb_tokens_set = set(emb_tokens)
for question in data:
    doc = tokenizer(question)
    for token in doc:
        tok_text = token.text
        vocab.update([tok_text])
        if vocab[tok_text] == 1:
            if tok_text not in emb_tokens_set:
                unknown_tokens.append(tok_text)
        
#doc = nlp(u'Apple is looking at buying U.K. startup for $1 billion')
#for token in doc:
#    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
#          token.shape_, token.is_alpha, token.is_stop)
# Out:
# CPU times: user 2min 22s, sys: 136 ms, total: 2min 22s
# Wall time: 2min 21s

# %%
vocab_tokens = dict(vocab.most_common()).keys()

# %%
token_types(vocab_tokens)
# Out:
# Number of num tokens:  29530
# Number of symbol tokens:  1727
# Number of lowcase tokens:  132699
# Number of upper case tokens:  113484
# Nubmer of capslock tokens:  15169
#
#
# Freq num tokens:  ['2', '2017', '2018', '1', '3', '10', '5', '4', '12', '6']
# Rare num tokens:  ['10–12', '61850', 'Feb-2018', '2200-$2500/mo', '4000/mo', '999999', '450cc', '78.53', '900va', '6740']
#
# Freq symbol tokens:  ['?', ',', '.', '"', '-', ')', '(', '/', "'", '&']
# Rare symbol tokens:  ['τῆς', 'κατὰ', 'τὴν', 'ἡμετέραν', 'χρῆσιν', 'συνηθείας', '=--', '中庸', '中庸之道', '∅⊂']
#
# Freq low tokens:  ['the', 'to', 'a', 'in', 'is', 'of', 'and', 'do', 'are', 'for']
# Rare low tokens:  ['noumber', 'sml', 'sgill', 'jauhar', 'clearly"bad', 'myAIR', 'cybershot', 'ganpat', 'rabels', 'photopicker']
#
# Freq up tokens:  ['What', 'I', 'How', 'Why', 'Is', 'Can', 'Which', 'Do', 'If', 'India']
# Rare up tokens:  ['Dime', 'Entanglements', 'Tamilar', 'Flurry', 'Routines', 'ULTIMATELY', 'Hb', 'Generate', 'Khayami', 'Thetis']
#
# Freq caps tokens:  ['I', 'US', 'USA', 'A', 'JEE', 'TV', 'UK', 'IIT', 'MBA', 'IT']
# Rare caps tokens:  ['IPOS', 'MANAV', 'ICSIL', 'RCZ', 'PPW', 'AOTS', 'THEORETICAL', 'FRAMEWORK', 'EPAM', 'ULTIMATELY']

# %% [markdown]
# ### Capslock tokens

# %%
caps_re = re.compile('^[A-Z]*$')
caps_tokens = []
for t in vocab_tokens:
    if caps_re.match(t):
        caps_tokens.append(t)

# %%
emotional_caps_tokens = []
for t in caps_tokens:
    if t not in emb_tokens_set and t.lower() in emb_tokens_set:
        emotional_caps_tokens.append(t)
print(len(emotional_caps_tokens))
# Out:
# 307

# %%
emotional_caps_tokens
# Out:
# ['UPSE',
#  'BHIM',
#  'IPHO',
#  'AADHAR',
#  'ANTHE',
#  'MESRA',
#  'QUORA',
#  'IARE',
#  'HODL',
#  'BLACKI',
#  'SHIATS',
#  'BRDS',
#  'PSUS',
#  'NARCOS',
#  'SILCHAR',
#  'SNAPCHAT',
#  'OCER',
#  'NITR',
#  'UOFT',
#  'FUDI',
#  'DEPR',
#  'NAOH',
#  'CRYPTOCURRENCY',
#  'EVETS',
#  'SBUF',
#  'JOSSA',
#  'RGIA',
#  'CELU',
#  'IANG',
#  'ARTICLESHIP',
#  'GOTRA',
#  'MARATHA',
#  'PRIST',
#  'CAPGEMINI',
#  'JAAT',
#  'LIATE',
#  'OMPRAKASH',
#  'HEETS',
#  'GOOGEL',
#  'ACHEIVEMENTS',
#  'RITEE',
#  'IRRESPONSIBILITY',
#  'ISHANT',
#  'BATSMEN',
#  'MEDICORE',
#  'ACCEDENT',
#  'PYURIA',
#  'GASSES',
#  'CURRNT',
#  'INSITED',
#  'EXHISTING',
#  'FANCHISE',
#  'CENSE',
#  'SURABHI',
#  'IRRITANTS',
#  'PANVEL',
#  'SAYEED',
#  'OLYMPIADS',
#  'JUCHE',
#  'UNWORKABLE',
#  'BLASPHEMING',
#  'DHARWAD',
#  'ASKD',
#  'CHEGG',
#  'FIIO',
#  'APPOITMENT',
#  'HTTRACK',
#  'WEBTOON',
#  'REFRENCES',
#  'SHEIN',
#  'BANARAS',
#  'GRETEST',
#  'GOWDA',
#  'REFERNECE',
#  'LANDLESS',
#  'INGENERAL',
#  'FATIHAH',
#  'SANJU',
#  'BELEIEVE',
#  'PARTIT',
#  'DAENERYS',
#  'TUMMO',
#  'BITCOINS',
#  'RATIONALIZE',
#  'ADND',
#  'AMIEN',
#  'VEERE',
#  'FETO',
#  'XAVIERS',
#  'REBOILER',
#  'LIIT',
#  'NUMERATOR',
#  'COURSERA',
#  'ENGINNERS',
#  'LISK',
#  'BRAHMANS',
#  'LEEE',
#  'COMMY',
#  'WATU',
#  'CUDS',
#  'CURCUMIN',
#  'FORB',
#  'VIXY',
#  'RIYAZ',
#  'KHURANA',
#  'VOIN',
#  'SUPARI',
#  'ACCOUSTICS',
#  'INDUSTRIALISATION',
#  'KASHMIRIS',
#  'PLEBISCITE',
#  'PAKISTHAN',
#  'BHIWANDI',
#  'VIDYAPEETH',
#  'DESTRUCTIONS',
#  'HOMINIDS',
#  'AREAR',
#  'MANAPHY',
#  'DIOT',
#  'IBATIS',
#  'VAPORIZE',
#  'NINCOMPOOPS',
#  'MEUM',
#  'SUAM',
#  'ABORTIVE',
#  'DEMONETIZATION',
#  'MUNS',
#  'ECRIS',
#  'XNK',
#  'POLITICANS',
#  'FIREBUG',
#  'LASIC',
#  'DERMOID',
#  'HARPING',
#  'CHALLAN',
#  'BIGINNER',
#  'KASAB',
#  'GOENKA',
#  'ZUZ',
#  'DIFFERNCE',
#  'NOKO',
#  'PRIVIOUS',
#  'SPYGATE',
#  'RETRENCH',
#  'GULABI',
#  'BURLA',
#  'BCUS',
#  'GUESSWORK',
#  'RUDRAKSH',
#  'IKY',
#  'SWAYAM',
#  'WITCHS',
#  'MANNUAL',
#  'NEUT',
#  'GIVEUP',
#  'FRICTIONLESS',
#  'ABSENTIA',
#  'DESCREPANCY',
#  'VAIRAGYA',
#  'PRABHAS',
#  'AIRBNB',
#  'KRANTHI',
#  'TIRUPATHI',
#  'STRIX',
#  'WORSENED',
#  'NAXAL',
#  'SMOTE',
#  'LEAVED',
#  'RANJI',
#  'KHATA',
#  'IIFE',
#  'MARJI',
#  'SMARTNESS',
#  'NAKBA',
#  'SHAREMARKETS',
#  'TIRUMALA',
#  'VISHESH',
#  'INDOR',
#  'DRAKON',
#  'PINKU',
#  'XIAOMI',
#  'BREIFLY',
#  'TABACCO',
#  'PINCHERS',
#  'MANIFACTURED',
#  'MIRCHI',
#  'HEMM',
#  'PSYCOLOGICAL',
#  'BCAAS',
#  'CIVILS',
#  'INSCRIPT',
#  'SHASTRA',
#  'CLUCH',
#  'LOPTOP',
#  'PIGI',
#  'PRACTICALS',
#  'MOSTEST',
#  'UNIVERCITY',
#  'DAINIK',
#  'JAGRAN',
#  'UNFORSEEN',
#  'UMANG',
#  'ANDHRAPRADESH',
#  'KAFFIRS',
#  'AFAID',
#  'AMHARA',
#  'BENEFICAL',
#  'GONK',
#  'URBANISATION',
#  'GCSES',
#  'DBOL',
#  'OSMANIA',
#  'BRUTTO',
#  'DEPRIVING',
#  'MUGO',
#  'QUATS',
#  'CONTINIOUSLY',
#  'TRIGONOMETRIC',
#  'BEARDO',
#  'SERVICEMAN',
#  'OFFPAGE',
#  'DEEPSET',
#  'DOUCHEBAGGERY',
#  'ACNES',
#  'AQUAINTANCE',
#  'GITH',
#  'USFOR',
#  'MEGHALAYA',
#  'MIMER',
#  'GESE',
#  'MOIT',
#  'HOMOMORPHISM',
#  'TRIPHALA',
#  'ENTROPAY',
#  'STREM',
#  'BEETWEEN',
#  'TRAPPIST',
#  'DELINK',
#  'BOIII',
#  'USUM',
#  'MAINTAINCE',
#  'ISSER',
#  'TQW',
#  'IMEL',
#  'LOOMPAS',
#  'AGET',
#  'DIGUSTING',
#  'ANSY',
#  'JAINS',
#  'PALYA',
#  'COFFY',
#  'VENKATESWARA',
#  'SADU',
#  'ANALYTICA',
#  'LOFO',
#  'CHATBOT',
#  'PLUNGED',
#  'APPCMD',
#  'ROTHCHILD',
#  'TERRIORISTS',
#  'SYDE',
#  'QDOBA',
#  'HOUSEMATES',
#  'XDN',
#  'SWERE',
#  'GOUGED',
#  'PRESSTITUTES',
#  'KERLA',
#  'ADHAR',
#  'CORELATION',
#  'SUAT',
#  'PADMAVATI',
#  'RUPAY',
#  'RULET',
#  'TRUSTER',
#  'DLED',
#  'ARCHITECHT',
#  'DIRP',
#  'TERF',
#  'PAPAD',
#  'FARIO',
#  'LOGMEIN',
#  'SEVAK',
#  'EXPREINCE',
#  'GESCOM',
#  'ALKANE',
#  'ALKENE',
#  'ALKYNE',
#  'TATKAL',
#  'SCILAB',
#  'COMOS',
#  'TEEKAY',
#  'GMAE',
#  'PAKKA',
#  'REHIRE',
#  'TIVI',
#  'ELAT',
#  'NESSUS',
#  'AADHAAR',
#  'KHADI',
#  'WEAV',
#  'TRANSGENDERS',
#  'DECIMATING',
#  'HIJRAH',
#  'QUORAN',
#  'LADDU',
#  'MANAV']

# %% [markdown]
# ### Unknown tokens

# %%
unk_vocab = {}
for w in unknown_tokens:
    unk_vocab[w] = vocab[w]
unk_vocab = Counter(unk_vocab)

# %%
print('Total number of tokens: ', sum(vocab.values()))
print('Number of unique tokens: ', len(vocab))
print('Total number of unknown tokens: ', sum(unk_vocab.values()))
print('Number of unique unknown tokens: ', len(unknown_tokens))
print('Percent of unknown tokens: ', 100 * sum(unk_vocab.values())/sum(vocab.values()))
# Out:
# Total number of tokens:  19837964
# Number of unique tokens:  268601
# Total number of unknown tokens:  113339
# Number of unique unknown tokens:  82595
# Percent of unknown tokens:  0.5713237507639393

# %%
unk_common = dict(unk_vocab.most_common())
print('Number of 100 most common unk tokens: ', sum(list(unk_common.values())[:100]))
# Out:
# Number of 100 most common unk tokens:  9242

# %%
unk_common
# Out:
# {'..': 888,
#  'Quorans': 882,
#  'Brexit': 510,
#  'cryptocurrencies': 506,
#  'Redmi': 394,
#  '\xa0': 239,
#  '/math': 231,
#  'x^2': 205,
#  'f(x': 179,
#  '^2': 147,
#  'OnePlus': 130,
#  'UCEED': 126,
#  'Blockchain': 111,
#  'GDPR': 110,
#  'demonetisation': 109,
#  'Coinbase': 105,
#  'BNBR': 104,
#  'Machedo': 103,
#  'Adityanath': 101,
#  'Boruto': 96,
#  '\\frac': 96,
#  'ethereum': 95,
#  'DCEU': 93,
#  'IIEST': 90,
#  'SJWs': 84,
#  'Qoura': 81,
#  "Qur'an": 79,
#  'LNMIIT': 72,
#  'Zerodha': 69,
#  'A+': 69,
#  'Upwork': 68,
#  'Kavalireddi': 67,
#  '.net': 65,
#  'bhakts': 65,
#  '1/': 65,
#  'Doklam': 62,
#  'NICMAR': 62,
#  'Vajiram': 61,
#  'Unacademy': 60,
#  'w/': 56,
#  'AlShamsi': 56,
#  'MUOET': 55,
#  'chsl': 55,
#  'x^3': 55,
#  "5'4": 53,
#  'Bhakts': 52,
#  'HackerRank': 52,
#  'Litecoin': 51,
#  'Jiren': 51,
#  'Awdhesh': 50,
#  "A2A'd": 49,
#  'altcoin': 49,
#  'y^2': 48,
#  'eLitmus': 47,
#  'altcoins': 47,
#  'Cryptocurrency': 47,
#  'Ryzen': 46,
#  "5'9": 46,
#  'SRMJEE': 46,
#  '\\sqrt': 44,
#  'Baahubali': 44,
#  '^3': 44,
#  "5'5": 44,
#  'Amazon.in': 43,
#  "5'3": 42,
#  'SGSITS': 42,
#  'Skripal': 42,
#  'Beerus': 42,
#  'coinbase': 41,
#  'B+': 41,
#  'What\u200b': 41,
#  'a+b': 40,
#  'Alshamsi': 40,
#  "5'7": 39,
#  "5'2": 39,
#  'BIPC': 38,
#  'BMSCE': 38,
#  'Gurugram': 38,
#  'bahubali': 38,
#  "5'6": 38,
#  'Binance': 38,
#  'SRMJEEE': 37,
#  'Zebpay': 37,
#  'Truecaller': 37,
#  'Swachh': 36,
#  "5'10": 36,
#  'josaa': 36,
#  'Ravula': 36,
#  'Golang': 35,
#  '\\math': 35,
#  'OBOR': 34,
#  'litecoin': 34,
#  "5'8": 34,
#  'clickbait': 33,
#  'upwork': 33,
#  'iisc': 33,
#  'MHCET': 33,
#  '\\infty': 33,
#  'TensorFlow': 32,
#  '^n': 32,
#  "5'11": 32,
#  'Google+': 32,
#  'e^x': 32,
#  'Quora.com': 31,
#  '.what': 31,
#  ':(': 31,
#  'Chromecast': 31,
#  'y=': 30,
#  'IISERs': 30,
#  'Adhaar': 30,
#  'PESSAT': 30,
#  'O+': 30,
#  'g(x': 30,
#  'adhaar': 29,
#  'demonitisation': 29,
#  'x^4': 29,
#  'Koinex': 29,
#  'LBSNAA': 29,
#  '\\int': 29,
#  'LGBT+': 28,
#  'LGBTQ+': 28,
#  'Patreon': 28,
#  'Byju': 28,
#  'unacademy': 28,
#  '.I': 28,
#  'hyperloop': 28,
#  'microservices': 27,
#  'Whst': 27,
#  'non-': 27,
#  '8)': 27,
#  'fortnite': 27,
#  'USICT': 27,
#  'ReactJS': 27,
#  '2x^2': 26,
#  'H+': 26,
#  'x+1': 26,
#  'Zamasu': 26,
#  'x=0': 26,
#  'UPSE': 26,
#  '\\sum': 26,
#  'mc^2': 25,
#  'B.Des': 25,
#  'Codeforces': 25,
#  'brexit': 25,
#  'Fiitjee': 25,
#  'A-': 25,
#  'Trumpcare': 25,
#  'Bittrex': 25,
#  'Irodov': 25,
#  'FTRE': 25,
#  'tensorflow': 25,
#  '\\left': 25,
#  'Tensorflow': 24,
#  '3x^2': 24,
#  'Demonetization': 24,
#  'Simpliv': 24,
#  'Howcan': 24,
#  'Kalpit': 24,
#  '₹': 24,
#  'e^': 24,
#  'JoSAA': 24,
#  '\\to': 24,
#  'OneDrive': 24,
#  '\\right': 24,
#  '.How': 24,
#  'NLUs': 23,
#  'MHTCET': 23,
#  'IIITH': 23,
#  'IGDTUW': 23,
#  '^1/2': 23,
#  "6'1": 22,
#  'musical.ly': 22,
#  's^2': 22,
#  'DeepMind': 22,
#  'Undertale': 22,
#  'Jungkook': 22,
#  'apist': 21,
#  'Arrowverse': 21,
#  'a^2': 21,
#  'Xiomi': 21,
#  'Whydo': 21,
#  'chapterwise': 21,
#  'JCPOA': 21,
#  'undergraduation': 21,
#  'sin(x': 21,
#  "6'2": 21,
#  'rohingya': 21,
#  'incels': 21,
#  'Despacito': 21,
#  '401(k': 21,
#  'genderfluid': 21,
#  'schizoids': 21,
#  'IIITD': 21,
#  '\\times': 21,
#  'hotstar': 21,
#  'Kubernetes': 20,
#  'WannaCry': 20,
#  'JioFi': 20,
#  'VSSUT': 20,
#  'AKTU': 20,
#  'AIATS': 20,
#  'dx[/math': 20,
#  'zebpay': 20,
#  '\\cdot': 20,
#  'book(s': 20,
#  'EFLU': 20,
#  'twinflame': 20,
#  'HBTU': 20,
#  'Theranos': 20,
#  'Zenfone': 20,
#  '.Net': 20,
#  'Veerwal': 20,
#  'MMMUT': 20,
#  'nanodegree': 19,
#  'fullform': 19,
#  'Hotstar': 19,
#  'PMAY': 19,
#  '\\in': 19,
#  'EXTC': 19,
#  'math]x[/math': 19,
#  'Na+': 19,
#  '/2': 19,
#  'madheshi': 19,
#  'language(s': 19,
#  'Cryptocurrencies': 19,
#  'Sarahah': 19,
#  'Padmaavat': 18,
#  'blockchains': 18,
#  'biharis': 18,
#  'x+y': 18,
#  '"-': 18,
#  'React.js': 18,
#  'How\u200b': 18,
#  'Kovind': 18,
#  'BHIM': 18,
#  'D3300': 18,
#  '\\displaystyle': 18,
#  'Pizzagate': 18,
#  'Kaneki': 18,
#  'AirPods': 18,
#  'Nanodegree': 18,
#  '-x': 18,
#  'a+b+c': 18,
#  'Strzok': 18,
#  'AB+': 18,
#  '\\lim': 18,
#  'pcod': 18,
#  'HackerEarth': 18,
#  'TISSNET': 17,
#  '2017/2018': 17,
#  'Swiggy': 17,
#  "I'am": 17,
#  'don´t': 17,
#  'Jupyter': 17,
#  '\\leq': 17,
#  'RLWL': 17,
#  'Instacart': 17,
#  'Odoo': 17,
#  'Kattankulathur': 17,
#  'n+1': 17,
#  'mhtcet': 17,
#  '\\pi': 17,
#  'करना': 17,
#  '\\dfrac': 17,
#  'Mbappe': 17,
#  'Zhihu': 17,
#  'ftre': 17,
#  'koinex': 17,
#  'IPMAT': 17,
#  'PayTM': 16,
#  'I`m': 16,
#  'Kainerugaba': 16,
#  'Qidian': 16,
#  'Ahok': 16,
#  'Steemit': 16,
#  '\ufeff': 16,
#  'SSCBS': 16,
#  "don'TS": 16,
#  'e-': 16,
#  'better-': 16,
#  'LNCT': 16,
#  'Awdesh': 16,
#  'UPESEAT': 16,
#  'x^': 16,
#  'Warmbier': 16,
#  'XXXTentacion': 16,
#  "6'4": 16,
#  'A=': 16,
#  'Whyis': 16,
#  'cos(x': 16,
#  'USACO': 16,
#  'zerodha': 16,
#  'class11': 16,
#  'Neuralink': 16,
#  'IFoS': 16,
#  'AIEEA': 16,
#  'B-': 15,
#  'I´m': 15,
#  'GANs': 15,
#  'PESU': 15,
#  'MSQE': 15,
#  'x^x': 15,
#  'AILET': 15,
#  '2k17': 15,
#  'OpenAI': 15,
#  'Dhinchak': 15,
#  '=3': 15,
#  'Drumpf': 15,
#  "5'1": 15,
#  'Padmavat': 15,
#  '.What': 15,
#  'Bitfinex': 15,
#  'VITMEE': 15,
#  '.how': 15,
#  '\n': 15,
#  '|x|': 14,
#  'b^2': 14,
#  '1=2': 14,
#  'BMSIT': 14,
#  'Plancess': 14,
#  'Taehyung': 14,
#  'B.arch': 14,
#  "gov't": 14,
#  'RGIPT': 14,
#  'Bitconnect': 14,
#  'MH370': 14,
#  'demonitization': 14,
#  'Killmonger': 14,
#  'dream11': 14,
#  ':/': 14,
#  'UGEE': 14,
#  'ipill': 14,
#  '2-': 14,
#  'Kefla': 14,
#  'internshala': 14,
#  'srmjee': 14,
#  'IIHM': 14,
#  'HSEE': 14,
#  'covfefe': 14,
#  'sh*t': 14,
#  'MAKAUT': 14,
#  'O-': 14,
#  'IIT(ISM': 14,
#  'Dream11': 13,
#  'Oneplus': 13,
#  'WikiTribune': 13,
#  'x+2': 13,
#  'D7200': 13,
#  'math]\\displaystyle': 13,
#  'NSEJS': 13,
#  'acturial': 13,
#  'NITians': 13,
#  'Vue.js': 13,
#  'Brexiters': 13,
#  '1[/math': 13,
#  'PGDBF': 13,
#  'MH17': 13,
#  'Electroneum': 13,
#  'Ravindrababu': 13,
#  'DSCE': 13,
#  'GSTIN': 13,
#  'sarahah': 13,
#  'G+': 13,
#  'AlphaGo': 13,
#  '\\div': 13,
#  '.exe': 13,
#  'narcissit': 13,
#  'VITEE': 13,
#  'parents’': 13,
#  'YourQuote': 13,
#  'Waymo': 12,
#  'covalency': 12,
#  'jiofi': 12,
#  'HYPSM': 12,
#  'mppsc': 12,
#  'Kilimall': 12,
#  'X^2': 12,
#  'AIMCAT': 12,
#  'RWBY': 12,
#  "f'(x": 12,
#  "CAT'17": 12,
#  '2x+1': 12,
#  '4x^3': 12,
#  '7700k': 12,
#  'Brexiteers': 12,
#  'Feku': 12,
#  'muoet': 12,
#  '^x': 12,
#  'LHMC': 12,
#  'Practo': 12,
#  '1+x': 12,
#  'MPSTME': 12,
#  'MobiKwik': 12,
#  'KGMU': 12,
#  '2x^3': 12,
#  'HomePod': 12,
#  'ex-': 12,
#  'math]n[/math': 12,
#  '️': 12,
#  'sin^2': 12,
#  'mhcet': 12,
#  '\\\\': 12,
#  '\\mathrm': 12,
#  'wumao': 12,
#  '/3': 12,
#  'FZ25': 12,
#  'a^3': 11,
#  '2^x': 11,
#  'kotlin': 11,
#  '0[/math': 11,
#  'NIELIT': 11,
#  'DoorDash': 11,
#  "dosen't": 11,
#  'DigitalOcean': 11,
#  '5’3': 11,
#  'incel': 11,
#  'RCOEM': 11,
#  'BALLB': 11,
#  'can`t': 11,
#  'dangal': 11,
#  'c^2': 11,
#  '=-': 11,
#  'pqwl': 11,
#  'Otsutsuki': 11,
#  'no.1': 11,
#  'JECRC': 11,
#  '\xa0 ': 11,
#  'you’': 11,
#  'remainers': 11,
#  '√2': 11,
#  'Tamilans': 11,
#  'ncerts': 11,
#  'sayat.me': 11,
#  'IMUCET': 11,
#  'Lenskart': 11,
#  'x+3': 11,
#  '.edu': 11,
#  '\\mathbb': 11,
#  'f**k': 11,
#  'class9': 11,
#  'countries’': 11,
#  'Trumpism': 11,
#  'Minance': 11,
#  'है': 11,
#  'VESIT': 11,
#  'math]\\int': 11,
#  'Poloniex': 11,
#  'WebAssembly': 10,
#  'parent(s': 10,
#  'GE14': 10,
#  'Qyburn': 10,
#  'ln(x': 10,
#  '.is': 10,
#  'Daesh': 10,
#  'Zoomcar': 10,
#  '-i': 10,
#  'Sense8': 10,
#  'US’': 10,
#  'GraphQL': 10,
#  'kmno4': 10,
#  '1300D': 10,
#  'OH-': 10,
#  'cringiest': 10,
#  '/her': 10,
#  'Whydoes': 10,
#  'darkweb': 10,
#  '2k18': 10,
#  'IERT': 10,
#  "6'5": 10,
#  'Tambrahms': 10,
#  '\\text': 10,
#  '.in': 10,
#  "6'0": 10,
#  'F(x': 10,
#  'States’': 10,
#  'others’': 10,
#  'SPPU': 10,
#  'deplorables': 10,
#  'o+': 10,
#  'rohingyas': 10,
#  '3-': 10,
#  'gaslighted': 10,
#  'Bolsonaro': 10,
#  'PhonePe': 10,
#  'hyperconjugation': 10,
#  'IGST': 10,
#  'Gurmehar': 10,
#  'PGDIE': 10,
#  'sambhaji': 10,
#  '4x^2': 10,
#  'without\u200b': 10,
#  'electroneum': 10,
#  'B.des': 10,
#  'Sanghis': 10,
#  'Unocoin': 10,
#  'DILR': 10,
#  "DON'T": 10,
#  'ERC20': 10,
#  "5'0": 10,
#  'Jipmer': 10,
#  'n^2': 10,
#  'thicc': 10,
#  'gaslighter': 10,
#  '/-': 10,
#  'byjus': 10,
#  'BYJU': 10,
#  'RNSIT': 10,
#  'Remainers': 10,
#  'Petuhov': 10,
#  'RNNs': 10,
#  'girls’': 10,
#  'shine.com': 10,
#  'flipcart': 10,
#  'boys’': 10,
#  'thing(s': 10,
#  'math]x': 10,
#  'LRDI': 9,
#  'Bajjika': 9,
#  'n=1': 9,
#  'BASLP': 9,
#  'b1/b2': 9,
#  'NCERTs': 9,
#  '\\cos': 9,
#  'Bartetzko': 9,
#  'PRMO': 9,
#  'Elitmus': 9,
#  'Krennic': 9,
#  'boruto': 9,
#  'mmmut': 9,
#  'Antminer': 9,
#  "6'3": 9,
#  'ecosport': 9,
#  'fz25': 9,
#  'ARKit': 9,
#  'his/': 9,
#  '.22LR': 9,
#  'a^': 9,
#  'sklearn': 9,
#  '5x^2': 9,
#  'A2As': 9,
#  'FRDI': 9,
#  'x[/math': 9,
#  '-ve': 9,
#  '3G/4': 9,
#  'NIFTEM': 9,
#  '1050ti': 9,
#  '^5': 9,
#  'Rejuvalex': 9,
#  'Midoriya': 9,
#  'IPUCET': 9,
#  'Trezor': 9,
#  '\\sin': 9,
#  'Gujratis': 9,
#  'sinx+cosx': 9,
#  'LeEco': 9,
#  'BVCOE': 9,
#  '.Is': 9,
#  'sec^2': 9,
#  'NLUO': 9,
#  'HIV+': 9,
#  'g5s': 9,
#  'Dogecoin': 9,
#  'x=2': 9,
#  'Howdoes': 9,
#  'm^3': 9,
#  'Demonetisation': 9,
#  'BitConnect': 9,
#  'machedo': 9,
#  'GDAX': 9,
#  'b.pharm': 9,
#  '/x': 9,
#  'RBEI': 9,
#  'IPHO': 9,
#  '2=5': 9,
#  'AlphaZero': 9,
#  '-1/2': 9,
#  'Americans’': 9,
#  'self-': 9,
#  'reason(s': 9,
#  '\\lt': 9,
#  'CPTSD': 9,
#  'aurangzeb': 9,
#  'x=': 9,
#  '5’7': 9,
#  'Microservices': 9,
#  '940mx': 9,
#  '^4': 9,
#  '5’9': 9,
#  'x^5': 9,
#  "4'11": 9,
#  '/or': 9,
#  '\\ln': 9,
#  ',-': 8,
#  'Quoras': 8,
#  '2^n': 8,
#  '₹5000': 8,
#  'F1.8': 8,
#  'b.pharma': 8,
#  'Whichis': 8,
#  'ShopClues': 8,
#  '-x^2': 8,
#  'crytocurrency': 8,
#  'tan^-1': 8,
#  '1-': 8,
#  'TQWL': 8,
#  'C+': 8,
#  '₹1': 8,
#  'jeemains': 8,
#  'and/': 8,
#  'Bumrah': 8,
#  'IIITDM': 8,
#  'alovera': 8,
#  'sadhguru': 8,
#  'fayol': 8,
#  '5’4': 8,
#  'autoencoder': 8,
#  'oswaal': 8,
#  'Jesus’': 8,
#  '9A0': 8,
#  'Chutiya': 8,
#  'Haptik': 8,
#  'Umtiti': 8,
#  'x^2+y^2': 8,
#  'Stardew': 8,
#  'B1B2': 8,
#  '2=4': 8,
#  'HoloLens': 8,
#  'PyTorch': 8,
#  'class12': 8,
#  'Nearbuy': 8,
#  'epfo': 8,
#  'Sokovia': 8,
#  '.find': 8,
#  'CIWG': 8,
#  'jungkook': 8,
#  'daiict': 8,
#  'Strowman': 8,
#  'FMGE': 8,
#  'WWhat': 8,
#  'x+1/x': 8,
#  '90%+': 8,
#  '√3': 8,
#  'math]n': 8,
#  'Jozwik': 8,
#  'x(t': 8,
#  '5=': 8,
#  'vidhan': 8,
#  'Webnovel': 8,
#  'jcece': 8,
#  '160r': 8,
#  'D5300': 8,
#  'E&TC': 8,
#  'H3O+': 8,
#  'doklam': 8,
#  'SIMSREE': 8,
#  'z^2': 8,
#  'cpec': 8,
#  'narcisists': 8,
#  'byju': 8,
#  'Philando': 8,
#  'biromantic': 8,
#  'WILP': 8,
#  'copper(II': 8,
#  'Mangalyaan': 8,
#  'coching': 8,
#  'Azdome': 8,
#  'sallery': 8,
#  'musigma': 8,
#  'x=3': 8,
#  'LSTMs': 8,
#  'x^n': 8,
#  'Antshares': 8,
#  'nickel(II': 8,
#  'freebitco.in': 8,
#  '1=': 8,
#  'No.1': 8,
#  'Kasganj': 8,
#  'one(s': 8,
#  'BigHit': 8,
#  'jallikattu': 8,
#  'Novichok': 8,
#  '-1/12': 8,
#  '.why': 8,
#  'Wishfie': 8,
#  'a+': 8,
#  '^-1': 8,
#  'MnC': 8,
#  'Avenatti': 8,
#  'B.pharm': 8,
#  'D3400': 8,
#  'uncollapse': 8,
#  'doky.io': 8,
#  'cos^2': 8,
#  'I‘m': 8,
#  'Qur’an': 8,
#  'NS200': 7,
#  "Qu'ran": 7,
#  'UberEats': 7,
#  'lnct': 7,
#  'Bregoli': 7,
#  'Cgl': 7,
#  '5’8': 7,
#  'Internshala': 7,
#  '2018/19': 7,
#  'note4': 7,
#  'b^3': 7,
#  'I️': 7,
#  '4^x': 7,
#  'D+': 7,
#  'PGDHRM': 7,
#  'C-': 7,
#  'harpic': 7,
#  'H2So4': 7,
#  'math]a': 7,
#  'Sharudenko': 7,
#  'IGTV': 7,
#  'Randyll': 7,
#  'zenfone': 7,
#  "shouldn't": 7,
#  'bokaro': 7,
#  'FNAF': 7,
#  'Rs.10000': 7,
#  'AADHAR': 7,
#  'vitee': 7,
#  'Ciaz': 7,
#  'JNUEE': 7,
#  'n+2': 7,
#  'aiats': 7,
#  'kids’': 7,
#  'polyhouse': 7,
#  '1080ti': 7,
#  'ISBF': 7,
#  'CUCET': 7,
#  'm.ed': 7,
#  'can´t': 7,
#  'ravindrababu': 7,
#  'Ibps': 7,
#  'a^x': 7,
#  '1+x^2': 7,
#  'dy=0': 7,
#  'GTBIT': 7,
#  'Altcoins': 7,
#  'pcmb': 7,
#  'k=1': 7,
#  'Vidyalankar': 7,
#  'h(x': 7,
#  'DSATM': 7,
#  'touchbar': 7,
#  'wish.com': 7,
#  'Cas9': 7,
#  'm²': 7,
#  'garud': 7,
#  'cm^2': 7,
#  'Xender': 7,
#  'Nidahas': 7,
#  'Kvpy': 7,
#  'Hashflare': 7,
#  '1300d': 7,
#  'Izuku': 7,
#  'Tezos': 7,
#  '\\beta': 7,
#  'Skripals': 7,
#  'locopilot': 7,
#  'Devasena': 7,
#  'f*ck': 7,
#  'P(x': 7,
#  'n^': 7,
#  'theeta': 7,
#  '.If': 7,
#  'CarPlay': 7,
#  'cm^3': 7,
#  '\\displaystyle\\int': 7,
#  'B=': 7,
#  '₹10,000': 7,
#  '940MX': 7,
#  'should\u200b': 7,
#  'BvS': 7,
#  'cryptocoin': 7,
#  'Whatdo': 7,
#  'digilocker': 7,
#  'l&t': 7,
#  'Pribumi': 7,
#  'NMAMIT': 7,
#  'Kygo': 7,
#  'empowr': 7,
#  'Dubsmash': 7,
#  'blockchain.info': 7,
#  'centillion': 7,
#  'juul': 7,
#  '501(c': 7,
#  'dx=': 7,
#  '1&2': 7,
#  'BREXIT': 7,
#  '₹1000': 7,
#  'babur': 7,
#  '‘s': 7,
#  'neet2017': 7,
#  '6’1': 7,
#  '\\rightarrow': 7,
#  'way(s': 7,
#  'nimhans': 7,
#  'bs4': 7,
#  'GFRG': 7,
#  'f(f(x': 7,
#  '.Why': 7,
#  '2√2': 7,
#  'voltric': 7,
#  'What´s': 7,
#  'hyperthymesia': 7,
#  'softmax': 7,
#  'venmo': 7,
#  'sapiosexual': 7,
#  'RMLNLU': 7,
#  '-a': 7,
#  'OMSCS': 7,
#  'muhajirs': 7,
#  't=0': 7,
#  'engineering\u200b': 7,
#  '1=0': 7,
#  'lbsnaa': 7,
#  'Bathla': 7,
#  'tan(x': 7,
#  '1000rs': 7,
#  'Delloite': 7,
#  'Syeds': 7,
#  'Deliveroo': 7,
#  'LeetCode': 7,
#  '5’6': 7,
#  'binance': 7,
#  'mc²': 7,
#  'mamc': 7,
#  'DITISS': 7,
#  'padmavat': 7,
#  'LPUNEST': 7,
#  'ESP8266': 7,
#  '160R': 7,
#  '^1/3': 7,
#  'DataCamp': 7,
#  'Nagerkovil': 7,
#  'NITian': 7,
#  'Mangalapuram': 7,
#  '100k+': 7,
#  'fitjee': 7,
#  'ucms': 7,
#  'preboards': 7,
#  'y(t': 7,
#  'God(s': 7,
#  '.docx': 6,
#  'Aksener': 6,
#  'JGEC': 6,
#  'GoLang': 6,
#  'AIACTR': 6,
#  'chaturbate': 6,
#  'it’': 6,
#  'LMRC': 6,
#  'AngularJs': 6,
#  'possesiveness': 6,
#  'Trumpian': 6,
#  'suryanamaskar': 6,
#  'Howdid': 6,
#  'f/1.8': 6,
#  'electrovalent': 6,
#  'Garrix': 6,
#  'cryptocurency': 6,
#  'upvoters': 6,
#  'nabard': 6,
#  '5’10': 6,
#  'PyQt5': 6,
#  'b.des': 6,
#  'phycopath': 6,
#  'gpsc': 6,
#  "What's\u200b": 6,
#  'Juicero': 6,
#  "4'9": 6,
#  'f(1': 6,
#  'demonatisation': 6,
#  '√x': 6,
#  '2n+1': 6,
#  '\\geq': 6,
#  'Xapo': 6,
#  '3×3': 6,
#  'Aayog': 6,
#  'intenship': 6,
#  'crytocurrencies': 6,
#  'wbcs': 6,
#  'Wikitribune': 6,
#  'modiji': 6,
#  'kulbhushan': 6,
#  'madheshis': 6,
#  'Rupay': 6,
#  'capf': 6,
#  'Rs.500': 6,
#  'XVG': 6,
#  'MVIT': 6,
#  'srmjeee': 6,
#  'Parmanu': 6,
#  'Caulifla': 6,
#  'JGLS': 6,
#  'x/': 6,
#  'bittrex': 6,
#  'movie(s': 6,
#  '2018/2019': 6,
#  'Thadomal': 6,
#  'god(s': 6,
#  'TRAPPIST-1': 6,
#  '95%+': 6,
#  'IITTM': 6,
#  'AMWF': 6,
#  "did'nt": 6,
#  'DUJAT': 6,
#  '.the': 6,
#  'IITRAM': 6,
#  "I'm\u200b": 6,
#  'someone\u200b': 6,
#  'kingroot': 6,
#  'Su-57': 6,
#  'broglie': 6,
#  'y=0': 6,
#  'adityanath': 6,
#  'Rautela': 6,
#  'toppr': 6,
#  'Freshworks': 6,
#  'JUIT': 6,
#  'cryptocoins': 6,
#  'ximb': 6,
#  '^10': 6,
#  'Puneri': 6,
#  "GATE'18": 6,
#  'XeF6': 6,
#  'y53': 6,
#  'friend(s': 6,
#  'he/': 6,
#  'Snapay': 6,
#  '\\alpha': 6,
#  '6300HQ': 6,
#  '7200U': 6,
#  'keam': 6,
#  'Debotosh': 6,
#  'Scripbox': 6,
#  'Bluemix': 6,
#  'Rojava': 6,
#  'bitconnect': 6,
#  'tifr': 6,
#  'etoos': 6,
#  'bschools': 6,
#  'JD(S': 6,
#  'Cuphead': 6,
#  'Kejariwal': 6,
#  "4'8": 6,
#  'quara': 6,
#  'oversmart': 6,
#  'y^3': 6,
#  'cos2x': 6,
#  'T(n': 6,
#  'etherum': 6,
#  'Mewani': 6,
#  'Mysuru': 6,
#  'mastuburation': 6,
#  'trignometric': 6,
#  'microservice': 6,
#  'P.HD': 6,
#  'K+': 6,
#  'dichlorine': 6,
#  '/she': 6,
#  'cryptocurreny': 6,
#  'diprotic': 6,
#  'Quorians': 6,
#  'infinix': 6,
#  'BIMARU': 6,
#  '6’3': 6,
#  'Oliveboard': 6,
#  'Ōtsutsuki': 6,
#  're-': 6,
#  '.mp3': 6,
#  'antibrahmin': 6,
#  '6’0': 6,
#  'Shifuji': 6,
#  't^2': 6,
#  'golgappa': 6,
#  '1mole': 6,
#  'delhite': 6,
#  'math]f(x': 6,
#  'orthocentre': 6,
#  'Eastwatch': 6,
#  'child(ren': 6,
#  'BA.LLB': 6,
#  'Kahoot': 6,
#  'PayUMoney': 6,
#  'angular2': 6,
#  'fssai': 6,
#  '0.1N': 6,
#  'DC++': 6,
#  'cause(s': 6,
#  'ZenFone': 6,
#  '2lakhs': 6,
#  'TSPSC': 6,
#  'SHAREit': 6,
#  'GOT7': 6,
#  'PUBDET': 6,
#  'crispr': 6,
#  ...}

# %%
token_types(list(unk_common.keys()))
# Out:
# Number of num tokens:  16564
# Number of symbol tokens:  1519
# Number of lowcase tokens:  43548
# Number of upper case tokens:  26679
# Nubmer of capslock tokens:  2531
#
#
# Freq num tokens:  ['x^2', '^2', '1/', 'x^3', "5'4", "A2A'd", 'y^2', "5'9", '^3', "5'5"]
# Rare num tokens:  ['An+1=', 'An=2', 'NBA2K18', '3.71/4.44', '39/389', 'Z2600', '10–12', 'Feb-2018', '2200-$2500/mo', '900va']
#
# Freq symbol tokens:  ['..', '\xa0', ':(', '₹', '"-', 'करना', '\ufeff', '\n', ':/', '️']
# Rare symbol tokens:  ['τῆς', 'κατὰ', 'τὴν', 'ἡμετέραν', 'χρῆσιν', 'συνηθείας', '=--', '中庸', '中庸之道', '∅⊂']
#
# Freq low tokens:  ['cryptocurrencies', 'x^2', 'f(x', 'demonetisation', 'ethereum', 'bhakts', 'w/', 'chsl', 'x^3', 'altcoin']
# Rare low tokens:  ['youvision', 'enrollnment', 'noumber', 'sgill', 'jauhar', 'clearly"bad', 'myAIR', 'ganpat', 'rabels', 'photopicker']
#
# Freq up tokens:  ['Quorans', 'Brexit', 'Redmi', 'OnePlus', 'UCEED', 'Blockchain', 'GDPR', 'Coinbase', 'BNBR', 'Machedo']
# Rare up tokens:  ['Bhangani', 'GS-', 'Magick++', 'NotJesseChen', 'Sakoku', 'Question(JQ', 'Feb-2018', 'Minesotan', 'Tamilar', 'Khayami']
#
# Freq caps tokens:  ['UCEED', 'GDPR', 'BNBR', 'DCEU', 'IIEST', 'LNMIIT', 'NICMAR', 'MUOET', 'SRMJEE', 'SGSITS']
# Rare caps tokens:  ['PYQ', 'OCJA', 'GEORGIVS', 'FEWD', 'SPCOMM', 'SPJIMSR', 'OPENCAPI', 'HYSPM', 'MANAV', 'ICSIL']

# %% [markdown]
# ### Look at spacy tokenizer

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
print(STOP_WORDS)
# Out:
# {'several', 'while', 'moreover', 'without', 'since', 'whoever', 'where', 'that', 'anyway', 'another', 'became', 'can', 'doing', 'anything', 'except', 'everything', 'if', 'were', 'else', 'thereafter', 'one', 'between', 'which', 'whose', 'formerly', 'nowhere', 'made', 'or', 'six', 'now', 'perhaps', 'name', 'same', 'become', 'being', 'these', 'former', 'whenever', 'nine', 'just', 'many', 'almost', 'first', 'sometime', 'please', 'twelve', 'besides', 'keep', 'is', 'have', 'latterly', 'anyone', 're', 'there', 'upon', 'get', 'below', 'nevertheless', 'never', 'above', 'serious', 'hence', 'twenty', 'latter', 'before', 'ourselves', 'more', 'onto', 'whom', 'take', 'afterwards', 'in', 'he', 'already', 'here', 'nothing', 'does', 'namely', 'noone', 'could', 'yourselves', 'move', 'using', 'whereas', 'least', 'she', 'behind', 'they', 'none', 'together', 'ever', 'too', 'across', 'than', 'most', 'elsewhere', 'fifteen', 'sometimes', 'our', 'though', 'when', 'seeming', 'anyhow', 'about', 'mine', 'four', 'from', 'him', 'nobody', 'part', 'regarding', 'but', 'each', 'should', 'might', 'who', 'will', 'yourself', 'due', 'i', 'then', 'somehow', 'against', 'well', 'call', 'even', 'indeed', 'ours', 'unless', 'used', 'seems', 'meanwhile', 'somewhere', 'by', 'much', 'would', 'whether', 'itself', 'hundred', 'be', 'forty', 'must', 'no', 'really', 'so', 'and', 'someone', 'top', 'up', 'see', 'make', 'next', 'not', 'front', 'this', 'eight', 'off', 'often', 'been', 'into', 'thru', 'third', 'again', 'after', 'both', 'empty', 'everywhere', 'own', 'whereafter', 'ten', 'give', 'how', 'seemed', 'an', 'beyond', 'only', 'therefore', 'eleven', 'until', 'either', 'towards', 'for', 'anywhere', 'all', 'quite', 'side', 'whither', 'neither', 'amount', 'over', 'amongst', 'whereby', 'hereupon', 'his', 'you', 'always', 'did', 'further', 'such', 'beside', 'full', 'thereupon', 'three', 'through', 'with', 'my', 'at', 'becomes', 'down', 'hereafter', 'hers', 'other', 'still', 'its', 'very', 'of', 'bottom', 'however', 'less', 'thence', 'fifty', 'throughout', 'nor', 'toward', 'themselves', 'me', 'whence', 'sixty', 'hereby', 'show', 'why', 'within', 'among', 'those', 'what', 'others', 'because', 'thus', 'few', 'them', 'whereupon', 'wherever', 'was', 'any', 'alone', 'becoming', 'yours', 'had', 'per', 'us', 'we', 'a', 'every', 'although', 'am', 'out', 'put', 'five', 'once', 'enough', 'everyone', 'it', 'yet', 'some', 'to', 'are', 'cannot', 'herein', 'as', 'herself', 'their', 'along', 'seem', 'mostly', 'via', 'has', 'also', 'various', 'thereby', 'last', 'her', 'your', 'done', 'myself', 'whatever', 'may', 'during', 'back', 'himself', 'whole', 'therein', 'go', 'the', 'ca', 'do', 'something', 'around', 'on', 'say', 'rather', 'beforehand', 'wherein', 'two', 'under', 'otherwise'}

# %% [markdown]
# ### Read embedding

# %%
import numpy as np
embs = {}
with open(emb_path) as f:
    count = 0
    for line in f:
        if count > 100000:
            break
        count += 1
        cut = line.find(' ')
        tok = line[:cut]
        emb = line[cut + 1:].split()
        emb = np.array([float(e) for e in emb])
        embs[tok] = emb

# %%
low = embs['I']
up = embs['you']

# %%
def sim(v1, v2):
    result = sum(v1*v2)/np.linalg.norm(v1)/np.linalg.norm(v2)
    return result

# %%
print(sim(low, up))
# Out:
# 0.6627086554182071
