# %% [markdown]
# # EDA Glove embedding and Spacy tokenizer

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import re
import pandas as pd
import spacy
from collections import Counter
import numpy as np
from utils import *

# %% [markdown]
# ### Look at embedding

# %%
emb_path = 'embeddings/glove.840B.300d/glove.840B.300d.txt'
data_dir = cache = '../data'

train_csv = os.path.join(data_dir, 'train.csv')
test_csv = os.path.join(data_dir, 'test.csv')
emb_path = os.path.join(data_dir, emb_path)

# %%
# %%time
emb_tokens = []
with open(emb_path) as f:
    for line in f:
        tok = line.split()[0]
        emb_tokens.append(tok)
# Out:
# CPU times: user 21.5 s, sys: 1.24 s, total: 22.7 s
# Wall time: 22.7 s

# %%
token_info(emb_tokens)
# Out:
# Number of tokens:  2196017
# First 10 tokens:  [',', '.', 'the', 'and', 'to', 'of', 'a', 'in', '"', ':']

# %%
token_types(emb_tokens)
# Out:
# Number of num tokens:  536635
# Number of symbol tokens:  2513
# Number of lowcase tokens:  653309
# Number of upper case tokens:  1089000
# Nubmer of capslock tokens:  153812
#
#
# Freq num tokens:  ['1', '2', '3', '4', '2012', '5', '2011', '10', '2010', '2009']
# Rare num tokens:  ['km/11', 'mono-2', 'otherjuicystar07', 'own36', 'p263', 'r91', 's9100', 'sarah123', 'v205', 'z/28']
#
# Freq symbol tokens:  [',', '.', '"', ':', ')', '(', '-', '...', '!', '?']
# Rare symbol tokens:  ['?!?!?!?!!', '?!?!?!?!?!?!?!?!?', 'ãƒˆã', 'ａ', '-------------------------------------------------------------------------------------------------------------------------------------------------', 'ɯ', 'вЂ', '回', 'ĵ', 'ÐÐ']
#
# Freq low tokens:  ['the', 'and', 'to', 'of', 'a', 'in', 'is', 'for', 'that', 'on']
# Rare low tokens:  ['work.Like', 'working.So', 'wried', 'wwent', 'xalisae', 'xtremecaffeine', 'yildirim', 'z/28', 'zipout', 'zulchzulu']
#
# Freq up tokens:  ['I', 'The', 'It', 'This', 'A', 'In', 'You', 'We', 'If', 'And']
# Rare up tokens:  ['Wozniaki', 'Xcode4', 'Yahne', 'Yes98', 'Yester-Me', 'YouMuhammad', 'Youli', 'ZNY', 'ZOELLICK', 'ZeitGeist']
#
# Freq caps tokens:  ['I', 'A', 'PM', 'AM', 'THE', 'US', 'TV', 'UK', 'OF', 'AND']
# Rare caps tokens:  ['TERRYK', 'TORSEN', 'VCDI', 'WEAO', 'WEDCO', 'WILLES', 'WMHK', 'WYLAM', 'ZNY', 'ZOELLICK']

# %% [markdown]
# ### Tokenize data and build vocab

# %%
train = pd.read_csv(train_csv)['question_text'].values.tolist()
test = pd.read_csv(test_csv)['question_text'].values.tolist()
data = train + test

# %%
# %%time
unknown_tokens = []
vocab = Counter()
spacy_en = spacy.load('en')
tokenizer = spacy_en.tokenizer
emb_tokens_set = set(emb_tokens)
for question in data:
    doc = tokenizer(question)
    for token in doc:
        tok_text = token.text
        vocab.update([tok_text])
        if vocab[tok_text] == 1:
            if tok_text not in emb_tokens_set:
                unknown_tokens.append(tok_text)
        
#doc = nlp(u'Apple is looking at buying U.K. startup for $1 billion')
#for token in doc:
#    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
#          token.shape_, token.is_alpha, token.is_stop)
# Out:
# CPU times: user 2min 24s, sys: 185 ms, total: 2min 25s
# Wall time: 2min 23s

# %%
vocab_tokens = dict(vocab.most_common()).keys()

# %%
token_types(vocab_tokens)
# Out:
# Number of num tokens:  29530
# Number of symbol tokens:  1727
# Number of lowcase tokens:  132699
# Number of upper case tokens:  113484
# Nubmer of capslock tokens:  15169
#
#
# Freq num tokens:  ['2', '2017', '2018', '1', '3', '10', '5', '4', '12', '6']
# Rare num tokens:  ['10–12', '61850', 'Feb-2018', '2200-$2500/mo', '4000/mo', '999999', '450cc', '78.53', '900va', '6740']
#
# Freq symbol tokens:  ['?', ',', '.', '"', '-', ')', '(', '/', "'", '&']
# Rare symbol tokens:  ['τῆς', 'κατὰ', 'τὴν', 'ἡμετέραν', 'χρῆσιν', 'συνηθείας', '=--', '中庸', '中庸之道', '∅⊂']
#
# Freq low tokens:  ['the', 'to', 'a', 'in', 'is', 'of', 'and', 'do', 'are', 'for']
# Rare low tokens:  ['noumber', 'sml', 'sgill', 'jauhar', 'clearly"bad', 'myAIR', 'cybershot', 'ganpat', 'rabels', 'photopicker']
#
# Freq up tokens:  ['What', 'I', 'How', 'Why', 'Is', 'Can', 'Which', 'Do', 'If', 'India']
# Rare up tokens:  ['Dime', 'Entanglements', 'Tamilar', 'Flurry', 'Routines', 'ULTIMATELY', 'Hb', 'Generate', 'Khayami', 'Thetis']
#
# Freq caps tokens:  ['I', 'US', 'USA', 'A', 'JEE', 'TV', 'UK', 'IIT', 'MBA', 'IT']
# Rare caps tokens:  ['IPOS', 'MANAV', 'ICSIL', 'RCZ', 'PPW', 'AOTS', 'THEORETICAL', 'FRAMEWORK', 'EPAM', 'ULTIMATELY']

# %% [markdown]
# ### Capslock tokens

# %%
caps_re = re.compile('^[A-Z]*$')
caps_tokens = []
for t in vocab_tokens:
    if caps_re.match(t):
        caps_tokens.append(t)

# %%
emotional_caps_tokens = []
for t in caps_tokens:
    if t not in emb_tokens_set and t.lower() in emb_tokens_set:
        emotional_caps_tokens.append(t)
print(len(emotional_caps_tokens))
# Out:
# 307

# %%
emotional_caps_tokens
# Out:
# ['UPSE',
#  'BHIM',
#  'IPHO',
#  'AADHAR',
#  'ANTHE',
#  'MESRA',
#  'QUORA',
#  'IARE',
#  'HODL',
#  'BLACKI',
#  'SHIATS',
#  'BRDS',
#  'PSUS',
#  'NARCOS',
#  'SILCHAR',
#  'SNAPCHAT',
#  'OCER',
#  'NITR',
#  'UOFT',
#  'FUDI',
#  'DEPR',
#  'NAOH',
#  'CRYPTOCURRENCY',
#  'EVETS',
#  'SBUF',
#  'JOSSA',
#  'RGIA',
#  'CELU',
#  'IANG',
#  'ARTICLESHIP',
#  'GOTRA',
#  'MARATHA',
#  'PRIST',
#  'CAPGEMINI',
#  'JAAT',
#  'LIATE',
#  'OMPRAKASH',
#  'HEETS',
#  'GOOGEL',
#  'ACHEIVEMENTS',
#  'RITEE',
#  'IRRESPONSIBILITY',
#  'ISHANT',
#  'BATSMEN',
#  'MEDICORE',
#  'ACCEDENT',
#  'PYURIA',
#  'GASSES',
#  'CURRNT',
#  'INSITED',
#  'EXHISTING',
#  'FANCHISE',
#  'CENSE',
#  'SURABHI',
#  'IRRITANTS',
#  'PANVEL',
#  'SAYEED',
#  'OLYMPIADS',
#  'JUCHE',
#  'UNWORKABLE',
#  'BLASPHEMING',
#  'DHARWAD',
#  'ASKD',
#  'CHEGG',
#  'FIIO',
#  'APPOITMENT',
#  'HTTRACK',
#  'WEBTOON',
#  'REFRENCES',
#  'SHEIN',
#  'BANARAS',
#  'GRETEST',
#  'GOWDA',
#  'REFERNECE',
#  'LANDLESS',
#  'INGENERAL',
#  'FATIHAH',
#  'SANJU',
#  'BELEIEVE',
#  'PARTIT',
#  'DAENERYS',
#  'TUMMO',
#  'BITCOINS',
#  'RATIONALIZE',
#  'ADND',
#  'AMIEN',
#  'VEERE',
#  'FETO',
#  'XAVIERS',
#  'REBOILER',
#  'LIIT',
#  'NUMERATOR',
#  'COURSERA',
#  'ENGINNERS',
#  'LISK',
#  'BRAHMANS',
#  'LEEE',
#  'COMMY',
#  'WATU',
#  'CUDS',
#  'CURCUMIN',
#  'FORB',
#  'VIXY',
#  'RIYAZ',
#  'KHURANA',
#  'VOIN',
#  'SUPARI',
#  'ACCOUSTICS',
#  'INDUSTRIALISATION',
#  'KASHMIRIS',
#  'PLEBISCITE',
#  'PAKISTHAN',
#  'BHIWANDI',
#  'VIDYAPEETH',
#  'DESTRUCTIONS',
#  'HOMINIDS',
#  'AREAR',
#  'MANAPHY',
#  'DIOT',
#  'IBATIS',
#  'VAPORIZE',
#  'NINCOMPOOPS',
#  'MEUM',
#  'SUAM',
#  'ABORTIVE',
#  'DEMONETIZATION',
#  'MUNS',
#  'ECRIS',
#  'XNK',
#  'POLITICANS',
#  'FIREBUG',
#  'LASIC',
#  'DERMOID',
#  'HARPING',
#  'CHALLAN',
#  'BIGINNER',
#  'KASAB',
#  'GOENKA',
#  'ZUZ',
#  'DIFFERNCE',
#  'NOKO',
#  'PRIVIOUS',
#  'SPYGATE',
#  'RETRENCH',
#  'GULABI',
#  'BURLA',
#  'BCUS',
#  'GUESSWORK',
#  'RUDRAKSH',
#  'IKY',
#  'SWAYAM',
#  'WITCHS',
#  'MANNUAL',
#  'NEUT',
#  'GIVEUP',
#  'FRICTIONLESS',
#  'ABSENTIA',
#  'DESCREPANCY',
#  'VAIRAGYA',
#  'PRABHAS',
#  'AIRBNB',
#  'KRANTHI',
#  'TIRUPATHI',
#  'STRIX',
#  'WORSENED',
#  'NAXAL',
#  'SMOTE',
#  'LEAVED',
#  'RANJI',
#  'KHATA',
#  'IIFE',
#  'MARJI',
#  'SMARTNESS',
#  'NAKBA',
#  'SHAREMARKETS',
#  'TIRUMALA',
#  'VISHESH',
#  'INDOR',
#  'DRAKON',
#  'PINKU',
#  'XIAOMI',
#  'BREIFLY',
#  'TABACCO',
#  'PINCHERS',
#  'MANIFACTURED',
#  'MIRCHI',
#  'HEMM',
#  'PSYCOLOGICAL',
#  'BCAAS',
#  'CIVILS',
#  'INSCRIPT',
#  'SHASTRA',
#  'CLUCH',
#  'LOPTOP',
#  'PIGI',
#  'PRACTICALS',
#  'MOSTEST',
#  'UNIVERCITY',
#  'DAINIK',
#  'JAGRAN',
#  'UNFORSEEN',
#  'UMANG',
#  'ANDHRAPRADESH',
#  'KAFFIRS',
#  'AFAID',
#  'AMHARA',
#  'BENEFICAL',
#  'GONK',
#  'URBANISATION',
#  'GCSES',
#  'DBOL',
#  'OSMANIA',
#  'BRUTTO',
#  'DEPRIVING',
#  'MUGO',
#  'QUATS',
#  'CONTINIOUSLY',
#  'TRIGONOMETRIC',
#  'BEARDO',
#  'SERVICEMAN',
#  'OFFPAGE',
#  'DEEPSET',
#  'DOUCHEBAGGERY',
#  'ACNES',
#  'AQUAINTANCE',
#  'GITH',
#  'USFOR',
#  'MEGHALAYA',
#  'MIMER',
#  'GESE',
#  'MOIT',
#  'HOMOMORPHISM',
#  'TRIPHALA',
#  'ENTROPAY',
#  'STREM',
#  'BEETWEEN',
#  'TRAPPIST',
#  'DELINK',
#  'BOIII',
#  'USUM',
#  'MAINTAINCE',
#  'ISSER',
#  'TQW',
#  'IMEL',
#  'LOOMPAS',
#  'AGET',
#  'DIGUSTING',
#  'ANSY',
#  'JAINS',
#  'PALYA',
#  'COFFY',
#  'VENKATESWARA',
#  'SADU',
#  'ANALYTICA',
#  'LOFO',
#  'CHATBOT',
#  'PLUNGED',
#  'APPCMD',
#  'ROTHCHILD',
#  'TERRIORISTS',
#  'SYDE',
#  'QDOBA',
#  'HOUSEMATES',
#  'XDN',
#  'SWERE',
#  'GOUGED',
#  'PRESSTITUTES',
#  'KERLA',
#  'ADHAR',
#  'CORELATION',
#  'SUAT',
#  'PADMAVATI',
#  'RUPAY',
#  'RULET',
#  'TRUSTER',
#  'DLED',
#  'ARCHITECHT',
#  'DIRP',
#  'TERF',
#  'PAPAD',
#  'FARIO',
#  'LOGMEIN',
#  'SEVAK',
#  'EXPREINCE',
#  'GESCOM',
#  'ALKANE',
#  'ALKENE',
#  'ALKYNE',
#  'TATKAL',
#  'SCILAB',
#  'COMOS',
#  'TEEKAY',
#  'GMAE',
#  'PAKKA',
#  'REHIRE',
#  'TIVI',
#  'ELAT',
#  'NESSUS',
#  'AADHAAR',
#  'KHADI',
#  'WEAV',
#  'TRANSGENDERS',
#  'DECIMATING',
#  'HIJRAH',
#  'QUORAN',
#  'LADDU',
#  'MANAV']

# %% [markdown]
# ### Unknown tokens

# %%
unk_vocab = {}
for w in unknown_tokens:
    unk_vocab[w] = vocab[w]
unk_vocab = Counter(unk_vocab)

# %%
print('Total number of tokens: ', sum(vocab.values()))
print('Number of unique tokens: ', len(vocab))
print('Total number of unknown tokens: ', sum(unk_vocab.values()))
print('Number of unique unknown tokens: ', len(unknown_tokens))
print('Percent of unknown tokens: ', 100 * sum(unk_vocab.values())/sum(vocab.values()))
# Out:
# Total number of tokens:  19837964
# Number of unique tokens:  268601
# Total number of unknown tokens:  113339
# Number of unique unknown tokens:  82595
# Percent of unknown tokens:  0.5713237507639393

# %%
unk_common = dict(unk_vocab.most_common())
print('Number of 100 most common unk tokens: ', sum(list(unk_common.values())[:100]))
# Out:
# Number of 100 most common unk tokens:  9242

# %%
unk_common
# Out:
# {'..': 888,
#  'Quorans': 882,
#  'Brexit': 510,
#  'cryptocurrencies': 506,
#  'Redmi': 394,
#  '\xa0': 239,
#  '/math': 231,
#  'x^2': 205,
#  'f(x': 179,
#  '^2': 147,
#  'OnePlus': 130,
#  'UCEED': 126,
#  'Blockchain': 111,
#  'GDPR': 110,
#  'demonetisation': 109,
#  'Coinbase': 105,
#  'BNBR': 104,
#  'Machedo': 103,
#  'Adityanath': 101,
#  'Boruto': 96,
#  '\\frac': 96,
#  'ethereum': 95,
#  'DCEU': 93,
#  'IIEST': 90,
#  'SJWs': 84,
#  'Qoura': 81,
#  "Qur'an": 79,
#  'LNMIIT': 72,
#  'Zerodha': 69,
#  'A+': 69,
#  'Upwork': 68,
#  'Kavalireddi': 67,
#  '.net': 65,
#  'bhakts': 65,
#  '1/': 65,
#  'Doklam': 62,
#  'NICMAR': 62,
#  'Vajiram': 61,
#  'Unacademy': 60,
#  'w/': 56,
#  'AlShamsi': 56,
#  'MUOET': 55,
#  'chsl': 55,
#  'x^3': 55,
#  "5'4": 53,
#  'Bhakts': 52,
#  'HackerRank': 52,
#  'Litecoin': 51,
#  'Jiren': 51,
#  'Awdhesh': 50,
#  "A2A'd": 49,
#  'altcoin': 49,
#  'y^2': 48,
#  'eLitmus': 47,
#  'altcoins': 47,
#  'Cryptocurrency': 47,
#  'Ryzen': 46,
#  "5'9": 46,
#  'SRMJEE': 46,
#  '\\sqrt': 44,
#  'Baahubali': 44,
#  '^3': 44,
#  "5'5": 44,
#  'Amazon.in': 43,
#  "5'3": 42,
#  'SGSITS': 42,
#  'Skripal': 42,
#  'Beerus': 42,
#  'coinbase': 41,
#  'B+': 41,
#  'What\u200b': 41,
#  'a+b': 40,
#  'Alshamsi': 40,
#  "5'7": 39,
#  "5'2": 39,
#  'BIPC': 38,
#  'BMSCE': 38,
#  'Gurugram': 38,
#  'bahubali': 38,
#  "5'6": 38,
#  'Binance': 38,
#  'SRMJEEE': 37,
#  'Zebpay': 37,
#  'Truecaller': 37,
#  'Swachh': 36,
#  "5'10": 36,
#  'josaa': 36,
#  'Ravula': 36,
#  'Golang': 35,
#  '\\math': 35,
#  'OBOR': 34,
#  'litecoin': 34,
#  "5'8": 34,
#  'clickbait': 33,
#  'upwork': 33,
#  'iisc': 33,
#  'MHCET': 33,
#  '\\infty': 33,
#  'TensorFlow': 32,
#  '^n': 32,
#  "5'11": 32,
#  'Google+': 32,
#  'e^x': 32,
#  'Quora.com': 31,
#  '.what': 31,
#  ':(': 31,
#  'Chromecast': 31,
#  'y=': 30,
#  'IISERs': 30,
#  'Adhaar': 30,
#  'PESSAT': 30,
#  'O+': 30,
#  'g(x': 30,
#  'adhaar': 29,
#  'demonitisation': 29,
#  'x^4': 29,
#  'Koinex': 29,
#  'LBSNAA': 29,
#  '\\int': 29,
#  'LGBT+': 28,
#  'LGBTQ+': 28,
#  'Patreon': 28,
#  'Byju': 28,
#  'unacademy': 28,
#  '.I': 28,
#  'hyperloop': 28,
#  'microservices': 27,
#  'Whst': 27,
#  'non-': 27,
#  '8)': 27,
#  'fortnite': 27,
#  'USICT': 27,
#  'ReactJS': 27,
#  '2x^2': 26,
#  'H+': 26,
#  'x+1': 26,
#  'Zamasu': 26,
#  'x=0': 26,
#  'UPSE': 26,
#  '\\sum': 26,
#  'mc^2': 25,
#  'B.Des': 25,
#  'Codeforces': 25,
#  'brexit': 25,
#  'Fiitjee': 25,
#  'A-': 25,
#  'Trumpcare': 25,
#  'Bittrex': 25,
#  'Irodov': 25,
#  'FTRE': 25,
#  'tensorflow': 25,
#  '\\left': 25,
#  'Tensorflow': 24,
#  '3x^2': 24,
#  'Demonetization': 24,
#  'Simpliv': 24,
#  'Howcan': 24,
#  'Kalpit': 24,
#  '₹': 24,
#  'e^': 24,
#  'JoSAA': 24,
#  '\\to': 24,
#  'OneDrive': 24,
#  '\\right': 24,
#  '.How': 24,
#  'NLUs': 23,
#  'MHTCET': 23,
#  'IIITH': 23,
#  'IGDTUW': 23,
#  '^1/2': 23,
#  "6'1": 22,
#  'musical.ly': 22,
#  's^2': 22,
#  'DeepMind': 22,
#  'Undertale': 22,
#  'Jungkook': 22,
#  'apist': 21,
#  'Arrowverse': 21,
#  'a^2': 21,
#  'Xiomi': 21,
#  'Whydo': 21,
#  'chapterwise': 21,
#  'JCPOA': 21,
#  'undergraduation': 21,
#  'sin(x': 21,
#  "6'2": 21,
#  'rohingya': 21,
#  'incels': 21,
#  'Despacito': 21,
#  '401(k': 21,
#  'genderfluid': 21,
#  'schizoids': 21,
#  'IIITD': 21,
#  '\\times': 21,
#  'hotstar': 21,
#  'Kubernetes': 20,
#  'WannaCry': 20,
#  'JioFi': 20,
#  'VSSUT': 20,
#  'AKTU': 20,
#  'AIATS': 20,
#  'dx[/math': 20,
#  'zebpay': 20,
#  '\\cdot': 20,
#  'book(s': 20,
#  'EFLU': 20,
#  'twinflame': 20,
#  'HBTU': 20,
#  'Theranos': 20,
#  'Zenfone': 20,
#  '.Net': 20,
#  'Veerwal': 20,
#  'MMMUT': 20,
#  'nanodegree': 19,
#  'fullform': 19,
#  'Hotstar': 19,
#  'PMAY': 19,
#  '\\in': 19,
#  'EXTC': 19,
#  'math]x[/math': 19,
#  'Na+': 19,
#  '/2': 19,
#  'madheshi': 19,
#  'language(s': 19,
#  'Cryptocurrencies': 19,
#  'Sarahah': 19,
#  'Padmaavat': 18,
#  'blockchains': 18,
#  'biharis': 18,
#  'x+y': 18,
#  '"-': 18,
#  'React.js': 18,
#  'How\u200b': 18,
#  'Kovind': 18,
#  'BHIM': 18,
#  'D3300': 18,
#  '\\displaystyle': 18,
#  'Pizzagate': 18,
#  'Kaneki': 18,
#  'AirPods': 18,
#  'Nanodegree': 18,
#  '-x': 18,
#  'a+b+c': 18,
#  'Strzok': 18,
#  'AB+': 18,
#  '\\lim': 18,
#  'pcod': 18,
#  'HackerEarth': 18,
#  'TISSNET': 17,
#  '2017/2018': 17,
#  'Swiggy': 17,
#  "I'am": 17,
#  'don´t': 17,
#  'Jupyter': 17,
#  '\\leq': 17,
#  'RLWL': 17,
#  'Instacart': 17,
#  'Odoo': 17,
#  'Kattankulathur': 17,
#  'n+1': 17,
#  'mhtcet': 17,
#  '\\pi': 17,
#  'करना': 17,
#  '\\dfrac': 17,
#  'Mbappe': 17,
#  'Zhihu': 17,
#  'ftre': 17,
#  'koinex': 17,
#  'IPMAT': 17,
#  'PayTM': 16,
#  'I`m': 16,
#  'Kainerugaba': 16,
#  'Qidian': 16,
#  'Ahok': 16,
#  'Steemit': 16,
#  '\ufeff': 16,
#  'SSCBS': 16,
#  "don'TS": 16,
#  'e-': 16,
#  'better-': 16,
#  'LNCT': 16,
#  'Awdesh': 16,
#  'UPESEAT': 16,
#  'x^': 16,
#  'Warmbier': 16,
#  'XXXTentacion': 16,
#  "6'4": 16,
#  'A=': 16,
#  'Whyis': 16,
#  'cos(x': 16,
#  'USACO': 16,
#  'zerodha': 16,
#  'class11': 16,
#  'Neuralink': 16,
#  'IFoS': 16,
#  'AIEEA': 16,
#  'B-': 15,
#  'I´m': 15,
#  'GANs': 15,
#  'PESU': 15,
#  'MSQE': 15,
#  'x^x': 15,
#  'AILET': 15,
#  '2k17': 15,
#  'OpenAI': 15,
#  'Dhinchak': 15,
#  '=3': 15,
#  'Drumpf': 15,
#  "5'1": 15,
#  'Padmavat': 15,
#  '.What': 15,
#  'Bitfinex': 15,
#  'VITMEE': 15,
#  '.how': 15,
#  '\n': 15,
#  '|x|': 14,
#  'b^2': 14,
#  '1=2': 14,
#  'BMSIT': 14,
#  'Plancess': 14,
#  'Taehyung': 14,
#  'B.arch': 14,
#  "gov't": 14,
#  'RGIPT': 14,
#  'Bitconnect': 14,
#  'MH370': 14,
#  'demonitization': 14,
#  'Killmonger': 14,
#  'dream11': 14,
#  ':/': 14,
#  'UGEE': 14,
#  'ipill': 14,
#  '2-': 14,
#  'Kefla': 14,
#  'internshala': 14,
#  'srmjee': 14,
#  'IIHM': 14,
#  'HSEE': 14,
#  'covfefe': 14,
#  'sh*t': 14,
#  'MAKAUT': 14,
#  'O-': 14,
#  'IIT(ISM': 14,
#  'Dream11': 13,
#  'Oneplus': 13,
#  'WikiTribune': 13,
#  'x+2': 13,
#  'D7200': 13,
#  'math]\\displaystyle': 13,
#  'NSEJS': 13,
#  'acturial': 13,
#  'NITians': 13,
#  'Vue.js': 13,
#  'Brexiters': 13,
#  '1[/math': 13,
#  'PGDBF': 13,
#  'MH17': 13,
#  'Electroneum': 13,
#  'Ravindrababu': 13,
#  'DSCE': 13,
#  'GSTIN': 13,
#  'sarahah': 13,
#  'G+': 13,
#  'AlphaGo': 13,
#  '\\div': 13,
#  '.exe': 13,
#  'narcissit': 13,
#  'VITEE': 13,
#  'parents’': 13,
#  'YourQuote': 13,
#  'Waymo': 12,
#  'covalency': 12,
#  'jiofi': 12,
#  'HYPSM': 12,
#  'mppsc': 12,
#  'Kilimall': 12,
#  'X^2': 12,
#  'AIMCAT': 12,
#  'RWBY': 12,
#  "f'(x": 12,
#  "CAT'17": 12,
#  '2x+1': 12,
#  '4x^3': 12,
#  '7700k': 12,
#  'Brexiteers': 12,
#  'Feku': 12,
#  'muoet': 12,
#  '^x': 12,
#  'LHMC': 12,
#  'Practo': 12,
#  '1+x': 12,
#  'MPSTME': 12,
#  'MobiKwik': 12,
#  'KGMU': 12,
#  '2x^3': 12,
#  'HomePod': 12,
#  'ex-': 12,
#  'math]n[/math': 12,
#  '️': 12,
#  'sin^2': 12,
#  'mhcet': 12,
#  '\\\\': 12,
#  '\\mathrm': 12,
#  'wumao': 12,
#  '/3': 12,
#  'FZ25': 12,
#  'a^3': 11,
#  '2^x': 11,
#  'kotlin': 11,
#  '0[/math': 11,
#  'NIELIT': 11,
#  'DoorDash': 11,
#  "dosen't": 11,
#  'DigitalOcean': 11,
#  '5’3': 11,
#  'incel': 11,
#  'RCOEM': 11,
#  'BALLB': 11,
#  'can`t': 11,
#  'dangal': 11,
#  'c^2': 11,
#  '=-': 11,
#  'pqwl': 11,
#  'Otsutsuki': 11,
#  'no.1': 11,
#  'JECRC': 11,
#  '\xa0 ': 11,
#  'you’': 11,
#  'remainers': 11,
#  '√2': 11,
#  'Tamilans': 11,
#  'ncerts': 11,
#  'sayat.me': 11,
#  'IMUCET': 11,
#  'Lenskart': 11,
#  'x+3': 11,
#  '.edu': 11,
#  '\\mathbb': 11,
#  'f**k': 11,
#  'class9': 11,
#  'countries’': 11,
#  'Trumpism': 11,
#  'Minance': 11,
#  'है': 11,
#  'VESIT': 11,
#  'math]\\int': 11,
#  'Poloniex': 11,
#  'WebAssembly': 10,
#  'parent(s': 10,
#  'GE14': 10,
#  'Qyburn': 10,
#  'ln(x': 10,
#  '.is': 10,
#  'Daesh': 10,
#  'Zoomcar': 10,
#  '-i': 10,
#  'Sense8': 10,
#  'US’': 10,
#  'GraphQL': 10,
#  'kmno4': 10,
#  '1300D': 10,
#  'OH-': 10,
#  'cringiest': 10,
#  '/her': 10,
#  'Whydoes': 10,
#  'darkweb': 10,
#  '2k18': 10,
#  'IERT': 10,
#  "6'5": 10,
#  'Tambrahms': 10,
#  '\\text': 10,
#  '.in': 10,
#  "6'0": 10,
#  'F(x': 10,
#  'States’': 10,
#  'others’': 10,
#  'SPPU': 10,
#  'deplorables': 10,
#  'o+': 10,
#  'rohingyas': 10,
#  '3-': 10,
#  'gaslighted': 10,
#  'Bolsonaro': 10,
#  'PhonePe': 10,
#  'hyperconjugation': 10,
#  'IGST': 10,
#  'Gurmehar': 10,
#  'PGDIE': 10,
#  'sambhaji': 10,
#  '4x^2': 10,
#  'without\u200b': 10,
#  'electroneum': 10,
#  'B.des': 10,
#  'Sanghis': 10,
#  'Unocoin': 10,
#  'DILR': 10,
#  "DON'T": 10,
#  'ERC20': 10,
#  "5'0": 10,
#  'Jipmer': 10,
#  'n^2': 10,
#  'thicc': 10,
#  'gaslighter': 10,
#  '/-': 10,
#  'byjus': 10,
#  'BYJU': 10,
#  'RNSIT': 10,
#  'Remainers': 10,
#  'Petuhov': 10,
#  'RNNs': 10,
#  'girls’': 10,
#  'shine.com': 10,
#  'flipcart': 10,
#  'boys’': 10,
#  'thing(s': 10,
#  'math]x': 10,
#  'LRDI': 9,
#  'Bajjika': 9,
#  'n=1': 9,
#  'BASLP': 9,
#  'b1/b2': 9,
#  'NCERTs': 9,
#  '\\cos': 9,
#  'Bartetzko': 9,
#  'PRMO': 9,
#  'Elitmus': 9,
#  'Krennic': 9,
#  'boruto': 9,
#  'mmmut': 9,
#  'Antminer': 9,
#  "6'3": 9,
#  'ecosport': 9,
#  'fz25': 9,
#  'ARKit': 9,
#  'his/': 9,
#  '.22LR': 9,
#  'a^': 9,
#  'sklearn': 9,
#  '5x^2': 9,
#  'A2As': 9,
#  'FRDI': 9,
#  'x[/math': 9,
#  '-ve': 9,
#  '3G/4': 9,
#  'NIFTEM': 9,
#  '1050ti': 9,
#  '^5': 9,
#  'Rejuvalex': 9,
#  'Midoriya': 9,
#  'IPUCET': 9,
#  'Trezor': 9,
#  '\\sin': 9,
#  'Gujratis': 9,
#  'sinx+cosx': 9,
#  'LeEco': 9,
#  'BVCOE': 9,
#  '.Is': 9,
#  'sec^2': 9,
#  'NLUO': 9,
#  'HIV+': 9,
#  'g5s': 9,
#  'Dogecoin': 9,
#  'x=2': 9,
#  'Howdoes': 9,
#  'm^3': 9,
#  'Demonetisation': 9,
#  'BitConnect': 9,
#  'machedo': 9,
#  'GDAX': 9,
#  'b.pharm': 9,
#  '/x': 9,
#  'RBEI': 9,
#  'IPHO': 9,
#  '2=5': 9,
#  'AlphaZero': 9,
#  '-1/2': 9,
#  'Americans’': 9,
#  'self-': 9,
#  'reason(s': 9,
#  '\\lt': 9,
#  'CPTSD': 9,
#  'aurangzeb': 9,
#  'x=': 9,
#  '5’7': 9,
#  'Microservices': 9,
#  '940mx': 9,
#  '^4': 9,
#  '5’9': 9,
#  'x^5': 9,
#  "4'11": 9,
#  '/or': 9,
#  '\\ln': 9,
#  ',-': 8,
#  'Quoras': 8,
#  '2^n': 8,
#  '₹5000': 8,
#  'F1.8': 8,
#  'b.pharma': 8,
#  'Whichis': 8,
#  'ShopClues': 8,
#  '-x^2': 8,
#  'crytocurrency': 8,
#  'tan^-1': 8,
#  '1-': 8,
#  'TQWL': 8,
#  'C+': 8,
#  '₹1': 8,
#  'jeemains': 8,
#  'and/': 8,
#  'Bumrah': 8,
#  'IIITDM': 8,
#  'alovera': 8,
#  'sadhguru': 8,
#  'fayol': 8,
#  '5’4': 8,
#  'autoencoder': 8,
#  'oswaal': 8,
#  'Jesus’': 8,
#  '9A0': 8,
#  'Chutiya': 8,
#  'Haptik': 8,
#  'Umtiti': 8,
#  'x^2+y^2': 8,
#  'Stardew': 8,
#  'B1B2': 8,
#  '2=4': 8,
#  'HoloLens': 8,
#  'PyTorch': 8,
#  'class12': 8,
#  'Nearbuy': 8,
#  'epfo': 8,
#  'Sokovia': 8,
#  '.find': 8,
#  'CIWG': 8,
#  'jungkook': 8,
#  'daiict': 8,
#  'Strowman': 8,
#  'FMGE': 8,
#  'WWhat': 8,
#  'x+1/x': 8,
#  '90%+': 8,
#  '√3': 8,
#  'math]n': 8,
#  'Jozwik': 8,
#  'x(t': 8,
#  '5=': 8,
#  'vidhan': 8,
#  'Webnovel': 8,
#  'jcece': 8,
#  '160r': 8,
#  'D5300': 8,
#  'E&TC': 8,
#  'H3O+': 8,
#  'doklam': 8,
#  'SIMSREE': 8,
#  'z^2': 8,
#  'cpec': 8,
#  'narcisists': 8,
#  'byju': 8,
#  'Philando': 8,
#  'biromantic': 8,
#  'WILP': 8,
#  'copper(II': 8,
#  'Mangalyaan': 8,
#  'coching': 8,
#  'Azdome': 8,
#  'sallery': 8,
#  'musigma': 8,
#  'x=3': 8,
#  'LSTMs': 8,
#  'x^n': 8,
#  'Antshares': 8,
#  'nickel(II': 8,
#  'freebitco.in': 8,
#  '1=': 8,
#  'No.1': 8,
#  'Kasganj': 8,
#  'one(s': 8,
#  'BigHit': 8,
#  'jallikattu': 8,
#  'Novichok': 8,
#  '-1/12': 8,
#  '.why': 8,
#  'Wishfie': 8,
#  'a+': 8,
#  '^-1': 8,
#  'MnC': 8,
#  'Avenatti': 8,
#  'B.pharm': 8,
#  'D3400': 8,
#  'uncollapse': 8,
#  'doky.io': 8,
#  'cos^2': 8,
#  'I‘m': 8,
#  'Qur’an': 8,
#  'NS200': 7,
#  "Qu'ran": 7,
#  'UberEats': 7,
#  'lnct': 7,
#  'Bregoli': 7,
#  'Cgl': 7,
#  '5’8': 7,
#  'Internshala': 7,
#  '2018/19': 7,
#  'note4': 7,
#  'b^3': 7,
#  'I️': 7,
#  '4^x': 7,
#  'D+': 7,
#  'PGDHRM': 7,
#  'C-': 7,
#  'harpic': 7,
#  'H2So4': 7,
#  'math]a': 7,
#  'Sharudenko': 7,
#  'IGTV': 7,
#  'Randyll': 7,
#  'zenfone': 7,
#  "shouldn't": 7,
#  'bokaro': 7,
#  'FNAF': 7,
#  'Rs.10000': 7,
#  'AADHAR': 7,
#  'vitee': 7,
#  'Ciaz': 7,
#  'JNUEE': 7,
#  'n+2': 7,
#  'aiats': 7,
#  'kids’': 7,
#  'polyhouse': 7,
#  '1080ti': 7,
#  'ISBF': 7,
#  'CUCET': 7,
#  'm.ed': 7,
#  'can´t': 7,
#  'ravindrababu': 7,
#  'Ibps': 7,
#  'a^x': 7,
#  '1+x^2': 7,
#  'dy=0': 7,
#  'GTBIT': 7,
#  'Altcoins': 7,
#  'pcmb': 7,
#  'k=1': 7,
#  'Vidyalankar': 7,
#  'h(x': 7,
#  'DSATM': 7,
#  'touchbar': 7,
#  'wish.com': 7,
#  'Cas9': 7,
#  'm²': 7,
#  'garud': 7,
#  'cm^2': 7,
#  'Xender': 7,
#  'Nidahas': 7,
#  'Kvpy': 7,
#  'Hashflare': 7,
#  '1300d': 7,
#  'Izuku': 7,
#  'Tezos': 7,
#  '\\beta': 7,
#  'Skripals': 7,
#  'locopilot': 7,
#  'Devasena': 7,
#  'f*ck': 7,
#  'P(x': 7,
#  'n^': 7,
#  'theeta': 7,
#  '.If': 7,
#  'CarPlay': 7,
#  'cm^3': 7,
#  '\\displaystyle\\int': 7,
#  'B=': 7,
#  '₹10,000': 7,
#  '940MX': 7,
#  'should\u200b': 7,
#  'BvS': 7,
#  'cryptocoin': 7,
#  'Whatdo': 7,
#  'digilocker': 7,
#  'l&t': 7,
#  'Pribumi': 7,
#  'NMAMIT': 7,
#  'Kygo': 7,
#  'empowr': 7,
#  'Dubsmash': 7,
#  'blockchain.info': 7,
#  'centillion': 7,
#  'juul': 7,
#  '501(c': 7,
#  'dx=': 7,
#  '1&2': 7,
#  'BREXIT': 7,
#  '₹1000': 7,
#  'babur': 7,
#  '‘s': 7,
#  'neet2017': 7,
#  '6’1': 7,
#  '\\rightarrow': 7,
#  'way(s': 7,
#  'nimhans': 7,
#  'bs4': 7,
#  'GFRG': 7,
#  'f(f(x': 7,
#  '.Why': 7,
#  '2√2': 7,
#  'voltric': 7,
#  'What´s': 7,
#  'hyperthymesia': 7,
#  'softmax': 7,
#  'venmo': 7,
#  'sapiosexual': 7,
#  'RMLNLU': 7,
#  '-a': 7,
#  'OMSCS': 7,
#  'muhajirs': 7,
#  't=0': 7,
#  'engineering\u200b': 7,
#  '1=0': 7,
#  'lbsnaa': 7,
#  'Bathla': 7,
#  'tan(x': 7,
#  '1000rs': 7,
#  'Delloite': 7,
#  'Syeds': 7,
#  'Deliveroo': 7,
#  'LeetCode': 7,
#  '5’6': 7,
#  'binance': 7,
#  'mc²': 7,
#  'mamc': 7,
#  'DITISS': 7,
#  'padmavat': 7,
#  'LPUNEST': 7,
#  'ESP8266': 7,
#  '160R': 7,
#  '^1/3': 7,
#  'DataCamp': 7,
#  'Nagerkovil': 7,
#  'NITian': 7,
#  'Mangalapuram': 7,
#  '100k+': 7,
#  'fitjee': 7,
#  'ucms': 7,
#  'preboards': 7,
#  'y(t': 7,
#  'God(s': 7,
#  '.docx': 6,
#  'Aksener': 6,
#  'JGEC': 6,
#  'GoLang': 6,
#  'AIACTR': 6,
#  'chaturbate': 6,
#  'it’': 6,
#  'LMRC': 6,
#  'AngularJs': 6,
#  'possesiveness': 6,
#  'Trumpian': 6,
#  'suryanamaskar': 6,
#  'Howdid': 6,
#  'f/1.8': 6,
#  'electrovalent': 6,
#  'Garrix': 6,
#  'cryptocurency': 6,
#  'upvoters': 6,
#  'nabard': 6,
#  '5’10': 6,
#  'PyQt5': 6,
#  'b.des': 6,
#  'phycopath': 6,
#  'gpsc': 6,
#  "What's\u200b": 6,
#  'Juicero': 6,
#  "4'9": 6,
#  'f(1': 6,
#  'demonatisation': 6,
#  '√x': 6,
#  '2n+1': 6,
#  '\\geq': 6,
#  'Xapo': 6,
#  '3×3': 6,
#  'Aayog': 6,
#  'intenship': 6,
#  'crytocurrencies': 6,
#  'wbcs': 6,
#  'Wikitribune': 6,
#  'modiji': 6,
#  'kulbhushan': 6,
#  'madheshis': 6,
#  'Rupay': 6,
#  'capf': 6,
#  'Rs.500': 6,
#  'XVG': 6,
#  'MVIT': 6,
#  'srmjeee': 6,
#  'Parmanu': 6,
#  'Caulifla': 6,
#  'JGLS': 6,
#  'x/': 6,
#  'bittrex': 6,
#  'movie(s': 6,
#  '2018/2019': 6,
#  'Thadomal': 6,
#  'god(s': 6,
#  'TRAPPIST-1': 6,
#  '95%+': 6,
#  'IITTM': 6,
#  'AMWF': 6,
#  "did'nt": 6,
#  'DUJAT': 6,
#  '.the': 6,
#  'IITRAM': 6,
#  "I'm\u200b": 6,
#  'someone\u200b': 6,
#  'kingroot': 6,
#  'Su-57': 6,
#  'broglie': 6,
#  'y=0': 6,
#  'adityanath': 6,
#  'Rautela': 6,
#  'toppr': 6,
#  'Freshworks': 6,
#  'JUIT': 6,
#  'cryptocoins': 6,
#  'ximb': 6,
#  '^10': 6,
#  'Puneri': 6,
#  "GATE'18": 6,
#  'XeF6': 6,
#  'y53': 6,
#  'friend(s': 6,
#  'he/': 6,
#  'Snapay': 6,
#  '\\alpha': 6,
#  '6300HQ': 6,
#  '7200U': 6,
#  'keam': 6,
#  'Debotosh': 6,
#  'Scripbox': 6,
#  'Bluemix': 6,
#  'Rojava': 6,
#  'bitconnect': 6,
#  'tifr': 6,
#  'etoos': 6,
#  'bschools': 6,
#  'JD(S': 6,
#  'Cuphead': 6,
#  'Kejariwal': 6,
#  "4'8": 6,
#  'quara': 6,
#  'oversmart': 6,
#  'y^3': 6,
#  'cos2x': 6,
#  'T(n': 6,
#  'etherum': 6,
#  'Mewani': 6,
#  'Mysuru': 6,
#  'mastuburation': 6,
#  'trignometric': 6,
#  'microservice': 6,
#  'P.HD': 6,
#  'K+': 6,
#  'dichlorine': 6,
#  '/she': 6,
#  'cryptocurreny': 6,
#  'diprotic': 6,
#  'Quorians': 6,
#  'infinix': 6,
#  'BIMARU': 6,
#  '6’3': 6,
#  'Oliveboard': 6,
#  'Ōtsutsuki': 6,
#  're-': 6,
#  '.mp3': 6,
#  'antibrahmin': 6,
#  '6’0': 6,
#  'Shifuji': 6,
#  't^2': 6,
#  'golgappa': 6,
#  '1mole': 6,
#  'delhite': 6,
#  'math]f(x': 6,
#  'orthocentre': 6,
#  'Eastwatch': 6,
#  'child(ren': 6,
#  'BA.LLB': 6,
#  'Kahoot': 6,
#  'PayUMoney': 6,
#  'angular2': 6,
#  'fssai': 6,
#  '0.1N': 6,
#  'DC++': 6,
#  'cause(s': 6,
#  'ZenFone': 6,
#  '2lakhs': 6,
#  'TSPSC': 6,
#  'SHAREit': 6,
#  'GOT7': 6,
#  'PUBDET': 6,
#  'crispr': 6,
#  ...}

# %%
token_types(list(unk_common.keys()))
# Out:
# Number of num tokens:  16564
# Number of symbol tokens:  1519
# Number of lowcase tokens:  43548
# Number of upper case tokens:  26679
# Nubmer of capslock tokens:  2531
#
#
# Freq num tokens:  ['x^2', '^2', '1/', 'x^3', "5'4", "A2A'd", 'y^2', "5'9", '^3', "5'5"]
# Rare num tokens:  ['An+1=', 'An=2', 'NBA2K18', '3.71/4.44', '39/389', 'Z2600', '10–12', 'Feb-2018', '2200-$2500/mo', '900va']
#
# Freq symbol tokens:  ['..', '\xa0', ':(', '₹', '"-', 'करना', '\ufeff', '\n', ':/', '️']
# Rare symbol tokens:  ['τῆς', 'κατὰ', 'τὴν', 'ἡμετέραν', 'χρῆσιν', 'συνηθείας', '=--', '中庸', '中庸之道', '∅⊂']
#
# Freq low tokens:  ['cryptocurrencies', 'x^2', 'f(x', 'demonetisation', 'ethereum', 'bhakts', 'w/', 'chsl', 'x^3', 'altcoin']
# Rare low tokens:  ['youvision', 'enrollnment', 'noumber', 'sgill', 'jauhar', 'clearly"bad', 'myAIR', 'ganpat', 'rabels', 'photopicker']
#
# Freq up tokens:  ['Quorans', 'Brexit', 'Redmi', 'OnePlus', 'UCEED', 'Blockchain', 'GDPR', 'Coinbase', 'BNBR', 'Machedo']
# Rare up tokens:  ['Bhangani', 'GS-', 'Magick++', 'NotJesseChen', 'Sakoku', 'Question(JQ', 'Feb-2018', 'Minesotan', 'Tamilar', 'Khayami']
#
# Freq caps tokens:  ['UCEED', 'GDPR', 'BNBR', 'DCEU', 'IIEST', 'LNMIIT', 'NICMAR', 'MUOET', 'SRMJEE', 'SGSITS']
# Rare caps tokens:  ['PYQ', 'OCJA', 'GEORGIVS', 'FEWD', 'SPCOMM', 'SPJIMSR', 'OPENCAPI', 'HYSPM', 'MANAV', 'ICSIL']

# %% [markdown]
# ### Look at spacy tokenizer

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
print(STOP_WORDS)
# Out:
# {'whether', 'must', 'you', 'becomes', 'otherwise', 'here', 'someone', 'on', 'and', 'no', 'out', 'make', 'everything', 'seemed', 'the', 'next', 'as', 'they', 'whereafter', 'whom', 'while', 'such', 'had', 'yourselves', 'four', 'latter', 'last', 'name', 'over', 'after', 'six', 'very', 'his', 'within', 'through', 'around', 'further', 'am', 'sometime', 'toward', 'behind', 'do', 'put', 'various', 'yours', 'five', 'something', 'quite', 'without', 'would', 'are', 'least', 'formerly', 'amount', 'please', 'thus', 'if', 'latterly', 'because', 'via', 'made', 'already', 'until', 'down', 'be', 'himself', 'doing', 'former', 'seeming', 'take', 'namely', 'side', 'what', 'has', 'against', 'herein', 'hers', 'itself', 'she', 'he', 'off', 'them', 'beforehand', 'due', 'my', 'ten', 'those', 'towards', 'sixty', 'i', 'though', 'show', 'own', 'myself', 'unless', 'during', 'hereupon', 'keep', 'somehow', 'were', 'nine', 'twelve', 'still', 'themselves', 'using', 'but', 'ca', 'a', 'again', 'may', 'often', 'full', 'one', 'nor', 'which', 'become', 'to', 'whose', 'first', 'beyond', 'nobody', 'eight', 'however', 'among', 'more', 'everywhere', 'nothing', 'yourself', 'hereby', 'me', 'whereupon', 'whither', 'herself', 'thereafter', 'where', 'or', 'too', 'two', 'alone', 'might', 'all', 'once', 'therefore', 'whereby', 'hereafter', 'up', 'into', 'can', 'along', 'at', 'neither', 'others', 'so', 'throughout', 'everyone', 'most', 'fifty', 'beside', 'together', 'top', 'call', 'three', 'being', 'nowhere', 'ours', 'why', 'nevertheless', 'became', 'whenever', 'yet', 'between', 'anyway', 'since', 'besides', 'other', 'under', 'us', 'mine', 'empty', 'move', 'anything', 'hundred', 'in', 'bottom', 'always', 'whence', 'meanwhile', 'give', 'elsewhere', 'been', 'go', 'from', 'another', 'these', 'could', 'wherein', 'whoever', 'across', 'either', 'serious', 'each', 'part', 'some', 'by', 'every', 'twenty', 'whatever', 'never', 'none', 'of', 'regarding', 'there', 'have', 'say', 'its', 'also', 'except', 'although', 'thence', 'we', 'for', 'few', 'then', 'cannot', 'upon', 'should', 'your', 'per', 'enough', 'perhaps', 'not', 'hence', 'about', 'below', 'see', 'onto', 'this', 'seems', 'almost', 'when', 'above', 'amongst', 'thereupon', 'thru', 'will', 'done', 'it', 'sometimes', 'an', 'than', 'moreover', 'how', 'anyone', 'indeed', 'was', 'both', 'only', 'same', 'afterwards', 'get', 'forty', 're', 'thereby', 'noone', 'else', 'well', 'did', 'ourselves', 'back', 'any', 'several', 'just', 'our', 'rather', 'really', 'used', 'ever', 'that', 'even', 'somewhere', 'who', 'whole', 'with', 'much', 'now', 'therein', 'seem', 'their', 'wherever', 'is', 'does', 'many', 'before', 'front', 'anywhere', 'anyhow', 'him', 'third', 'mostly', 'less', 'her', 'fifteen', 'whereas', 'eleven', 'becoming'}

# %% [markdown]
# ### Emb vectors

# %%
# %%time
# read to dict
embs = {}
with open(emb_path) as f:
    count = 0
    for line in f:
        count += 1
        cut = line.find(' ')
        tok = line[:cut]
        emb = line[cut + 1:].split()
        emb = np.array([float(e) for e in emb])
        #embs[tok] = emb
# Out:
# CPU times: user 3min 38s, sys: 952 ms, total: 3min 39s
# Wall time: 3min 39s

# %%
# %%time
a = np.loadtxt(emb_path, usecols=list(range(2, 300)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/anaconda3/envs/kaggle-kernel/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#    1099         # converting the data
#    1100         X = None
# -> 1101         for x in read_data(_loadtxt_chunksize):
#    1102             if X is None:
#    1103                 X = np.array(x, dtype)
#
# ~/anaconda3/envs/kaggle-kernel/lib/python3.6/site-packages/numpy/lib/npyio.py in read_data(chunk_size)
#    1026
#    1027             # Convert each value according to its column and store
# -> 1028             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1029
#    1030             # Then pack it according to the dtype's nesting
#
# ~/anaconda3/envs/kaggle-kernel/lib/python3.6/site-packages/numpy/lib/npyio.py in <listcomp>(.0)
#    1026
#    1027             # Convert each value according to its column and store
# -> 1028             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1029
#    1030             # Then pack it according to the dtype's nesting
#
# ~/anaconda3/envs/kaggle-kernel/lib/python3.6/site-packages/numpy/lib/npyio.py in floatconv(x)
#     744         if '0x' in x:
#     745             return float.fromhex(x)
# --> 746         return float(x)
#     747
#     748     typ = dtype.type
#
# ValueError: could not convert string to float: '.'

# %%
range(1,200)
# Out:
# range(1, 200)

# %%
# times:
# go through lines: 2.5 s
# tok = : 3 s
# emb = line[cut + 1:].split()   23.5 s
# emb = np.array() :  1 min 56 sec
# total: 2 min

# %%
low = embs['I']
up = embs['you']

# %%
def sim(v1, v2):
    result = sum(v1*v2)/np.linalg.norm(v1)/np.linalg.norm(v2)
    return result

# %%
print(sim(low, up))
# Out:
# 0.6627086554182071

# %%
# read to array
emb_vectors = emb_to_array(emb_path)

# %%
mean = np.mean(emb_vectors, 0)

# %%
np.mean(np.array([abs(e) for e in mean]))
# Out:
# 0.11827651831144917

# %%
np.mean(mean)
# Out:
# -0.005838490668689134

# %%
np.std(mean)
# Out:
# 0.1819384092990661

# %%
np.std(emb_vectors, 0)
# Out:
# array([0.44851531, 0.46038846, 0.44955892, 0.45646961, 0.47140167,
#        0.4422903 , 0.44041244, 0.44698275, 0.4442726 , 0.59969696,
#        0.46547839, 0.44527083, 0.44985766, 0.45156409, 0.44917818,
#        0.44906476, 0.44474889, 0.52384112, 0.45641812, 0.4467048 ,
#        0.44479669, 0.45699833, 0.45092903, 0.44507482, 0.45484755,
#        0.44878899, 0.44448158, 0.43785266, 0.45786598, 0.44926295,
#        0.44259412, 0.45113808, 0.45128958, 0.44436349, 0.45377213,
#        0.44751607, 0.44129199, 0.46179661, 0.43668213, 0.47212486,
#        0.44979053, 0.45925169, 0.44387464, 0.45996361, 0.45231752,
#        0.44722584, 0.46001757, 0.4524131 , 0.44885582, 0.45103552,
#        0.44425859, 0.46027448, 0.44023431, 0.44849907, 0.44747041,
#        0.45154174, 0.44528843, 0.44824609, 0.45852647, 0.45084543,
#        0.44968386, 0.44867101, 0.45057548, 0.48588496, 0.46485229,
#        0.44705304, 0.44496828, 0.4460746 , 0.44262784, 0.46026568,
#        0.46001462, 0.4595112 , 0.46911504, 0.44716035, 0.44971153,
#        0.45100173, 0.44299067, 0.45305022, 0.44535208, 0.45200695,
#        0.44585954, 0.44921488, 0.44291399, 0.44462283, 0.44566354,
#        0.45138856, 0.49343275, 0.48098615, 0.44826175, 0.44104765,
#        0.45174509, 0.45647736, 0.44903077, 0.44331719, 0.44676785,
#        0.44918724, 0.45582819, 0.4562197 , 0.45762246, 0.44485986,
#        0.44394612, 0.44509485, 0.45901302, 0.45267588, 0.44443249,
#        0.62046233, 0.43663946, 0.45424583, 0.4423564 , 0.45594801,
#        0.45451528, 0.44550293, 0.45129472, 0.44524647, 0.46027835,
#        0.45118767, 0.44721149, 0.4495307 , 0.4443674 , 0.45566282,
#        0.45434937, 0.44674522, 0.44938084, 0.43738666, 0.44097567,
#        0.44027789, 0.44261091, 0.45178901, 0.45999922, 0.45225848,
#        0.44599614, 0.44461915, 0.44829422, 0.44640389, 0.4534072 ,
#        0.44117591, 0.44364996, 0.4552937 , 0.43855315, 0.45073377,
#        0.50491126, 0.4495362 , 0.45009603, 0.44271669, 0.44575805,
#        0.44635214, 0.44969577, 0.45332456, 0.46064876, 0.44712967,
#        0.44071361, 0.4426563 , 0.44323724, 0.44845637, 0.45248158,
#        0.44822787, 0.44443037, 0.44366942, 0.4579043 , 0.45504418,
#        0.45648776, 0.45155586, 0.45094678, 0.45403725, 0.44644366,
#        0.46681284, 0.45490809, 0.44125868, 0.47296508, 0.44304339,
#        0.44756109, 0.45183048, 0.45436406, 0.4485879 , 0.45175631,
#        0.45628094, 0.44957885, 0.44552556, 0.45561701, 0.44524398,
#        0.4513565 , 0.44602758, 0.45778941, 0.44894746, 0.46107788,
#        0.44893216, 0.45000188, 0.45760402, 0.44986158, 0.45101902,
#        0.4517361 , 0.45094353, 0.45076698, 0.46105294, 0.44715768,
#        0.46577997, 0.45455927, 0.44566148, 0.45977409, 0.45295679,
#        0.4466633 , 0.44211739, 0.44786914, 0.43777095, 0.45374121,
#        0.44303306, 0.44041806, 0.44448945, 0.43684032, 0.43775181,
#        0.45564189, 0.4590132 , 0.45748978, 0.47468898, 0.44912766,
#        0.44005704, 0.43745587, 0.45691619, 0.45792966, 0.44441866,
#        0.44962557, 0.44748571, 0.45488444, 0.44719825, 0.45440734,
#        0.44699144, 0.45638358, 0.45702147, 0.45148115, 0.45597144,
#        0.44753013, 0.4568319 , 0.456834  , 0.44971774, 0.44750561,
#        0.44783463, 0.44017814, 0.44103779, 0.45692412, 0.44183952,
#        0.44771177, 0.44803973, 0.4488636 , 0.45730729, 0.45542602,
#        0.44858046, 0.45498792, 0.44077795, 0.45458013, 0.44896541,
#        0.45478427, 0.46374604, 0.44824272, 0.45216742, 0.4528457 ,
#        0.44796176, 0.45258725, 0.45275917, 0.44189461, 0.4532034 ,
#        0.44010207, 0.45546398, 0.44889847, 0.44688734, 0.45410915,
#        0.44417451, 0.44780191, 0.4436335 , 0.46508442, 0.44673622,
#        0.46077772, 0.44468042, 0.45145272, 0.47299406, 0.44521408,
#        0.44070951, 0.44523304, 0.47861048, 0.46521058, 0.45802145,
#        0.45839256, 0.46050111, 0.45629536, 0.45034753, 0.45644186,
#        0.44737427, 0.44976079, 0.44846654, 0.45049967, 0.45536017,
#        0.45987951, 0.44369737, 0.44340481, 0.45806152, 0.45967161,
#        0.44439969, 0.44882275, 0.44945856, 0.44534159, 0.44386304])

# %%
np.mean(emb_vectors)
# Out:
# -0.005838490668689374

# %%
np.std(emb_vectors)
# Out:
# 0.48782070623981577

# %%
np.random.normal(0, 0.5)
# Out:
# 0.16967462959684068

# %% [markdown]
# ### t.lower() if t not in emb

# %%
unk_known = []
for t in list(unk_common.keys()):
    if t.lower() in emb_tokens_set:
        unk_known.append(t)
print(len(unk_known))
# Out:
# 2161

# %%
unk_known
# Out:
# ['Blockchain',
#  'Cryptocurrency',
#  'Golang',
#  'Whst',
#  'UPSE',
#  'Fiitjee',
#  'Demonetization',
#  'Howcan',
#  'BHIM',
#  'Swiggy',
#  'GANs',
#  'B.arch',
#  "DON'T",
#  'Jipmer',
#  'IPHO',
#  'Whichis',
#  '9A0',
#  'Chutiya',
#  'WWhat',
#  'BigHit',
#  'MnC',
#  'Cgl',
#  'H2So4',
#  'AADHAR',
#  'Ibps',
#  'BvS',
#  'Whatdo',
#  'Pribumi',
#  'GoLang',
#  'AngularJs',
#  'Rupay',
#  'SHAREit',
#  'LoRa',
#  'Wbjee',
#  'Angularjs',
#  'Whatdoes',
#  'Lpu',
#  'Odias',
#  'UpGrad',
#  'Whuch',
#  'BoJack',
#  'pharmD',
#  'Tnpsc',
#  'ANTHE',
#  'Happn',
#  'Dogsee',
#  'NetLogon',
#  'LLb',
#  'Whatwas',
#  'eBay.in',
#  'MESRA',
#  'Wherecan',
#  'Ncert',
#  'ReLEx',
#  'QUORA',
#  'IARE',
#  'UoT',
#  'DoMS',
#  'Wgat',
#  'A.p',
#  'TenX',
#  'CSe',
#  'H0w',
#  'Wjat',
#  'H2so4',
#  'spaCy',
#  'tanA',
#  'Pagri',
#  'BlockChain',
#  'Acads',
#  'Lnt',
#  'theDifference',
#  'Metzitzah',
#  'ComedK',
#  'Watsapp',
#  'Whh',
#  'PrOPEL',
#  'GitHub.com',
#  'B.ARCH',
#  'Java.lang',
#  'Rrb',
#  'LnT',
#  'HODL',
#  'Cdac',
#  'WhT',
#  'AntiFa',
#  'Epf',
#  'BLACKI',
#  'SHIATS',
#  'BRDS',
#  'Hown',
#  'GloVe',
#  'cosA',
#  'Jeou',
#  'sinA',
#  'PSUS',
#  'AirBnb',
#  'NARCOS',
#  'Uiet',
#  'Severalty',
#  'Sanyasis',
#  'SILCHAR',
#  'Cgpa',
#  'Pgdm',
#  'CliQ',
#  'Glossier',
#  'DeX',
#  'Semrush',
#  'Magnons',
#  'Nmat',
#  'ARMYs',
#  'NaoH',
#  'Awei',
#  'LUMs',
#  'RuPay',
#  'Doea',
#  'MagA',
#  'KiiT',
#  'Wbich',
#  'Bigdata',
#  'WhatIs',
#  'secA',
#  'comedK',
#  'MUNs',
#  'Whowas',
#  'SNAPCHAT',
#  'Apj',
#  'Eurocent',
#  'Wherei',
#  'Iiit',
#  'Superintelligence',
#  'Whichare',
#  'cotA',
#  'Censorious',
#  'Entp',
#  'Codeblocks',
#  'Uchicago',
#  'Kiit',
#  'nEUROn',
#  'OCER',
#  'NITR',
#  'Trippie',
#  'HowI',
#  'Ahref',
#  'Catalyser',
#  'MVvm',
#  'UOFT',
#  'EveryoneDies',
#  'Cheratussin',
#  'FUDI',
#  'DEPR',
#  'IndiaMart',
#  'nCn',
#  'Myapp',
#  'Ifwe',
#  'angularJS',
#  'iFax',
#  'Afmc',
#  'Appalam',
#  'Neurotypicals',
#  'Equestris',
#  'FZs',
#  'Hoors',
#  'mRT',
#  'Givez',
#  'Duckduckgo',
#  'BrF',
#  'Plssss',
#  'M.a',
#  'Bighit',
#  'Vtu',
#  'Elor',
#  'AIIMs',
#  'NAOH',
#  'Calculas',
#  'WhatWhat',
#  'pH.d',
#  'Spokeperson',
#  'shouldI',
#  'CRYPTOCURRENCY',
#  'Togaf',
#  'Iist',
#  'angularJs',
#  'MiiVerse',
#  'Tuberclosis',
#  '22Mag',
#  'Shouls',
#  'VoLte',
#  'fAmily',
#  'EVETS',
#  'LawBreakers',
#  'Voseo',
#  'h1B',
#  'WHey',
#  'Perrona',
#  'SBUF',
#  'JOSSA',
#  'NIt',
#  'sInce',
#  'Ntse',
#  'Jacksfilms',
#  'Barycentre',
#  'Heterotrophs',
#  'pH.D',
#  'Whatwe',
#  'AcAc',
#  'Fzs',
#  'Ho2',
#  'IPho',
#  'RGIA',
#  'UToronto',
#  'Wrost',
#  'CELU',
#  'HumSafar',
#  'boAt',
#  'Sholud',
#  'GMm',
#  'Nism',
#  'sinC',
#  'CoPR',
#  'Dmat',
#  'IANG',
#  'Dooes',
#  'Extratorrent',
#  'B.CA',
#  'Saries',
#  'ARTICLESHIP',
#  '11MIL',
#  'Doess',
#  'Microdosing',
#  'Jnu',
#  'Populator',
#  'Antitheist',
#  'Chó',
#  'WhIch',
#  'Iaf',
#  'Kwid',
#  'Sessons',
#  'GOTRA',
#  'Icai',
#  'Howthe',
#  'Saprophytes',
#  'Tancet',
#  'Burkhas',
#  'MultiThreaded',
#  'IndIan',
#  'Hring',
#  'SAFe',
#  'Memers',
#  'MARATHA',
#  'Whythe',
#  'Marshmello',
#  'PRIST',
#  'Whait',
#  'Shouldi',
#  'CAPGEMINI',
#  'mL.',
#  'Andh',
#  'GoT.',
#  'tanC',
#  'Dlib',
#  'Athlean',
#  'Italki',
#  'Shyp',
#  'CryptoCurrency',
#  'JAAT',
#  'studyIng',
#  'Decribe',
#  'WhI',
#  'LifeHacks',
#  'Whtat',
#  'LIATE',
#  'Yobbos',
#  'Θ',
#  'Gatech',
#  'Megabites',
#  'OMPRAKASH',
#  'BEeF',
#  'HEETS',
#  'Shoukd',
#  'shashanK',
#  'DAf',
#  'NightCore',
#  'Andher',
#  'GOOGEL',
#  'ToastMasters',
#  'ACHEIVEMENTS',
#  'Agressivly',
#  'M3/s',
#  'aVIT',
#  'RITEE',
#  'Whati',
#  'ON8',
#  'Rigts',
#  'IRRESPONSIBILITY',
#  'Squareroot',
#  'Luckyman',
#  'E.i',
#  'ISHANT',
#  'BATSMEN',
#  'MEDICORE',
#  'Aluminide',
#  'Hyperechoic',
#  'hyperV',
#  'famILY',
#  'Convectional',
#  'theGround',
#  'VK.com',
#  'Nascency',
#  'Alguma',
#  'inTN',
#  'ACCEDENT',
#  'BlogPosting',
#  'AIrline',
#  'unGlue',
#  'BTeCh',
#  'CardDav',
#  'Google.co.in',
#  'Gastroc',
#  'PYURIA',
#  'cousIn',
#  'Ehich',
#  'Mqm',
#  'Wwn',
#  'Undir',
#  'eggPlant',
#  'PreCalc',
#  'GASSES',
#  'Actioning',
#  'CURRNT',
#  'AdX',
#  'Delicios',
#  'NACl',
#  'Apsidal',
#  'ROtJ',
#  'Pimavanserin',
#  'Orogenies',
#  'Suxamethonium',
#  'aGricultural',
#  'Cmment',
#  'F.e.a.r',
#  'CouchSurfing.com',
#  'Arythmia',
#  'Loathly',
#  'INSITED',
#  'Gigajoules',
#  'chennaI',
#  'MuhamMAD',
#  'QDoba',
#  'Emtionally',
#  'Electricia',
#  'Andour',
#  'Adelphia.net',
#  'Rhombuses',
#  'gSt',
#  'RIse',
#  'gIrlfriend',
#  'DuckFace',
#  'Ayaa',
#  'NcR',
#  'Importnt',
#  'aCtivated',
#  'EXHISTING',
#  'FANCHISE',
#  'Stackexchange',
#  "CAN'T",
#  'CENSE',
#  'SURABHI',
#  'BOllywood',
#  'Dishonorably',
#  'PiViT',
#  'supremeCourt',
#  'Abody',
#  'diplomA',
#  'NGiNX',
#  'IRRITANTS',
#  'Rhinoplastic',
#  'Hcf',
#  'CBR600rr',
#  'verifIcation',
#  'Dicide',
#  'Dificulties',
#  'PANVEL',
#  'eNTRI',
#  'Azoxystrobin',
#  'Conterparts',
#  'colorI',
#  'TriNessa',
#  'ISHa',
#  'Imgur.com',
#  'Fucntions',
#  'Artifitial',
#  'Likeley',
#  'Pradise',
#  'deletEd',
#  'MACbook',
#  'Euthymia',
#  'Cauterisation',
#  'SAYEED',
#  'Kwt',
#  'WHst',
#  'HowCan',
#  'Conext',
#  'Macbookpro',
#  'OLYMPIADS',
#  'JUCHE',
#  'IphO',
#  'MIcrobiology',
#  'anywY',
#  'Datetime2',
#  'GsT',
#  'TeQ',
#  'SoIt',
#  'ePU',
#  'Al4',
#  'UNWORKABLE',
#  'ITsm',
#  'Persude',
#  'Pellucida',
#  'gRam',
#  'bitCoin',
#  'Scientificly',
#  'DuckDuckgo',
#  'Whoch',
#  'IoTs',
#  'STAPs',
#  'Havw',
#  'TiPi',
#  'oFw',
#  'BLASPHEMING',
#  'Litrature',
#  'Bypolls',
#  'Interatrial',
#  'mDna',
#  'Sperare',
#  'Campanies',
#  'Simc',
#  'NaW',
#  'GatE',
#  'Qouta',
#  'DHARWAD',
#  'MbA',
#  'Yahoo.co.in',
#  'WHai',
#  'Macroadenoma',
#  'DDu',
#  'DOb',
#  'Cannabalism',
#  'Goverenment',
#  'sYstema',
#  'ASKD',
#  'cOconut',
#  'exAG',
#  'MeIR',
#  'TRump',
#  'Bisiness',
#  'Indroduce',
#  'acetylAtion',
#  'CHEGG',
#  'scientifiC',
#  'InstitutE',
#  'EpicFail',
#  'FIIO',
#  'Destining',
#  'APPOITMENT',
#  'Petent',
#  'Eople',
#  'EXAmination',
#  'Formaly',
#  'Leksikon',
#  'HTTRACK',
#  'Marksheets',
#  'INTernet',
#  'AmarNath',
#  'Ppls',
#  'isLess',
#  'GilChrist',
#  'Ftrace',
#  'WEBTOON',
#  'Sayins',
#  'Tgc',
#  'REFRENCES',
#  'Messeger',
#  'Weeaboos',
#  'Doesthe',
#  'wG',
#  'impOrtants',
#  'AbcDEf',
#  'WRite',
#  'Populistic',
#  'GTAsa',
#  'SHEIN',
#  'Π',
#  'St.petersburg',
#  'NANDroid',
#  'inEveryone',
#  'P.h',
#  'StreamIn',
#  'BANARAS',
#  'Deuterons',
#  'uttarAkhand',
#  'gRED',
#  'pRED',
#  'GRETEST',
#  'Idiotism',
#  'PlayStation-3',
#  'UPSc',
#  'Equilbrium',
#  'GOWDA',
#  'Whatr',
#  'booK',
#  'Northmost',
#  'lOving',
#  'ulU',
#  'CANoe',
#  'CHoose',
#  'REFERNECE',
#  'Diring',
#  'LANDLESS',
#  'Necassary',
#  'Isochoric',
#  'Metamorphosing',
#  'INGENERAL',
#  'elImInate',
#  'habIt',
#  'skIppIng',
#  'resultIng',
#  'wIeght',
#  'FATIHAH',
#  'Masturbaiting',
#  'Taqiya',
#  'aCcording',
#  '5NO',
#  'SCorp',
#  'Micigan',
#  'Xfers',
#  'DJinn',
#  'SANJU',
#  'GMe',
#  'Tokenistic',
#  'financiaL',
#  'Whoos',
#  'Aetheists',
#  'Epsiodes',
#  'cHaracteristics',
#  'Ppf',
#  'Inselbergs',
#  'SnapSeed',
#  'Psycopath',
#  'Whichh',
#  'BELEIEVE',
#  'S10E',
#  'IaS',
#  'Geodemographic',
#  'Paleoart',
#  'theIFS',
#  'Awnser',
#  'IndiraNagar',
#  'DynPro',
#  'Neritic',
#  'C1919',
#  'Guestofaguest',
#  'Megajoules',
#  'Clensing',
#  'Candaian',
#  'Ozonolysis',
#  'Hydrosulfide',
#  'Capreomycin',
#  'Ctet',
#  'Discontinous',
#  'GraceNote',
#  'PFile',
#  'PARTIT',
#  'DAENERYS',
#  'AAdhar',
#  'Appsc',
#  'theBiggest',
#  'Ageof',
#  'DUbai',
#  'TUMMO',
#  'IVYs',
#  'OnG',
#  'Varified',
#  'meN',
#  'ABC.txt',
#  'Afyer',
#  'BITCOINS',
#  'kLa',
#  'Vanillic',
#  'RATIONALIZE',
#  'Diethylcarbamazine',
#  'Sin2x',
#  'ADND',
#  'Plzzzzzz',
#  'Mdr1',
#  'WWill',
#  'SIngaporean',
#  'Carbondioxide',
#  'AAre',
#  'mandAte',
#  'AMIEN',
#  'IMMs',
#  'Hadsome',
#  'MudBone',
#  'Pentesters',
#  'AbRam',
#  'Nonmuslims',
#  'VEERE',
#  'Sabachthani',
#  'Reccently',
#  'Prohet',
#  'Increses',
#  'MPHs',
#  'Interpals',
#  'Butanone',
#  'goIng',
#  'questIons',
#  'southAFrica',
#  'Eej',
#  '2Ac',
#  'manY',
#  'Ecomonics',
#  'Sq.cm',
#  'YouKu',
#  'H2o2',
#  'W3schools.com',
#  'CUSO4',
#  'Collaspe',
#  'VSauce',
#  'reMarkable',
#  'Ashtma',
#  'Airmile',
#  'LeadGen',
#  'FETO',
#  'Whathe',
#  'Nbe',
#  'Rignt',
#  'Aouth',
#  'XAVIERS',
#  'Mansplaining',
#  'JinnAh',
#  'REBOILER',
#  'LIIT',
#  'tIps',
#  'UpSC',
#  'NUMERATOR',
#  'Forcely',
#  'Ecomomic',
#  'COURSERA',
#  'GfT',
#  'rAjkot',
#  'gAve',
#  'ENGINNERS',
#  'Coxibs',
#  'TVseries',
#  'Multidimentional',
#  'Microwatts',
#  'Neckbeards',
#  'girLs',
#  'BlackSmithing',
#  'Lookism',
#  'Zaroor',
#  'LISK',
#  'aFRICA',
#  'Nahia',
#  'Biharmonic',
#  'Methology',
#  'BRAHMANS',
#  'Hepatis',
#  'graduateS',
#  'BE.I',
#  'DIploma',
#  'beIng',
#  'weIrd',
#  'Exaxtly',
#  'LEEE',
#  'COMMY',
#  'STinson',
#  'hHow',
#  'BOmbay',
#  'WATU',
#  'CUDS',
#  'NGinX',
#  'NeoNazis',
#  'CURCUMIN',
#  'NutJob',
#  'FORB',
#  'Mansae',
#  'Ifly',
#  'pOC',
#  'Trompos',
#  'Khanacademy',
#  'AnB',
#  'AuB',
#  'cORP',
#  'noSql',
#  'VIXY',
#  'Nameof',
#  'Idp',
#  '2MbPS',
#  'Revaluating',
#  'AZlyrics',
#  'Blackberrying',
#  'ChaI',
#  'goING',
#  'RIYAZ',
#  'Degreee',
#  'UNreal',
#  'RealMe',
#  'Divident',
#  'Textnow',
#  'Textplus',
#  'KHURANA',
#  'Diahrea',
#  'farmING',
#  'NICd',
#  'HyperThyroidism',
#  'NepalI',
#  'Indea',
#  'Indains',
#  'VOIN',
#  'SUPARI',
#  'Ultrarealistic',
#  'MlS',
#  'GofT',
#  'giRL',
#  'Ammature',
#  'ACCOUSTICS',
#  'GATEs',
#  'INDUSTRIALISATION',
#  'Allophones',
#  'Mpsc',
#  'Whola',
#  'Cetyltrimethylammonium',
#  'MaKE',
#  'RunBook',
#  'Xuv',
#  'KASHMIRIS',
#  'PLEBISCITE',
#  'PAKISTHAN',
#  'Commination',
#  'Adrianisen',
#  'melodY',
#  'HindI',
#  'Defferent',
#  'Havr',
#  'Postgraduation',
#  'Cuboidal',
#  'hWhy',
#  'ISl',
#  'isMy',
#  'Biperiden',
#  'iFEEL',
#  'Niclosamide',
#  'Teşekkür',
#  'ASSuME',
#  'Industrialize',
#  'x86_64-Linux',
#  'Infrastruture',
#  'FoxVideo',
#  'Barotropic',
#  'IBr',
#  'Hypertextuality',
#  'BHIWANDI',
#  '2005D',
#  'POkemon',
#  'squAre',
#  'posSible',
#  'rId',
#  'Howthey',
#  'Vigourously',
#  'BraceFace',
#  'iMportant',
#  'antePenultimate',
#  'Allha',
#  'Falled',
#  'Unascertained',
#  'Exectly',
#  'CEtuximab',
#  'Hapoo',
#  'Tradeing',
#  'useS',
#  'Judgeing',
#  'Rarly',
#  'Libral',
#  'LineDrive',
#  'Ebat',
#  'Foursquare.com',
#  'Ambivert',
#  'Helpppp',
#  'VIDYAPEETH',
#  'DESTRUCTIONS',
#  'Korganizer',
#  'Trimellitic',
#  'HOMINIDS',
#  'Unfreedom',
#  'MoBike',
#  'Gmos',
#  'Adaptibility',
#  'Yhat',
#  'Togain',
#  'PPPoe',
#  'APUd',
#  'AREAR',
#  '07TH',
#  'KVa',
#  'Likelyhood',
#  'MACBookPro',
#  'LightinTheBox',
#  'Carbonitride',
#  'Jealth',
#  'UCo',
#  'Pangram',
#  'MANAPHY',
#  'Itsm',
#  'Icwa',
#  'Mbb',
#  'DIOT',
#  'IBATIS',
#  'BIochemistry',
#  'VAPORIZE',
#  'Prepartions',
#  'Psycholgy',
#  'modeLLing',
#  'Shakhas',
#  'Bereavements',
#  'europE',
#  'Guyys',
#  'RocketMail',
#  'Injested',
#  'Dcfs',
#  'Everyweek',
#  'MyCroft',
#  'toDeal',
#  'ISi',
#  'unOrdinary',
#  'igG',
#  '6Tb',
#  'DoesA',
#  '500/Yr',
#  'IBanking',
#  'Chorioretinopathy',
#  'FIVERR.COM',
#  'Inute',
#  'Eligious',
#  'FaaS',
#  'Mansplain',
#  'Tautomerism',
#  'NINCOMPOOPS',
#  'H2sO4',
#  'EyeBeam',
#  'Intercaste',
#  'MEUM',
#  'SUAM',
#  'ABORTIVE',
#  '2-Socket',
#  'BackSlash',
#  '90KM',
#  'DImensions',
#  'Cosidering',
#  "L'Artista",
#  'DEMONETIZATION',
#  'Cyberspies',
#  'Crpf',
#  'Majoritarianism',
#  'MUNS',
#  'Airflight',
#  'Nworks',
#  'ECRIS',
#  'Ialah',
#  'theMain',
#  'UkIp',
#  'Sugest',
#  'Cả',
#  'Cũng',
#  'ClF',
#  'Kynurenic',
#  'XNK',
#  'Uptu',
#  'Iys',
#  'isVery',
#  'libRary',
#  'doctoR',
#  'souRce',
#  'doughNUTS',
#  '64MG',
#  'Wolframalpha',
#  'Protobuf',
#  'Tysm',
#  'HashTags',
#  'Shittah',
#  '3PM-9PM',
#  '7Plus',
#  'MInority',
#  'Resuts',
#  'MBoX',
#  'WhEre',
#  'libGDX',
#  'MarcoS',
#  'onCE',
#  'Autotroph',
#  'Thenumber',
#  'passworD',
#  'Panipuri',
#  'Dhotis',
#  'GRUs',
#  'AWPer',
#  'sTudy',
#  'Viperine',
#  'tAke',
#  'Csgo',
#  'JOng',
#  'JoSSA',
#  'Dmrc',
#  'Mythically',
#  'Ʃ',
#  'VEnice',
#  '2aX',
#  'Sympathiser',
#  'Slained',
#  'POLITICANS',
#  'EWhat',
#  'Efrons',
#  'Borh',
#  'FIREBUG',
#  'LASIC',
#  'POSsible',
#  'X/10',
#  'Tropane',
#  'SUggest',
#  'PekWM',
#  'AAfter',
#  'Wheni',
#  'Dactylic',
#  'Hoiw',
#  'DERMOID',
#  'Asthenopia',
#  'MahaVishnu',
#  'MiUi',
#  'ChennAI',
#  'Freefrom',
#  'TrumPETS',
#  'Bagat',
#  'Priminister',
#  'HARPING',
#  'Carbocation',
#  'INDesign',
#  'downloadTest',
#  'drInk',
#  'cIder',
#  'vInagar',
#  'fVCKing',
#  'BeD',
#  'PostColonial',
#  'CHALLAN',
#  'UberCart',
#  'lPE',
#  'Sepcific',
#  'Informatiom',
#  'BIGINNER',
#  'KASAB',
#  'GOENKA',
#  'AhmadiNejad',
#  'GUYs',
#  'Betn',
#  'Specificaly',
#  'Whice',
#  'Remainer',
#  'Quinol',
#  'VEllore',
#  'yD',
#  'SPass',
#  'Smetimes',
#  'PartS',
#  'Whcich',
#  'EDx',
#  'TAnzania',
#  'Diid',
#  'Erope',
#  'ZUZ',
#  'Wheb',
#  'COUNTRy',
#  'Tebuconazole',
#  'DElhi',
#  'toChange',
#  'TWhat',
#  'AwS',
#  'DIFFERNCE',
#  'OFSted',
#  'eMPH',
#  'EMacs',
#  'Bycicles',
#  'beTween',
#  '2MBPS',
#  'metaL',
#  'Classmark',
#  'NOKO',
#  'dIstinction',
#  'Scholors',
#  'peopLe',
#  ...]
