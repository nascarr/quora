# %% [markdown]
# # EDA google news embedding and Spacy tokenizer

# %%
import os
import re
import pandas as pd
import spacy
from collections import Counter

# %%
def token_info(tokens):
    print('Number of tokens: ', len(tokens))
    print('First 10 tokens: ', tokens[:10])

# %%
def token_types(tokens):
    num_tokens = []
    symbol_tokens = []
    low_tokens = []
    up_tokens = []
    caps_tokens = []
    num_re = re.compile('[0-9]')
    low_re = re.compile('[a-z]')
    up_re = re.compile('[A-Z]')
    caps_re = re.compile('^[A-Z]*$')
    letnum_re = re.compile('[a-zA-Z0-9]')
    for t in tokens:
        if num_re.search(t):
            num_tokens.append(t)
        if not letnum_re.search(t):
            symbol_tokens.append(t)
        if low_re.match(t):
            low_tokens.append(t)
        if up_re.match(t):
            up_tokens.append(t)
        if caps_re.match(t):
            caps_tokens.append(t)
    print('Number of num tokens: ', len(num_tokens))
    print('Number of symbol tokens: ', len(symbol_tokens))
    print('Number of lowcase tokens: ' , len(low_tokens))
    print('Number of upper case tokens: ', len(up_tokens))
    print('Nubmer of capslock tokens: ' , len(caps_tokens))
    
    print('\n')
    
    print('Freq num tokens: ', num_tokens[:10])
    print('Rare num tokens: ', num_tokens[-10:], '\n')
    print('Freq symbol tokens: ', symbol_tokens[:10])
    print('Rare symbol tokens: ', symbol_tokens[-10:], '\n')
    print('Freq low tokens: ', low_tokens[:10])
    print('Rare low tokens: ', low_tokens[-10:], '\n')
    print('Freq up tokens: ', up_tokens[:10])
    print('Rare up tokens: ', up_tokens[-10:], '\n')
    print('Freq caps tokens: ', caps_tokens[:10])
    print('Rare caps tokens: ', caps_tokens[-10:])

# %% [markdown]
# ### Look at embedding

# %%
emb_path = 'embeddings/paragram_300_sl999/paragram_300_sl999.txt'
data_dir = cache = '../data'

train_csv = os.path.join(data_dir, 'train.csv')
test_csv = os.path.join(data_dir, 'test.csv')
emb_path = os.path.join(data_dir, emb_path)

# %%
# %%time
emb_tokens = []
errors = 0
with open(emb_path, 'rb') as f:
    for line in f:
        try:
            tok = line.rstrip().split(b" ")[0]
            tok = tok.decode('utf-8')
            emb_tokens.append(tok)
        except: 
            errors += 1
            continue
print(errors)
# Out:
# 4
# CPU times: user 17.3 s, sys: 1.63 s, total: 18.9 s
# Wall time: 24.9 s

# %%
token_info(emb_tokens)
# Out:
# Number of tokens:  1703752
# First 10 tokens:  [',', '.', 'the', 'and', 'to', 'of', 'a', 'in', '"', ':']

# %%
token_types(emb_tokens)
# Out:
# Number of num tokens:  510038
# Number of symbol tokens:  2518
# Number of lowcase tokens:  1265160
# Number of upper case tokens:  1
# Nubmer of capslock tokens:  1
#
#
# Freq num tokens:  ['1', '2', '3', '4', '2012', '5', '2011', '10', '2010', '2009']
# Rare num tokens:  ['crowdog89', 'data0053', 'doc2doc', 'i686.pet', 'km/11', 'mono-2', 'otherjuicystar07', 'own36', 'p263', 'sarah123']
#
# Freq symbol tokens:  [',', '.', '"', ':', ')', '(', '-', '...', '!', '?']
# Rare symbol tokens:  ['?!?!?!?!!', '?!?!?!?!?!?!?!?!?', 'ãƒˆã', 'ａ', '-------------------------------------------------------------------------------------------------------------------------------------------------', 'ɯ', 'вЂ', '回', 'ĵ', 'ÐÐ']
#
# Freq low tokens:  ['the', 'and', 'to', 'of', 'a', 'in', 'is', 'for', 'i', 'that']
# Rare low tokens:  ['windowstransgender', 'wordsforyoungmen', 'work.like', 'working.so', 'wried', 'wwent', 'xalisae', 'xtremecaffeine', 'zipout', 'zulchzulu']
#
# Freq up tokens:  ['UUUNKKK']
# Rare up tokens:  ['UUUNKKK']
#
# Freq caps tokens:  ['UUUNKKK']
# Rare caps tokens:  ['UUUNKKK']

# %% [markdown]
# ### Tokenize data and build vocab

# %%
train = pd.read_csv(train_csv)['question_text'].values.tolist()
test = pd.read_csv(test_csv)['question_text'].values.tolist()
data = train + test

# %%
# %%time
unknown_tokens = []
vocab = Counter()
spacy_en = spacy.load('en')
tokenizer = spacy_en.tokenizer
emb_tokens_set = set(emb_tokens)
for question in data:
    doc = tokenizer(question)
    for token in doc:
        tok_text = token.text
        vocab.update([tok_text])
        if vocab[tok_text] == 1:
            if tok_text not in emb_tokens_set:
                unknown_tokens.append(tok_text)
        
#doc = nlp(u'Apple is looking at buying U.K. startup for $1 billion')
#for token in doc:
#    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
#          token.shape_, token.is_alpha, token.is_stop)
# Out:
# CPU times: user 2min 30s, sys: 98.3 ms, total: 2min 30s
# Wall time: 2min 28s

# %%
vocab_tokens = dict(vocab.most_common()).keys()

# %%
token_types(vocab_tokens)
# Out:
# Number of num tokens:  29530
# Number of symbol tokens:  1727
# Number of lowcase tokens:  132699
# Number of upper case tokens:  113484
# Nubmer of capslock tokens:  15169
#
#
# Freq num tokens:  ['2', '2017', '2018', '1', '3', '10', '5', '4', '12', '6']
# Rare num tokens:  ['10–12', '61850', 'Feb-2018', '2200-$2500/mo', '4000/mo', '999999', '450cc', '78.53', '900va', '6740']
#
# Freq symbol tokens:  ['?', ',', '.', '"', '-', ')', '(', '/', "'", '&']
# Rare symbol tokens:  ['τῆς', 'κατὰ', 'τὴν', 'ἡμετέραν', 'χρῆσιν', 'συνηθείας', '=--', '中庸', '中庸之道', '∅⊂']
#
# Freq low tokens:  ['the', 'to', 'a', 'in', 'is', 'of', 'and', 'do', 'are', 'for']
# Rare low tokens:  ['noumber', 'sml', 'sgill', 'jauhar', 'clearly"bad', 'myAIR', 'cybershot', 'ganpat', 'rabels', 'photopicker']
#
# Freq up tokens:  ['What', 'I', 'How', 'Why', 'Is', 'Can', 'Which', 'Do', 'If', 'India']
# Rare up tokens:  ['Dime', 'Entanglements', 'Tamilar', 'Flurry', 'Routines', 'ULTIMATELY', 'Hb', 'Generate', 'Khayami', 'Thetis']
#
# Freq caps tokens:  ['I', 'US', 'USA', 'A', 'JEE', 'TV', 'UK', 'IIT', 'MBA', 'IT']
# Rare caps tokens:  ['IPOS', 'MANAV', 'ICSIL', 'RCZ', 'PPW', 'AOTS', 'THEORETICAL', 'FRAMEWORK', 'EPAM', 'ULTIMATELY']

# %% [markdown]
# ### Capslock tokens

# %%
caps_re = re.compile('^[A-Z]*$')
caps_tokens = []
for t in vocab_tokens:
    if caps_re.match(t):
        caps_tokens.append(t)

# %%
emotional_caps_tokens = []
for t in caps_tokens:
    if t not in emb_tokens_set and t.lower() in emb_tokens_set:
        emotional_caps_tokens.append(t)
print(len(emotional_caps_tokens))
# Out:
# 13152

# %%
emotional_caps_tokens
# Out:
# ['I',
#  'US',
#  'USA',
#  'A',
#  'JEE',
#  'TV',
#  'UK',
#  'IIT',
#  'MBA',
#  'IT',
#  'CSE',
#  'UPSC',
#  'MS',
#  'IQ',
#  'CBSE',
#  'CA',
#  'NEET',
#  'C',
#  'CS',
#  'NIT',
#  'BJP',
#  'MBBS',
#  'PC',
#  'IAS',
#  'SSC',
#  'B',
#  'AI',
#  'GST',
#  'GATE',
#  'EU',
#  'DC',
#  'ECE',
#  'X',
#  'CAT',
#  'AIIMS',
#  'DNA',
#  'VIT',
#  'MIT',
#  'IIM',
#  'SBI',
#  'CGL',
#  'SEO',
#  'PG',
#  'SAT',
#  'GPA',
#  'G',
#  'OBC',
#  'BITS',
#  'BA',
#  'PM',
#  'K',
#  'SC',
#  'AC',
#  'II',
#  'ISIS',
#  'BBA',
#  'GRE',
#  'HR',
#  'D',
#  'ICSE',
#  'PO',
#  'PR',
#  'SAP',
#  'SRM',
#  'AP',
#  'PHP',
#  'TCS',
#  'NDA',
#  'WWII',
#  'R',
#  'FBI',
#  'OS',
#  'HTML',
#  'PDF',
#  'NASA',
#  'IIIT',
#  'BITSAT',
#  'CEO',
#  'CGPA',
#  'IELTS',
#  'CET',
#  'IP',
#  'IPL',
#  'M',
#  'NBA',
#  'NYC',
#  'E',
#  'UN',
#  'API',
#  'RBI',
#  'DU',
#  'UAE',
#  'NCERT',
#  'PCM',
#  'T',
#  'HIV',
#  'OK',
#  'SSB',
#  'NFL',
#  'AWS',
#  'HP',
#  'MCU',
#  'IS',
#  'MA',
#  'USB',
#  'ISRO',
#  'GB',
#  'SQL',
#  'CLAT',
#  'ADHD',
#  'BCA',
#  'ID',
#  'GDP',
#  'PSU',
#  'ISC',
#  'IPS',
#  'FIFA',
#  'IBPS',
#  'V',
#  'S',
#  'BPD',
#  'BHU',
#  'NIFT',
#  'INR',
#  'IB',
#  'IES',
#  'UP',
#  'UG',
#  'UX',
#  'LGBT',
#  'RSS',
#  'CSS',
#  'COMEDK',
#  'CPU',
#  'KVPY',
#  'USD',
#  'UI',
#  'IISER',
#  'LLB',
#  'MCA',
#  'BTS',
#  'BE',
#  'IPCC',
#  'N',
#  'IBM',
#  'CFA',
#  'CIA',
#  'IGNOU',
#  'OCD',
#  'GTA',
#  'DTU',
#  'CNN',
#  'BDS',
#  'UC',
#  'EEE',
#  'NCR',
#  'ATM',
#  'VPN',
#  'AIR',
#  'MNC',
#  'L',
#  'WWE',
#  'BS',
#  'NRA',
#  'NATO',
#  'GMAT',
#  'GOP',
#  'F',
#  'USSR',
#  'O',
#  'MD',
#  'HD',
#  'NPD',
#  'KIIT',
#  'NY',
#  'GPS',
#  'P',
#  'CV',
#  'VR',
#  'RAM',
#  'PCB',
#  'EE',
#  'PTSD',
#  'PGDM',
#  'NET',
#  'LED',
#  'SMS',
#  'ICO',
#  'SD',
#  'IRS',
#  'LG',
#  'IFS',
#  'WBJEE',
#  'MP',
#  'ACT',
#  'NRI',
#  'CM',
#  'ISS',
#  'Z',
#  'LLC',
#  'CPT',
#  'ML',
#  'Y',
#  'IPU',
#  'ESE',
#  'FB',
#  'DSLR',
#  'KCET',
#  'HSC',
#  'H',
#  'MATLAB',
#  'DVD',
#  'BMW',
#  'ST',
#  'LA',
#  'ACCA',
#  'TOEFL',
#  'ISI',
#  'NGO',
#  'AAP',
#  'JNU',
#  'TX',
#  'POTUS',
#  'U',
#  'W',
#  'STEM',
#  'UGC',
#  'NOT',
#  'NIOS',
#  'ME',
#  'FL',
#  'VITEEE',
#  'Q',
#  'OR',
#  'TN',
#  'BC',
#  'FIITJEE',
#  'III',
#  'INTJ',
#  'IPO',
#  'IOCL',
#  'VLSI',
#  'BPO',
#  'ERP',
#  'CRM',
#  'CPA',
#  'GPU',
#  'VC',
#  'INTP',
#  'ABC',
#  'ONGC',
#  'EC',
#  'BBC',
#  'NMIMS',
#  'CD',
#  'AND',
#  'INFJ',
#  'CT',
#  'NTSE',
#  'ICICI',
#  'IHM',
#  'RC',
#  'SIM',
#  'AMD',
#  'RRB',
#  'NATA',
#  'WWI',
#  'HDFC',
#  'UPES',
#  'BSNL',
#  'LSD',
#  'SA',
#  'MBTI',
#  'TO',
#  'SAS',
#  'SIP',
#  'PA',
#  'JAM',
#  'J',
#  'AIDS',
#  'FC',
#  'SS',
#  'GTX',
#  'UCLA',
#  'VA',
#  'IV',
#  'DJ',
#  'BMS',
#  'BHK',
#  'SSD',
#  'SO',
#  'NSIT',
#  'MLB',
#  'CPEC',
#  'AFMC',
#  'BAMS',
#  'TISS',
#  'MMA',
#  'EMI',
#  'HCL',
#  'URL',
#  'AR',
#  'SE',
#  'CCNA',
#  'CTC',
#  'CE',
#  'EAMCET',
#  'AB',
#  'NC',
#  'GS',
#  'AFCAT',
#  'OET',
#  'CDAC',
#  'LGBTQ',
#  'LIC',
#  'MIS',
#  'DIY',
#  'NUS',
#  'TB',
#  'ISP',
#  'IRA',
#  'AM',
#  'NID',
#  'PF',
#  'CBI',
#  'DRDO',
#  'ICT',
#  'JFK',
#  'MU',
#  'PLC',
#  'NSE',
#  'BTC',
#  'QA',
#  'NHL',
#  'ISB',
#  'DNC',
#  'MRI',
#  'SSN',
#  'INFP',
#  'NJ',
#  'NLP',
#  'USMLE',
#  'CAD',
#  'ETH',
#  'COEP',
#  'FMS',
#  'CDS',
#  'JS',
#  'BSC',
#  'KTM',
#  'IBS',
#  'UPSEE',
#  'NLU',
#  'DACA',
#  'ADD',
#  'IPM',
#  'BIT',
#  'USPS',
#  'PU',
#  'SF',
#  'XRP',
#  'IC',
#  'XII',
#  'LCD',
#  'IGCSE',
#  'WHY',
#  'CMA',
#  'IRCTC',
#  'PES',
#  'KKK',
#  'LPU',
#  'CAN',
#  'VAT',
#  'NCC',
#  'GA',
#  'YOU',
#  'XAT',
#  'NYU',
#  'RNA',
#  'ROI',
#  'UT',
#  'BSE',
#  'MLA',
#  'USC',
#  'PAN',
#  'STD',
#  'PI',
#  'CBD',
#  'AMCAT',
#  'TU',
#  'UPS',
#  'CSIR',
#  'CCTV',
#  'GET',
#  'GD',
#  'UPTU',
#  'SJW',
#  'ASD',
#  'TDS',
#  'GT',
#  'BARC',
#  'IMU',
#  'TS',
#  'IDE',
#  'ISO',
#  'CMS',
#  'RV',
#  'IF',
#  'NCL',
#  'ODI',
#  'PPC',
#  'QR',
#  'SX',
#  'XI',
#  'CNC',
#  'UV',
#  'MH',
#  'LTE',
#  'HDMI',
#  'IITJEE',
#  'FM',
#  'SP',
#  'BDSM',
#  'PEC',
#  'JP',
#  'RAW',
#  'MI',
#  'ROM',
#  'KFC',
#  'AS',
#  'ALL',
#  'VP',
#  'IIST',
#  'IISC',
#  'ICC',
#  'RVCE',
#  'LPG',
#  'JRF',
#  'SI',
#  'HTC',
#  'OPT',
#  'CC',
#  'IAF',
#  'AD',
#  'MUN',
#  'RS',
#  'UFC',
#  'NO',
#  'VFX',
#  'PSG',
#  'ETF',
#  'EVM',
#  'IIFT',
#  'HDD',
#  'NHS',
#  'HS',
#  'NSA',
#  'VMC',
#  'MHT',
#  'CCP',
#  'PMP',
#  'XLRI',
#  'VJTI',
#  'PCOS',
#  'SUV',
#  'GUI',
#  'VTU',
#  'EDM',
#  'JE',
#  'TED',
#  'MLM',
#  'GE',
#  'DM',
#  'POS',
#  'DOJ',
#  'ACA',
#  'NMAT',
#  'JIPMER',
#  'PHD',
#  'NZ',
#  'AAA',
#  'AA',
#  'IDF',
#  'IITB',
#  'ICE',
#  'DBA',
#  'MSRIT',
#  'CMU',
#  'DNS',
#  'UFO',
#  'CTMU',
#  'RCC',
#  'IMEI',
#  'PPF',
#  'JIIT',
#  'USS',
#  'GK',
#  'MPC',
#  'ATP',
#  'MNNIT',
#  'MVP',
#  'LLM',
#  'BI',
#  'CGI',
#  'IMS',
#  'RMO',
#  'GCSE',
#  'BMI',
#  'FPS',
#  'XP',
#  'OMR',
#  'NTPC',
#  'CMAT',
#  'ASPD',
#  'XL',
#  'PS',
#  'GIS',
#  'IMO',
#  'VS',
#  'OTA',
#  'HL',
#  'PE',
#  'DBMS',
#  'PGP',
#  'ED',
#  'EM',
#  'PRC',
#  'WA',
#  'RTI',
#  'NTU',
#  'NOC',
#  'JSON',
#  'CO',
#  'MTS',
#  'IOT',
#  'DLP',
#  'MSC',
#  'SDE',
#  'MAINS',
#  'OP',
#  'ICAI',
#  'MPH',
#  'PTE',
#  'IUPAC',
#  'EOS',
#  'BP',
#  'RPM',
#  'NITK',
#  'GM',
#  'VISA',
#  'MB',
#  'AT',
#  'GED',
#  'NISER',
#  'ASOIAF',
#  'EY',
#  'HBO',
#  'UCL',
#  'GITAM',
#  'CTO',
#  'DUI',
#  'FRM',
#  'EA',
#  'ACL',
#  'HRM',
#  'CMC',
#  'ABS',
#  'CBS',
#  'FCC',
#  'NPTEL',
#  'USAF',
#  'ASEAN',
#  'GO',
#  'FDA',
#  'MVC',
#  'ICBM',
#  'VI',
#  'CNG',
#  'AZ',
#  'RPG',
#  'GGSIPU',
#  'ACM',
#  'ENTP',
#  'KPMG',
#  'VBA',
#  'AMC',
#  'OH',
#  'LDS',
#  'DPS',
#  'LPA',
#  'MPSC',
#  'FMCG',
#  'UEFA',
#  'DID',
#  'ENFP',
#  'ON',
#  'ISM',
#  'CTS',
#  'SNAP',
#  'CMI',
#  'EMP',
#  'SET',
#  'HC',
#  'RPA',
#  'IMT',
#  'CRS',
#  'BB',
#  'MAT',
#  'CPC',
#  'DOB',
#  'APK',
#  'JMI',
#  'ER',
#  'PLA',
#  'ABAP',
#  'NBC',
#  'USCIS',
#  'PVC',
#  'FBA',
#  'CATIA',
#  'HVAC',
#  'FIR',
#  'IOTA',
#  'MTV',
#  'VIP',
#  'MY',
#  'MOOC',
#  'MMS',
#  'KGP',
#  'FDR',
#  'SOP',
#  'MDS',
#  'AMU',
#  'BLM',
#  'GSM',
#  'SWAT',
#  'GF',
#  'UIUC',
#  'NK',
#  'WHO',
#  'IEEE',
#  'IMA',
#  'RTO',
#  'MF',
#  'DMV',
#  'DB',
#  'JD',
#  'JU',
#  'USMC',
#  'IET',
#  'RCB',
#  'LAN',
#  'EAD',
#  'SL',
#  'HQ',
#  'JBL',
#  'MCQ',
#  'HANA',
#  'KYC',
#  'UAN',
#  'HPCL',
#  'THC',
#  'GDS',
#  'PV',
#  'RF',
#  'DL',
#  'PWD',
#  'UCSD',
#  'DA',
#  'HK',
#  'KMC',
#  'MT',
#  'CUSAT',
#  'TSA',
#  'CU',
#  'ATC',
#  'SCOTUS',
#  'EQ',
#  'UR',
#  'BCCI',
#  'NDTV',
#  'VNIT',
#  'NT',
#  'SM',
#  'GOT',
#  'WES',
#  'CSK',
#  'PUBG',
#  'NITIE',
#  'CPL',
#  'IL',
#  'EXO',
#  'ISE',
#  'DPRK',
#  'SEC',
#  'IR',
#  'DSP',
#  'OC',
#  'CCE',
#  'AIQ',
#  'OOP',
#  'DAC',
#  'FD',
#  'EPF',
#  'ITA',
#  'JK',
#  'SIBM',
#  'TA',
#  'IA',
#  'CERN',
#  'PNB',
#  'PET',
#  'LCM',
#  'PSAT',
#  'AICTE',
#  'CVV',
#  'JSS',
#  'PCMB',
#  'ESL',
#  'MAC',
#  'GP',
#  'SDK',
#  'BIM',
#  'CVT',
#  'SRCC',
#  'CPI',
#  'LSE',
#  'UPI',
#  'TIME',
#  'KKR',
#  'BBQ',
#  'CHSL',
#  'GMO',
#  'NEO',
#  'JAT',
#  'UNSC',
#  'DTH',
#  'ITC',
#  'PCS',
#  'RE',
#  'FROM',
#  'OTG',
#  'BMM',
#  'ASAP',
#  'CRISPR',
#  'MAIT',
#  'DMT',
#  'ICWA',
#  'MAMC',
#  'FX',
#  'IE',
#  'OTP',
#  'NFC',
#  'FYROM',
#  'LASIK',
#  'CFO',
#  'AE',
#  'RFID',
#  'MM',
#  'WWIII',
#  'TSH',
#  'PETA',
#  'DD',
#  'ASL',
#  'TIFR',
#  'MRP',
#  'SCADA',
#  'RD',
#  'BF',
#  'PMS',
#  'FDI',
#  'IPC',
#  'XPS',
#  'MCAT',
#  'ITR',
#  'IG',
#  'MNIT',
#  'ESPN',
#  'VIII',
#  'FPGA',
#  'CW',
#  'XML',
#  'VM',
#  'LSAT',
#  'PT',
#  'JNTU',
#  'MSNBC',
#  'RO',
#  'EPL',
#  'DNB',
#  'NEST',
#  'PIN',
#  'CSC',
#  'SASTRA',
#  'CB',
#  'WW',
#  'DO',
#  'ELSS',
#  'CPM',
#  'JYP',
#  'ISKCON',
#  'NP',
#  'CBT',
#  'ILP',
#  'PD',
#  'ZTE',
#  'SAE',
#  'CFD',
#  'LTTE',
#  'ECA',
#  'ETL',
#  'LDR',
#  'WB',
#  'GCC',
#  'WE',
#  'NPAT',
#  'ONLY',
#  'AL',
#  'ACE',
#  'MSW',
#  'PKK',
#  'SEAL',
#  'TUM',
#  'SLS',
#  'PNP',
#  'DP',
#  'UBC',
#  'ALS',
#  'CSR',
#  'IVF',
#  'RBC',
#  'VPS',
#  'AIT',
#  'ROTC',
#  'IMF',
#  'GBS',
#  'JVM',
#  'ASUS',
#  'MSI',
#  'NVIDIA',
#  'VW',
#  'PDPU',
#  'LLP',
#  'IIMA',
#  'JSP',
#  'WTO',
#  'MAIN',
#  'RAS',
#  'TCP',
#  'SEM',
#  'KGB',
#  'REST',
#  'DASA',
#  'IEM',
#  'GMC',
#  'CDC',
#  'FA',
#  'TVS',
#  'INC',
#  'DI',
#  'NCAA',
#  'AIPMT',
#  'BCG',
#  'UNESCO',
#  'HDI',
#  'SEBI',
#  'STP',
#  'YMCA',
#  'RAF',
#  'OJ',
#  'ISL',
#  'ARM',
#  'CBIT',
#  'VGA',
#  'OBOR',
#  'ASO',
#  'THAT',
#  'HAVE',
#  'TMC',
#  'YOUR',
#  'RAC',
#  'PL',
#  'JBIMS',
#  'GC',
#  'EPA',
#  'IPE',
#  'HRT',
#  'SRK',
#  'IM',
#  'NAFTA',
#  'MC',
#  'NABARD',
#  'IMAX',
#  'VII',
#  'NS',
#  'DHL',
#  'USI',
#  'NASCAR',
#  'MOS',
#  'AG',
#  'AGI',
#  'PNG',
#  'XIMB',
#  'MSM',
#  'MBB',
#  'SVM',
#  'RMS',
#  'UPA',
#  'ICPC',
#  'PESIT',
#  'PBUH',
#  'JIO',
#  'DBS',
#  'IITK',
#  'LTC',
#  'AMIE',
#  'MIM',
#  'HPV',
#  'FICO',
#  'SME',
#  'FZ',
#  'UW',
#  'HTTP',
#  'NA',
#  'LSTM',
#  'HAL',
#  'SPA',
#  'SLR',
#  'UNIX',
#  'AAO',
#  'HRC',
#  'SB',
#  'MSIT',
#  'WI',
#  'BPCL',
#  'CMOS',
#  'KL',
#  'ANY',
#  'THEY',
#  'MEAN',
#  'ASU',
#  'TATA',
#  'NPS',
#  'SSI',
#  'AOL',
#  'HSBC',
#  'NSW',
#  'RA',
#  'PUC',
#  'CDSE',
#  'DOS',
#  'RERA',
#  'MEA',
#  'LOTR',
#  'ECG',
#  'COD',
#  'AF',
#  'MMORPG',
#  'SSE',
#  'HMS',
#  'ICAR',
#  'DMRC',
#  'SPSS',
#  'LMS',
#  'ATV',
#  'WAT',
#  'ET',
#  'SJCE',
#  'WILL',
#  'BEL',
#  'EUR',
#  'SNU',
#  'DLF',
#  'AED',
#  'YPG',
#  'LR',
#  'WHICH',
#  'LAPD',
#  'ETC',
#  'BJJ',
#  'UIET',
#  'TD',
#  'UTI',
#  'DJI',
#  'SNL',
#  'OCR',
#  'AUD',
#  'POC',
#  'IKEA',
#  'TEFL',
#  'PSC',
#  'DOES',
#  'HIIT',
#  'CAP',
#  'TVF',
#  'HRA',
#  'FTP',
#  'APJ',
#  'EPS',
#  'KTR',
#  ...]

# %% [markdown]
# ### Unknown tokens

# %%
unk_vocab = {}
for w in unknown_tokens:
    unk_vocab[w] = vocab[w]
unk_vocab = Counter(unk_vocab)

# %%
print('Total number of tokens: ', sum(vocab.values()))
print('Number of unique tokens: ', len(vocab))
print('Total number of unknown tokens: ', sum(unk_vocab.values()))
print('Number of unique unknown tokens: ', len(unknown_tokens))
print('Percent of unknown tokens: ', 100 * sum(unk_vocab.values())/sum(vocab.values()))
# Out:
# Total number of tokens:  19837964
# Number of unique tokens:  268601
# Total number of unknown tokens:  3354250
# Number of unique unknown tokens:  165972
# Percent of unknown tokens:  16.90823715578877

# %%
unk_common = dict(unk_vocab.most_common())
print('Number of 100 most common unk tokens: ', sum(list(unk_common.values())[:100]))
# Out:
# Number of 100 most common unk tokens:  2100848

# %%
unk_common
# Out:
# {'What': 452309,
#  'I': 344086,
#  'How': 274523,
#  'Why': 151622,
#  'Is': 115278,
#  'Can': 55112,
#  'Which': 49416,
#  'Do': 42778,
#  'If': 36135,
#  'India': 34181,
#  'Are': 30882,
#  'Does': 24583,
#  'Who': 23507,
#  'Where': 20267,
#  'Should': 17794,
#  'Quora': 16573,
#  'Will': 15335,
#  'When': 15253,
#  'Trump': 14824,
#  'Indian': 14231,
#  'US': 13251,
#  'The': 11015,
#  'Would': 10740,
#  'In': 10644,
#  'My': 8627,
#  'China': 8356,
#  'English': 8069,
#  'Did': 8028,
#  'American': 7952,
#  'Have': 7571,
#  'Chinese': 6614,
#  'America': 6571,
#  'Has': 6121,
#  'USA': 5917,
#  'Google': 5883,
#  'A': 5697,
#  'Americans': 5620,
#  'University': 5617,
#  'Canada': 5510,
#  'Muslims': 5373,
#  'Facebook': 5190,
#  'JEE': 5153,
#  'TV': 4887,
#  'As': 4865,
#  'Could': 4789,
#  'United': 4679,
#  'Was': 4648,
#  'Indians': 4613,
#  'UK': 4455,
#  'God': 4353,
#  'Pakistan': 4307,
#  'It': 4287,
#  'Delhi': 4245,
#  'Muslim': 4212,
#  'IIT': 4164,
#  'North': 4017,
#  'States': 3943,
#  'Android': 3855,
#  'Donald': 3831,
#  'MBA': 3810,
#  'New': 3765,
#  'And': 3693,
#  'YouTube': 3675,
#  'South': 3576,
#  'Russia': 3542,
#  'Europe': 3413,
#  'Germany': 3403,
#  'British': 3278,
#  'Korea': 3212,
#  'IT': 3210,
#  'Australia': 3080,
#  'Bangalore': 3019,
#  'Mumbai': 2969,
#  'President': 2953,
#  'Japanese': 2875,
#  'Amazon': 2756,
#  'iPhone': 2738,
#  'Israel': 2738,
#  'CSE': 2701,
#  'Islam': 2686,
#  'Modi': 2675,
#  'Japan': 2642,
#  'Instagram': 2604,
#  'For': 2603,
#  'War': 2553,
#  'Earth': 2536,
#  'Jews': 2522,
#  'U.S.': 2419,
#  'European': 2396,
#  'Obama': 2379,
#  'French': 2279,
#  'UPSC': 2256,
#  'PhD': 2252,
#  'He': 2242,
#  'World': 2215,
#  'Java': 2208,
#  'German': 2194,
#  'Russian': 2147,
#  'Apple': 2146,
#  'Hindi': 2130,
#  'Mains': 2127,
#  'Africa': 2105,
#  'Or': 2104,
#  'Am': 2086,
#  'Hyderabad': 2080,
#  'We': 2074,
#  'MS': 2048,
#  'Christians': 2039,
#  'Christian': 2015,
#  'Pune': 2001,
#  'IQ': 2000,
#  'CBSE': 1984,
#  'Asian': 1961,
#  'CA': 1956,
#  'NEET': 1945,
#  'C': 1912,
#  'African': 1909,
#  'After': 1877,
#  'CS': 1866,
#  'Hindu': 1861,
#  'You': 1858,
#  'California': 1771,
#  'Singapore': 1742,
#  'Jesus': 1731,
#  'NIT': 1710,
#  'BJP': 1708,
#  'Tamil': 1695,
#  'Hitler': 1683,
#  'Chennai': 1679,
#  'Engineering': 1673,
#  'Hindus': 1629,
#  'West': 1615,
#  'MBBS': 1614,
#  'John': 1600,
#  'PC': 1599,
#  'Science': 1577,
#  'WhatsApp': 1564,
#  'IAS': 1553,
#  'SSC': 1546,
#  'Korean': 1538,
#  'France': 1532,
#  'B': 1527,
#  'Democrats': 1526,
#  'There': 1523,
#  'Bible': 1521,
#  'Harry': 1520,
#  'East': 1520,
#  'With': 1497,
#  'Iran': 1492,
#  'At': 1489,
#  'To': 1489,
#  'They': 1485,
#  'Star': 1477,
#  'York': 1435,
#  'Windows': 1422,
#  'AI': 1418,
#  'College': 1413,
#  'London': 1397,
#  'Any': 1389,
#  'Spanish': 1384,
#  'GST': 1382,
#  'Jewish': 1381,
#  'Western': 1333,
#  'She': 1322,
#  'Canadian': 1320,
#  'So': 1315,
#  'Were': 1312,
#  'This': 1307,
#  'From': 1302,
#  'GATE': 1301,
#  'Black': 1299,
#  'England': 1285,
#  'Hillary': 1285,
#  'EU': 1281,
#  'White': 1279,
#  'Since': 1250,
#  'One': 1244,
#  'State': 1222,
#  'Clinton': 1217,
#  'Kolkata': 1216,
#  'Microsoft': 1212,
#  'School': 1209,
#  'But': 1198,
#  'Dubai': 1195,
#  'DC': 1194,
#  'ECE': 1194,
#  'Asia': 1173,
#  'X': 1161,
#  'Mexico': 1161,
#  'On': 1137,
#  'Lord': 1131,
#  'Twitter': 1122,
#  'Turkey': 1112,
#  'Computer': 1111,
#  'Samsung': 1108,
#  'Wars': 1108,
#  'iOS': 1105,
#  'Now': 1101,
#  'Britain': 1098,
#  'CAT': 1096,
#  'San': 1095,
#  'AIIMS': 1068,
#  'DNA': 1067,
#  'Indonesia': 1058,
#  'Pakistani': 1053,
#  'VIT': 1043,
#  'Vietnam': 1042,
#  'WW2': 1040,
#  'Christianity': 1038,
#  'Europeans': 1037,
#  'MIT': 1037,
#  'Bitcoin': 1035,
#  'City': 1026,
#  'Islamic': 1012,
#  'IIM': 1008,
#  'Linux': 1005,
#  'Uber': 1003,
#  'Karnataka': 998,
#  'Republicans': 996,
#  'Bollywood': 995,
#  'Saudi': 994,
#  'Potter': 993,
#  'Middle': 990,
#  'National': 986,
#  'Gandhi': 982,
#  'SBI': 982,
#  'Italy': 980,
#  'Greek': 980,
#  'James': 970,
#  'Malaysia': 970,
#  'Philippines': 964,
#  'CGL': 947,
#  'Kerala': 943,
#  'Mars': 940,
#  'King': 920,
#  'Nigeria': 918,
#  'Kashmir': 917,
#  'Python': 915,
#  'Marvel': 914,
#  'Texas': 908,
#  'Michael': 905,
#  'Syria': 903,
#  'Spain': 898,
#  'Roman': 895,
#  'SEO': 894,
#  'Hollywood': 893,
#  '..': 888,
#  'Quorans': 882,
#  'Great': 879,
#  'Nepal': 878,
#  'People': 877,
#  'Turkish': 874,
#  'PG': 871,
#  'SAT': 870,
#  'GPA': 861,
#  'House': 860,
#  'Army': 858,
#  'G': 854,
#  'OBC': 850,
#  'Snapchat': 848,
#  'Bangladesh': 847,
#  'BITS': 847,
#  'BA': 845,
#  'Putin': 843,
#  'PM': 842,
#  'Union': 841,
#  'Please': 839,
#  'Australian': 836,
#  'K': 831,
#  'League': 822,
#  'Management': 814,
#  'Congress': 809,
#  'Bank': 808,
#  'George': 807,
#  '3D': 805,
#  'SC': 802,
#  'Arabia': 802,
#  'Empire': 801,
#  'AC': 801,
#  'International': 800,
#  'Civil': 798,
#  'Ireland': 795,
#  'Russians': 794,
#  'Arab': 785,
#  'All': 783,
#  'Business': 783,
#  'Manipal': 779,
#  'Party': 779,
#  'Jio': 777,
#  'Harvard': 776,
#  'Big': 775,
#  'WordPress': 774,
#  'Asians': 774,
#  'Nazi': 773,
#  'Italian': 770,
#  'Institute': 769,
#  'Bill': 769,
#  'Kim': 766,
#  'Christmas': 765,
#  'Florida': 762,
#  'Also': 755,
#  'II': 754,
#  'Christ': 754,
#  'Galaxy': 753,
#  'C++': 750,
#  'ISIS': 749,
#  'BBA': 747,
#  'Zealand': 746,
#  'May': 745,
#  'Arabic': 741,
#  'Robert': 733,
#  'Naruto': 728,
#  'Paul': 728,
#  'Data': 725,
#  'GRE': 720,
#  'No': 718,
#  'Batman': 717,
#  'HR': 713,
#  'Sweden': 713,
#  'D': 705,
#  'Air': 705,
#  'Pradesh': 701,
#  'Republican': 700,
#  'Man': 696,
#  'Maharashtra': 696,
#  'Hinduism': 694,
#  'Greece': 693,
#  'Soviet': 690,
#  'ICSE': 690,
#  'Valley': 690,
#  'Tesla': 689,
#  'Physics': 684,
#  'David': 681,
#  'PO': 680,
#  'PR': 678,
#  'SAP': 674,
#  'Mac': 672,
#  'SRM': 668,
#  'Netflix': 667,
#  'Egypt': 666,
#  'Khan': 662,
#  'AP': 661,
#  'PHP': 658,
#  'Israeli': 658,
#  'Quran': 656,
#  'TCS': 655,
#  'Day': 652,
#  'Technology': 651,
#  'Brazil': 651,
#  'Arabs': 649,
#  'Nadu': 648,
#  'Noida': 645,
#  'Latin': 642,
#  'Sri': 642,
#  'Given': 637,
#  'NDA': 636,
#  'Bengal': 636,
#  'Washington': 635,
#  'Disney': 632,
#  'WWII': 629,
#  'Game': 629,
#  'Germans': 627,
#  'R': 624,
#  'General': 621,
#  'Gmail': 619,
#  'Palestinians': 614,
#  'Narendra': 613,
#  'Kong': 605,
#  'Elon': 604,
#  'Republic': 598,
#  'Gurgaon': 596,
#  'Internet': 595,
#  'FBI': 594,
#  'Francisco': 594,
#  'OS': 593,
#  'Like': 593,
#  'HTML': 591,
#  'PDF': 589,
#  'Musk': 588,
#  'Eastern': 588,
#  'LinkedIn': 583,
#  'Paris': 582,
#  'NASA': 582,
#  'Pakistanis': 581,
#  'IIIT': 580,
#  'Queen': 580,
#  'BITSAT': 578,
#  'CEO': 577,
#  'CGPA': 576,
#  'IELTS': 573,
#  'Muhammad': 573,
#  'CET': 569,
#  'Hong': 567,
#  'IP': 565,
#  'Superman': 563,
#  'Pro': 562,
#  'Singh': 561,
#  'Jaipur': 561,
#  'Act': 559,
#  'Gujarat': 556,
#  'Service': 551,
#  'William': 549,
#  'Some': 549,
#  'IPL': 549,
#  'M': 549,
#  'Stanford': 547,
#  'JavaScript': 546,
#  'Advanced': 545,
#  'Even': 545,
#  'Allen': 544,
#  'June': 544,
#  'Master': 544,
#  'Goa': 543,
#  'Masters': 540,
#  'Africans': 540,
#  'Catholic': 539,
#  'Thailand': 537,
#  'Vietnamese': 537,
#  'Law': 537,
#  'NBA': 535,
#  'Mangalore': 533,
#  'Mexican': 532,
#  'NYC': 531,
#  'Not': 530,
#  'Prime': 530,
#  'Chicago': 526,
#  'High': 526,
#  'Navy': 522,
#  'Government': 522,
#  'Iraq': 521,
#  'Nazis': 521,
#  'E': 521,
#  'Mark': 521,
#  'UN': 520,
#  'IITs': 519,
#  'API': 516,
#  'RBI': 514,
#  'DU': 514,
#  'Force': 512,
#  'Of': 512,
#  'MSc': 510,
#  'Brexit': 510,
#  'UAE': 508,
#  'cryptocurrencies': 506,
#  'Toronto': 502,
#  'Irish': 502,
#  'Jackson': 500,
#  'NCERT': 500,
#  'Chandigarh': 498,
#  'Infosys': 498,
#  'Poland': 498,
#  'Steve': 497,
#  'Indonesian': 494,
#  'Stephen': 494,
#  'Just': 493,
#  'According': 493,
#  'Central': 492,
#  'PCM': 490,
#  'Cup': 490,
#  'Rahul': 489,
#  'April': 488,
#  'T': 487,
#  'Turks': 486,
#  'Einstein': 485,
#  'HIV': 485,
#  'Red': 484,
#  'Taiwan': 484,
#  'OK': 480,
#  'Allah': 480,
#  'Super': 479,
#  'Prince': 478,
#  'B.Tech': 478,
#  'Dr.': 476,
#  'Afghanistan': 475,
#  'Los': 473,
#  'SSB': 470,
#  'Pokemon': 469,
#  'Being': 469,
#  'NFL': 468,
#  'AWS': 468,
#  'Thomas': 467,
#  'HP': 466,
#  'Democratic': 466,
#  'Charles': 465,
#  'First': 464,
#  'Jong': 464,
#  'Native': 463,
#  'MCU': 463,
#  'IS': 463,
#  'MA': 462,
#  'Bay': 462,
#  'Gordon': 460,
#  'USB': 458,
#  'Palestine': 452,
#  'ISRO': 450,
#  'Switzerland': 449,
#  'GB': 449,
#  'SQL': 448,
#  'Life': 448,
#  'Peter': 447,
#  'Miller': 447,
#  'An': 446,
#  'December': 446,
#  'CLAT': 446,
#  'Netherlands': 445,
#  'Rome': 445,
#  'MacBook': 443,
#  'Mr.': 442,
#  'Dutch': 441,
#  'Men': 440,
#  'ADHD': 440,
#  'BCA': 440,
#  'ID': 439,
#  'iPad': 439,
#  'U.S': 438,
#  'Northern': 438,
#  'Punjab': 436,
#  'Richard': 435,
#  'Angeles': 434,
#  'Rs': 434,
#  'Minister': 434,
#  'Kingdom': 430,
#  'Chrome': 430,
#  'Greeks': 430,
#  'Adam': 429,
#  'Park': 428,
#  'Court': 426,
#  'GDP': 426,
#  'Model': 424,
#  'Koreans': 423,
#  'Learning': 422,
#  'Ukraine': 421,
#  'Thrones': 420,
#  'Lee': 418,
#  'July': 417,
#  'By': 417,
#  'Tom': 416,
#  'Avengers': 415,
#  'Telugu': 414,
#  'Al': 414,
#  'BSc': 414,
#  'Most': 412,
#  'Oracle': 412,
#  'Smith': 411,
#  'Sun': 410,
#  'Vellore': 410,
#  'Bengali': 410,
#  'Explain': 410,
#  'Mueller': 410,
#  'PSU': 406,
#  'Pilani': 406,
#  'Security': 403,
#  'ISC': 402,
#  'IPS': 402,
#  'Krishna': 402,
#  'Medical': 402,
#  'PayPal': 402,
#  'Green': 401,
#  'That': 401,
#  'Moon': 401,
#  'Royal': 400,
#  'FIFA': 400,
#  'IBPS': 400,
#  'Jordan': 400,
#  'Canadians': 399,
#  'V': 398,
#  'Battle': 398,
#  'S': 397,
#  'Company': 396,
#  'Academy': 395,
#  'BPD': 395,
#  'Redmi': 394,
#  'Bihar': 394,
#  'Sir': 394,
#  'Wikipedia': 393,
#  'While': 393,
#  'Vegas': 392,
#  'Sony': 392,
#  'Norway': 392,
#  'Elizabeth': 391,
#  'Judaism': 391,
#  'Universe': 391,
#  'Tech': 391,
#  'Mary': 390,
#  'Goku': 390,
#  'Justice': 389,
#  'BHU': 388,
#  'Martin': 387,
#  'Kota': 386,
#  'Church': 386,
#  'Silicon': 384,
#  'Jon': 384,
#  'Stalin': 383,
#  'Tinder': 383,
#  'Social': 383,
#  'Jerusalem': 382,
#  'Swift': 381,
#  'Women': 381,
#  'March': 381,
#  'Boston': 381,
#  'NIFT': 380,
#  'Sanskrit': 380,
#  'INR': 379,
#  'Fox': 377,
#  'IB': 377,
#  'Machine': 377,
#  'IES': 376,
#  'Real': 376,
#  'Your': 376,
#  'eBay': 375,
#  'Last': 375,
#  'Barack': 373,
#  'UP': 373,
#  'Supreme': 373,
#  'UG': 373,
#  'UX': 373,
#  'Ahmedabad': 372,
#  'News': 371,
#  'Iranian': 371,
#  'LGBT': 371,
#  'Ca': 370,
#  'Georgia': 370,
#  'RSS': 369,
#  'Me': 368,
#  'Southern': 368,
#  'CSS': 368,
#  'During': 368,
#  'Mathematics': 367,
#  'Columbia': 367,
#  'Flipkart': 366,
#  'Services': 366,
#  'Revolution': 365,
#  'Canon': 364,
#  'COMEDK': 363,
#  'Other': 363,
#  'Considering': 363,
#  'Dell': 362,
#  'CPU': 362,
#  'Lucknow': 361,
#  'KVPY': 361,
#  'Indore': 361,
#  'USD': 361,
#  'Jedi': 361,
#  'UI': 361,
#  'Portuguese': 359,
#  'Constitution': 355,
#  'Persian': 353,
#  'IISER': 353,
#  'Accenture': 353,
#  'Thanos': 352,
#  'Power': 351,
#  'Infinity': 351,
#  'Paytm': 350,
#  'Death': 349,
#  'Intel': 349,
#  'Buddhism': 348,
#  'Finance': 348,
#  'Many': 348,
#  'LLB': 346,
#  'Democrat': 345,
#  'MCA': 345,
#  'BTS': 345,
#  'System': 345,
#  'History': 343,
#  'Global': 342,
#  'Jack': 342,
#  'St.': 342,
#  'Syrian': 342,
#  'Thor': 340,
#  'Dragon': 339,
#  'Hi': 339,
#  'Under': 339,
#  'BE': 339,
#  'Then': 338,
#  'IPCC': 337,
#  'N': 337,
#  'Shiva': 336,
#  'Alexander': 336,
#  'Ali': 335,
#  'Joseph': 335,
#  'Blue': 334,
#  'IBM': 333,
#  'Palestinian': 333,
#  'Ben': 333,
#  'Top': 332,
#  'Bengaluru': 332,
#  'CFA': 331,
#  'Darth': 331,
#  'Justin': 330,
#  'Captain': 330,
#  'Ancient': 330,
#  'Lanka': 329,
#  'August': 329,
#  'Someone': 328,
#  'Amendment': 328,
#  'PS4': 328,
#  'Cambridge': 327,
#  'Ivy': 327,
#  'Brahmins': 327,
#  'Scotland': 326,
#  'M.Tech': 326,
#  'CIA': 325,
#  'IGNOU': 325,
#  'Doctor': 324,
#  'Swedish': 323,
#  'Development': 323,
#  'Love': 323,
#  'OCD': 323,
#  'Saturn': 323,
#  'Jew': 323,
#  'Adobe': 322,
#  'Holocaust': 322,
#  'Quoran': 322,
#  'Jones': 322,
#  'Amity': 322,
#  'Space': 321,
#  'January': 321,
#  'Un': 320,
#  'Bombay': 320,
#  'GTA': 320,
#  'Mandarin': 319,
#  'Visa': 318,
#  'DTU': 318,
#  'Honda': 317,
#  'Barcelona': 317,
#  'Kannada': 315,
#  'Iron': 315,
#  'Portugal': 314,
#  'Bhopal': 313,
#  'Time': 313,
#  'Excel': 313,
#  'Liberals': 312,
#  'Information': 312,
#  'Area': 312,
#  'CNN': 312,
#  'September': 311,
#  'Henry': 311,
#  'Because': 311,
#  'Sikhs': 311,
#  'Indonesians': 310,
#  'Mike': 310,
#  'Las': 310,
#  'BDS': 310,
#  'Airtel': 310,
#  'Education': 310,
#  'UC': 310,
#  'Israelis': 310,
#  'EEE': 309,
#  'Human': 309,
#  'Analytics': 309,
#  'Two': 309,
#  'NCR': 309,
#  'ATM': 309,
#  'Newton': 308,
#  'Luke': 308,
#  'Test': 307,
#  'Punjabi': 306,
#  'Group': 306,
#  'Island': 305,
#  'VPN': 305,
#  'Sydney': 304,
#  'Lenovo': 303,
#  'Sanders': 303,
#  'AIR': 302,
#  'Rajasthan': 302,
#  'Oxford': 302,
#  'MNC': 301,
#  'L': 301,
#  'Let': 300,
#  'Pacific': 300,
#  'App': 300,
#  'WWE': 299,
#  'Electrical': 299,
#  'H1B': 299,
#  'Santa': 299,
#  'Center': 299,
#  'Digital': 299,
#  'Berlin': 299,
#  'BS': 299,
#  'NRA': 298,
#  'Chris': 298,
#  'November': 298,
#  'Chemistry': 297,
#  'NATO': 296,
#  'Taylor': 296,
#  'Xbox': 296,
#  'Inc.': 296,
#  'Ball': 295,
#  'GMAT': 295,
#  'Halloween': 294,
#  'GOP': 294,
#  'Manchester': 293,
#  'Denmark': 292,
#  'Note': 291,
#  'F': 291,
#  'Andhra': 291,
#  'Street': 291,
#  'Iranians': 290,
#  'B.': 289,
#  'Kumar': 289,
#  'Patna': 288,
#  'F1': 288,
#  'Yahoo': 288,
#  'Ubuntu': 287,
#  'Puerto': 287,
#  'Argentina': 287,
#  'Hawaii': 286,
#  'Media': 286,
#  'Jupiter': 284,
#  'Malaysian': 284,
#  'Melbourne': 283,
#  'Seattle': 283,
#  'Shopify': 283,
#  'Kashmiri': 283,
#  'Book': 281,
#  'USSR': 281,
#  'Filipino': 281,
#  'Anyone': 280,
#  'Office': 279,
#  'O': 278,
#  'Michigan': 278,
#  'Qatar': 278,
#  'MD': 277,
#  'Catholics': 277,
#  'Ford': 277,
#  'Ronaldo': 276,
#  'Brown': 275,
#  'Project': 275,
#  'WiFi': 275,
#  'Mexicans': 275,
#  'HD': 274,
#  'Kindle': 274,
#  'NPD': 274,
#  'St': 274,
#  'Program': 274,
#  'Age': 274,
#  'Australians': 273,
#  'KIIT': 273,
#  'NY': 273,
#  'Web': 273,
#  'Xi': 272,
#  'Dark': 271,
#  'Kenya': 271,
#  'Besides': 271,
#  'Trek': 271,
#  'Madrid': 271,
#  'Ram': 271,
#  'Bush': 270,
#  'J.': 270,
#  'Walmart': 270,
#  'Mobile': 270,
#  'Satan': 270,
#  'Harvey': 269,
#  'Photoshop': 269,
#  'GPS': 269,
#  'Every': 268,
#  'Coimbatore': 268,
#  'Italians': 268,
#  'P': 268,
#  'Home': 268,
#  'Berkeley': 267,
#  'CV': 267,
#  'Nations': 267,
#  'B2B': 267,
#  'Give': 267,
#  'Messi': 267,
#  'Online': 266,
#  'Jimmy': 266,
#  'Starbucks': 265,
#  'Kejriwal': 264,
#  'Old': 264,
#  'Moto': 264,
#  'Urdu': 264,
#  'Design': 264,
#  'VR': 264,
#  'Nokia': 263,
#  'WW1': 263,
#  'Adolf': 263,
#  'Out': 263,
#  'Jain': 263,
#  'Stark': 263,
#  'Assuming': 262,
#  'Plus': 261,
#  'Johnson': 261,
#  'Minecraft': 261,
#  'Good': 261,
#  'Nagpur': 261,
#  'Marathi': 261,
#  'Ayurveda': 261,
#  'Lewis': 260,
#  'Thai': 260,
#  'Flash': 260,
#  'Hadoop': 259,
#  'Joe': 259,
#  'Maths': 259,
#  'Zuckerberg': 259,
#  'Research': 259,
#  'Austria': 258,
#  'Sherlock': 258,
#  'RAM': 258,
#  'Egyptian': 257,
#  'Balaji': 257,
#  'Vader': 257,
#  'Venus': 257,
#  'Tamils': 256,
#  'Bang': 255,
#  'Ethereum': 255,
#  'His': 254,
#  'PCB': 254,
#  'Series': 253,
#  'EE': 253,
#  'Math': 253,
#  'Intelligence': 253,
#  'PTSD': 252,
#  'Hulk': 252,
#  'Miami': 251,
#  'Hebrew': 251,
#  'IIMs': 251,
#  'Uttar': 251,
#  'PGDM': 251,
#  'Wall': 250,
#  'Tony': 250,
#  'Ontario': 249,
#  'Golden': 249,
#  'Network': 249,
#  'NET': 249,
#  'Finland': 248,
#  'Class': 248,
#  'Voldemort': 248,
#  'LED': 248,
#  'Brazilian': 248,
#  'Department': 248,
#  'SMS': 248,
#  'Edition': 248,
#  'Houston': 247,
#  'Family': 247,
#  'Buddhist': 247,
#  'Arizona': 247,
#  'Kanpur': 247,
#  'ICO': 246,
#  'Christopher': 246,
#  'Bernie': 245,
#  'Shall': 245,
#  'Nehru': 244,
#  'Assam': 244,
#  'Health': 244,
#  'Tokyo': 243,
#  'SD': 243,
#  'Show': 243,
#  'IRS': 243,
#  'Theory': 242,
#  'Express': 242,
#  'Carolina': 242,
#  'LG': 241,
#  'IFS': 241,
#  'Venezuela': 241,
#  'Sometimes': 241,
#  'Shakespeare': 240,
#  'Go': 240,
#  'Vishnu': 240,
#  'Nikon': 240,
#  'Nobel': 240,
#  'Thapar': 240,
#  'WBJEE': 239,
#  'Hawking': 239,
#  'Gates': 239,
#  'Ola': 239,
#  'Sea': 239,
#  'MP': 238,
#  'Times': 238,
#  'Grand': 238,
#  'Manager': 238,
#  'Find': 238,
#  'ACT': 238,
#  'Olympics': 238,
#  'Second': 238,
#  'NRI': 237,
#  'Trudeau': 237,
#  'October': 237,
#  'Fire': 237,
#  'Tata': 237,
#  'Spotify': 237,
#  'Frank': 236,
#  'Romans': 235,
#  'Marine': 235,
#  'Name': 235,
#  'Non': 235,
#  'Sharma': 235,
#  'Deloitte': 235,
#  'Sunday': 235,
#  'SaaS': 235,
#  'iTunes': 234,
#  'Shah': 234,
#  'Ohio': 234,
#  'Jeff': 234,
#  'Without': 233,
#  'Banglore': 233,
#  'CM': 233,
#  'Allahabad': 233,
#  'Word': 232,
#  ...}

# %%
token_types(list(unk_common.keys()))
# Out:
# Number of num tokens:  19491
# Number of symbol tokens:  1518
# Number of lowcase tokens:  39402
# Number of upper case tokens:  113484
# Nubmer of capslock tokens:  15169
#
#
# Freq num tokens:  ['WW2', '3D', 'PS4', 'H1B', 'F1', 'B2B', 'WW1', 'CO2', 'x^2', '2D']
# Rare num tokens:  ['An=2', 'NBA2K18', '3.71/4.44', '39/389', 'GD1', 'N4200', 'Z2600', '10–12', 'Feb-2018', '2200-$2500/mo']
#
# Freq symbol tokens:  ['..', ':(', '₹', '"-', 'करना', '\ufeff', '\n', ':/', '️', '\\\\']
# Rare symbol tokens:  ['τῆς', 'κατὰ', 'τὴν', 'ἡμετέραν', 'χρῆσιν', 'συνηθείας', '=--', '中庸', '中庸之道', '∅⊂']
#
# Freq low tokens:  ['iPhone', 'iOS', 'cryptocurrencies', 'iPad', 'eBay', 'iTunes', 'pH', 'x^2', 'f(x', 'iPhones']
# Rare low tokens:  ['heritor', 'proportionals', 'youvision', 'enrollnment', 'noumber', 'sgill', 'clearly"bad', 'myAIR', 'rabels', 'photopicker']
#
# Freq up tokens:  ['What', 'I', 'How', 'Why', 'Is', 'Can', 'Which', 'Do', 'If', 'India']
# Rare up tokens:  ['Dime', 'Entanglements', 'Tamilar', 'Flurry', 'Routines', 'ULTIMATELY', 'Hb', 'Generate', 'Khayami', 'Thetis']
#
# Freq caps tokens:  ['I', 'US', 'USA', 'A', 'JEE', 'TV', 'UK', 'IIT', 'MBA', 'IT']
# Rare caps tokens:  ['IPOS', 'MANAV', 'ICSIL', 'RCZ', 'PPW', 'AOTS', 'THEORETICAL', 'FRAMEWORK', 'EPAM', 'ULTIMATELY']

# %% [markdown]
# ### Look at spacy tokenizer

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
print(STOP_WORDS)
# Out:
# {'around', 'every', 'hereafter', 'no', 'across', 'rather', 'side', 'their', 'enough', 'anything', 'via', 'whereupon', 'nevertheless', 'anywhere', 'name', 'using', 'everyone', 'six', 'along', 'former', 'afterwards', 'below', 'to', 'others', 'well', 'wherever', 'at', 'nor', 'above', 'beside', 'eight', 'quite', 'toward', 'onto', 'another', 'latter', 'by', 'third', 'put', 'whoever', 'used', 'through', 'but', 'against', 'who', 'off', 'most', 'someone', 'his', 'together', 'yours', 'seeming', 'did', 'eleven', 'that', 'from', 'alone', 'too', 'whereby', 'as', 'each', 'next', 'other', 'any', 'everything', 'towards', 'few', 'until', 'before', 'front', 'get', 'some', 'within', 'him', 'out', 'less', 'then', 'almost', 'doing', 'has', 'herein', 'hereupon', 'elsewhere', 're', 'serious', 'this', 'hereby', 'in', 'very', 'three', 'give', 'several', 'there', 'else', 'hers', 'neither', 'down', 'hundred', 'between', 'made', 'nothing', 'never', 'seem', 'thereby', 'your', 'keep', 'seemed', 'same', 'after', 'into', 'even', 'more', 'not', 'though', 'ever', 'us', 'although', 'often', 'for', 'where', 'however', 'regarding', 'thru', 'forty', 'fifty', 'make', 'somehow', 'when', 'first', 'which', 'why', 'am', 'cannot', 'everywhere', 'meanwhile', 'is', 'how', 'are', 'moreover', 'full', 'part', 'will', 'back', 'with', 'behind', 'himself', 'except', 'her', 'done', 'have', 'please', 'you', 'five', 'it', 'just', 'whence', 'my', 'all', 'indeed', 'its', 'nobody', 'such', 'what', 'various', 'sometime', 'than', 'itself', 'throughout', 'thereupon', 'since', 'anyway', 'among', 'latterly', 'whole', 'beforehand', 'four', 'he', 'here', 'two', 'whatever', 'anyone', 'once', 'also', 'thence', 'twenty', 'under', 'being', 'either', 'namely', 'of', 'had', 'and', 'none', 'might', 'should', 'fifteen', 'without', 'formerly', 'still', 'top', 'thus', 'anyhow', 'may', 'so', 'take', 'sometimes', 'much', 'show', 'therefore', 'those', 'amongst', 'up', 'becoming', 'seems', 'thereafter', 'we', 'now', 'while', 'besides', 'wherein', 'further', 'whereas', 'something', 'becomes', 'i', 'unless', 'whereafter', 'whenever', 'during', 'whom', 'our', 'only', 'whether', 'due', 'empty', 'she', 'ours', 'yet', 'the', 'me', 'per', 'if', 'myself', 'nine', 'sixty', 'on', 'was', 'them', 'amount', 'an', 'themselves', 'about', 'a', 'both', 'say', 'noone', 'does', 'because', 'mine', 'whither', 'whose', 'must', 'ca', 'go', 'ourselves', 'been', 'over', 'were', 'or', 'yourselves', 'move', 'nowhere', 'be', 'can', 'yourself', 'call', 'mostly', 'these', 'already', 'therein', 'upon', 'see', 'perhaps', 'always', 'otherwise', 'they', 'could', 'become', 'do', 'bottom', 'herself', 'one', 'twelve', 'again', 'hence', 'last', 'beyond', 'least', 'own', 'somewhere', 'ten', 'would', 'became', 'really', 'many'}

# %% [markdown]
# ### Read embedding

# %%
import numpy as np
embs = {}
with open(emb_path) as f:
    count = 0
    for line in f:
        if count > 90000:
            break
        count += 1
        cut = line.find(' ')
        tok = line[:cut]
        emb = line[cut + 1:].split()
        emb = np.array([float(e) for e in emb])
        embs[tok] = emb

# %%
low = embs['much']
up = embs['more']

# %%
def sim(v1, v2):
    result = sum(v1*v2)/np.linalg.norm(v1)/np.linalg.norm(v2)
    return result

# %%
print(sim(low, up))
# Out:
# 0.2550954033558647
