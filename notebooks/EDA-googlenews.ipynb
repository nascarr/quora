# %% [markdown]
# # EDA google news embedding and Spacy tokenizer

# %%
import os
import re
import pandas as pd
import spacy
from collections import Counter
from gensim.models import KeyedVectors
from utils import *

# %%
class TokenTypes:
    def __init__(self):
        self.num_tokens = []
        self.symbol_tokens = []
        self.low_tokens = []
        self.up_tokens = []
        self.caps_tokens = []
        self.merged_tokens = []
        self.num_alpha_tokens = []
        self.one_symb_tokens = []

    def __call__(self, tokens):
        num_re = re.compile('[0-9]')
        low_re = re.compile('[a-z]')
        up_re = re.compile('[A-Z]')
        caps_re = re.compile('^[A-Z]*$')
        letnum_re = re.compile('[a-zA-Z0-9]')
        merged_re = re.compile('_')
        num_alpha_re = re.compile('^[0-9]+[a-zA-Z]+$')
        one_symb_re = re.compile('^[a-zA-Z]*[^0-9a-zA-Z][a-zA-Z]*$')
        
        for t in tokens:
            if num_re.search(t):
                self.num_tokens.append(t)
            if not letnum_re.search(t):
                self.symbol_tokens.append(t)
            if low_re.match(t):
                self.low_tokens.append(t)
            if up_re.match(t):
                self.up_tokens.append(t)
            if caps_re.match(t):
                self.caps_tokens.append(t)
            if merged_re.search(t):
                self.merged_tokens.append(t)
            if num_alpha_re.match(t):
                self.num_alpha_tokens.append(t)
            if one_symb_re.match(t) and len(t) > 1 and not merged_re.search(t):
                self.one_symb_tokens.append(t)
        print('Number of num tokens: ', len(self.num_tokens))
        print('Number of symbol tokens: ', len(self.symbol_tokens))
        print('Number of lowcase tokens: ', len(self.low_tokens))
        print('Number of upper case tokens: ', len(self.up_tokens))
        print('Nubmer of capslock tokens: ', len(self.caps_tokens))
        print('Nubmer of merged tokens: ', len(self.merged_tokens))
        print('Nubmer of num alpha tokens: ', len(self.num_alpha_tokens))
        print('Nubmer of one symbol tokens: ', len(self.one_symb_tokens))

        print('\n')

        print('Freq num tokens: ', self.num_tokens[:50])
        print('Rare num tokens: ', self.num_tokens[-10:], '\n')
        print('Freq symbol tokens: ', self.symbol_tokens[:10])
        print('Rare symbol tokens: ', self.symbol_tokens[-10:], '\n')
        print('Freq low tokens: ', self.low_tokens[:10])
        print('Rare low tokens: ', self.low_tokens[-10:], '\n')
        print('Freq up tokens: ', self.up_tokens[:10])
        print('Rare up tokens: ', self.up_tokens[-10:], '\n')
        print('Freq caps tokens: ', self.caps_tokens[:10])
        print('Rare caps tokens: ', self.caps_tokens[-10:])
        print('Freq merged tokens: ', self.merged_tokens[:20])
        print('Freq num alpha tokens: ', self.num_alpha_tokens[:20])
        print('Freq one symb tokens: ', self.one_symb_tokens[:20])

# %% [markdown]
# ### Look at embedding

# %%
emb_path = 'embeddings/GoogleNews-vectors-negative300/GoogleNews-vectors-negative300.bin'
data_dir = cache = '../data'

train_csv = os.path.join(data_dir, 'train.csv')
test_csv = os.path.join(data_dir, 'test.csv')
emb_path = os.path.join(data_dir, emb_path)

# %%
embeddings_index = KeyedVectors.load_word2vec_format(emb_path, binary=True)

# %%
emb_tokens = embeddings_index.index2word

# %%
embeddings_index.vector_size
# Out:
# 300

# %%
token_info(emb_tokens)
# Out:
# Number of tokens:  3000000
# First 10 tokens:  ['</s>', 'in', 'for', 'that', 'is', 'on', '##', 'The', 'with', 'said']

# %%
ttemb = TokenTypes()
ttemb(emb_tokens)
# Out:
# Number of num tokens:  35844
# Number of symbol tokens:  5172
# Number of lowcase tokens:  631815
# Number of upper case tokens:  2324222
# Nubmer of capslock tokens:  104279
# Nubmer of merged tokens:  2070978
# Nubmer of num alpha tokens:  2255
# Nubmer of one symbol tokens:  22548
#
#
# Freq num tokens:  ['1', '2', '3', '5', '4', '6', '7', '8', '9', '0', '2nd', '1st', '3_pointer', '3rd', '3D', '4th', '3_pointers', '3G', '5th', '6th', '7th', '8th', '9th', 'Q1', 'F1', 'Q3', 'Q2', 'Q4', 'PS3', 'CO2', 'MP3', '4A', '7pm', 'G8', '8pm', '4G', '3M', '3s', '5pm', '3A', 'U2', 'No.1', '6pm', '5A', '3pm', '0_Comments', '5K', 'O2', '2pm', '4pm']
# Rare num tokens:  ['K9_Duds', 'ponceau_4R_E###', 'ctorres2@bloomberg.net', 'Twickenham_TW1', 'GSX_R####_K9', 'Jailbreak_iPhone_3GS', 'W3C_OASIS', 'Time4_Media_subsidiary', '1p_dearer', 'Audi_A4_saloon']
#
# Freq symbol tokens:  ['##', '####', '$', '###', '#.#', '#-#', '%', '#,###', '#.##', '##,###']
# Rare symbol tokens:  ['###:#_###:#', '=====_====', 'Ð_¸_Ð', '+##-###-##-#####', '¢_##,###,###,###', '##,###,###_##,###,###_-------------------------------------', '#########_##.####_#.#####', '#,###,###_#,###,###_-------------------------------------------', '##.#:#_##.#:#_##.#:#', '#.#####_+#.#####_#.#####_-#.#####']
#
# Freq low tokens:  ['in', 'for', 'that', 'is', 'on', 'with', 'said', 'was', 'the', 'at']
# Rare low tokens:  ['prince_Guido_Henckel', 'loess_soil', 'listed_Beijing_Centergate', 'malfunctioning_tin_whisker', 'sheepdog_herding', 'chairman_Ken_Dulieu', 'divider_pistons', 'righthander_Kyle_Drabek', 'pulverizes_boulders', 'snowcapped_Caucasus']
#
# Freq up tokens:  ['The', 'I', 'It', 'He', 'We', 'In', 'A', 'U.S.', 'But', 'This']
# Rare up tokens:  ['Cow_Plop_Bingo', 'Shahid_Afridi_Rana_Naved', 'Anagnostaras_Adams', 'USA_TODAY_Reid_Cherner', 'Mauri_Liberati', 'Shilpa_Goenka', 'Thirsty_Owl', 'RAFFAELE', 'Bim_Skala_Bim', 'Mezze_Cafe']
#
# Freq caps tokens:  ['I', 'A', 'AP', 'TV', 'UK', 'CEO', 'UN', 'R', 'NFL', 'D']
# Rare caps tokens:  ['BRASKEM', 'KITTRELL', 'CHASSE', 'AICHI', 'BIMST', 'PLPM', 'PERVEZ', 'KUNDI', 'VISIONPAD', 'RAFFAELE']
# Freq merged tokens:  ['New_York', 'United_States', 'per_cent', '_', 'Associated_Press', 'Los_Angeles', 'health_care', 'looking_statements', 'White_House', 'High_School', 'e_mail', 'vice_president', 'World_Cup', 'Web_site', 'chief_executive', 'New_Zealand', 'Supreme_Court', 'real_estate', 'NEW_YORK', 'San_Francisco']
# Freq num alpha tokens:  ['2nd', '1st', '3rd', '3D', '4th', '3G', '5th', '6th', '7th', '8th', '9th', '4A', '7pm', '8pm', '4G', '3M', '3s', '5pm', '3A', '6pm']
# Freq one symb tokens:  ["'re", "'ve", "'m", "'ll", 'Inc.', 'Mr.', 'No.', "'d", 'St.', 'Dr.', 'Sept.', 'Jan.', 'Dec.', 'Corp.', 'Oct.', 'Nov.', 'Feb.', 'Aug.', 'Co.', 'in.']

# %%
ttemb.merged_tokens[500:]
# Out:
# ['First_Amendment',
#  'integral_part',
#  'Great_Depression',
#  'scoreless_innings',
#  'American_Legion',
#  'Finance_Committee',
#  'Kobe_Bryant',
#  'press_releases',
#  'Public_Works',
#  'Bear_Stearns',
#  'Roger_Federer',
#  'State_Condoleezza_Rice',
#  'Election_Day',
#  'Tony_Blair',
#  'Notes_@',
#  'Memorial_Hospital',
#  '###-####_ext',
#  'younger_brother',
#  'heavy_rain',
#  'House_Speaker',
#  'running_mate',
#  'Prime_Minister_Manmohan_Singh',
#  'parliamentary_elections',
#  'radio_stations',
#  'Highway_Patrol',
#  'place_undue_reliance',
#  'Nova_Scotia',
#  'Times_Square',
#  'starting_lineup',
#  'Tamil_Nadu',
#  'text_message',
#  'due_diligence',
#  'identity_theft',
#  'homeland_security',
#  'Humane_Society',
#  'Jesus_Christ',
#  'associate_professor',
#  'Commonwealth_Games',
#  'Southeastern_Conference',
#  'pm_EDT',
#  'sport_utility',
#  'Costa_Rica',
#  'drunken_driving',
#  'Public_Schools',
#  'invisible_item_flow',
#  'Funeral_Home',
#  'historical_facts',
#  'Chief_Operating_Officer',
#  'lung_cancer',
#  'Robert_Gates',
#  'Gold_Coast',
#  'master_degree',
#  'similar_expressions',
#  'illegal_immigration',
#  'jobless_rate',
#  'mental_illness',
#  'AC_Milan',
#  'safe_haven',
#  'Yankee_Stadium',
#  'Britney_Spears',
#  'stable_condition',
#  'partially_offset',
#  'institutional_investors',
#  'child_pornography',
#  'capital_expenditures',
#  'Human_Rights_Watch',
#  'respective_owners',
#  'market_capitalization',
#  'Red_Bull',
#  'tender_offer',
#  'West_Bengal',
#  'media_outlets',
#  'Colorado_Springs',
#  'JP_Morgan',
#  'Co._Ltd.',
#  'General_Motors_Corp.',
#  'apartment_complex',
#  'Grand_Rapids',
#  'New_Yorkers',
#  'anywhere_else',
#  'unknown_risks',
#  'delete_comments',
#  'blue_chip',
#  'raw_material',
#  'suicide_bomber',
#  'substance_abuse',
#  'search_warrant',
#  'Vietnam_War',
#  'mutual_fund',
#  'Southeast_Asia',
#  'Dallas_Cowboys',
#  '#:##_AM_ET',
#  'active_duty',
#  'Planning_Commission',
#  'stem_cells',
#  'contained_herein',
#  'anytime_soon',
#  'gross_margin',
#  'salary_cap',
#  'Christmas_Eve',
#  'Ole_Miss',
#  'Ben_Bernanke',
#  'Actual_results',
#  'Crude_oil',
#  'batting_.###',
#  'San_Bernardino',
#  'assistant_professor',
#  'e_mailed',
#  'Beverly_Hills',
#  'roadside_bomb',
#  'center_fielder',
#  'England_Patriots',
#  'nonprofit_organization',
#  'convenience_store',
#  'touch_screen',
#  'securities_laws',
#  'Middle_Eastern',
#  'Joe_Biden',
#  'armed_robbery',
#  'Alex_Rodriguez',
#  'standing_ovation',
#  'sexual_orientation',
#  'criminal_justice',
#  'wide_ranging',
#  'Baton_Rouge',
#  'double_digits',
#  'British_Airways',
#  'Al_Gore',
#  'drug_trafficking',
#  'tear_gas',
#  'release_contains',
#  'missile_defense',
#  'cloud_computing',
#  'Los_Angeles_Dodgers',
#  'Armed_Forces',
#  'intensive_care',
#  'arrest_warrant',
#  'private_placement',
#  'bachelor_degree',
#  'Reader_comments',
#  'Tea_Party',
#  'Mississippi_River',
#  'Toronto_Stock_Exchange',
#  'inspector_general',
#  'SAN_DIEGO',
#  'legislative_session',
#  'Indian_Ocean',
#  'Fort_Lauderdale',
#  'Superior_Court_Judge',
#  'Suu_Kyi',
#  'Madison_Square_Garden',
#  'Federal_Reserve_Chairman',
#  'Alzheimer_disease',
#  'published_broadcast_rewritten',
#  'Prince_William',
#  'suicide_bombers',
#  'David_Beckham',
#  'guilty_plea',
#  'Section_##E',
#  'wild_pitch',
#  'dining_room',
#  '###th_anniversary',
#  'prescription_drug',
#  'Eastern_Time',
#  'Ford_Motor_Co.',
#  'am_EDT',
#  'gold_medals',
#  'seasonally_adjusted',
#  'customer_satisfaction',
#  'Kuala_Lumpur',
#  'elementary_schools',
#  'Please_note',
#  'Star_Wars',
#  'cash_flows',
#  'Brett_Favre',
#  'Amnesty_International',
#  'Beijing_Olympics',
#  'Santa_Fe',
#  'Sierra_Leone',
#  'President_Mahmoud_Ahmadinejad',
#  'Academy_Award',
#  'President_Nicolas_Sarkozy',
#  'Uttar_Pradesh',
#  'Federal_Aviation_Administration',
#  'Port_au_Prince',
#  'uranium_enrichment',
#  'International_Atomic_Energy',
#  'comment_violates',
#  'Health_Organization',
#  'Census_Bureau',
#  'President_Hamid_Karzai',
#  'pleading_guilty',
#  'gunned_down',
#  'plead_guilty',
#  '£_#.#m',
#  'Rose_Bowl',
#  'Big_Brother',
#  'Fort_Wayne',
#  'natural_disasters',
#  'John_F._Kennedy',
#  'Dow_Jones_Industrial_Average',
#  'Atlantic_Coast',
#  'prior_written_consent',
#  'PO_Box',
#  'discontinued_operations',
#  'sex_offenders',
#  'Athletic_Conference',
#  'performance_enhancing',
#  'taxes_suitable',
#  'comic_book',
#  'NEW_ORLEANS',
#  'preliminary_hearing',
#  'swimming_pool',
#  'Asset_Management',
#  'eighth_grade',
#  'backed_securities',
#  'de_facto',
#  'aggravated_assault',
#  '###.##_yen',
#  'regulatory_approval',
#  'Information_Technology',
#  'per_annum',
#  'heavy_rains',
#  'Mercedes_Benz',
#  'Guantanamo_Bay',
#  'Army_Corps',
#  'profit_margins',
#  'Ann_Arbor',
#  'Al_Jazeera',
#  'Hewlett_Packard',
#  'Labour_Party',
#  'South_Africans',
#  'San_Francisco_Giants',
#  'controlled_substance',
#  'Historical_Society',
#  'LONDON_Reuters',
#  'disorderly_conduct',
#  'BHP_Billiton',
#  'Academy_Awards',
#  'seat_belt',
#  'Lt._Col.',
#  'Wal_Mart_Stores',
#  'Miami_Dade',
#  'Miami_Heat',
#  'Daily_Telegraph',
#  'Interior_Minister',
#  'pm_EST',
#  'somewhere_else',
#  'carbon_emissions',
#  'Barry_Bonds',
#  'Philadelphia_Phillies',
#  'Treasury_note',
#  'nursing_homes',
#  'repeat_violators',
#  'Warner_Bros.',
#  'Postal_Service',
#  'Tom_Brady',
#  'Mental_Health',
#  'somebody_else',
#  'user_click',
#  'objectionable_comment',
#  'Remember_comment_moderation',
#  'reader_interaction_discussion',
#  'use_profanities_vulgarities',
#  'guidelines_click',
#  'paste_outside',
#  'moderator_review',
#  'borrowing_costs',
#  'containing_inappropriate_links_obscenities',
#  'Deputy_Prime_Minister',
#  'delete_inappropriate_comments',
#  'American_Cancer_Society',
#  'material_objectionable',
#  'Crime_Stoppers',
#  'committed_suicide',
#  'Prime_Minister_Tony_Blair',
#  'Rafael_Nadal',
#  'President_Mahmoud_Abbas',
#  'Phil_Mickelson',
#  'National_Institutes',
#  'Business_Wire',
#  'administrative_expenses',
#  'knee_surgery',
#  'safe_harbor_provisions',
#  'privately_owned',
#  'LAS_VEGAS',
#  'closely_watched',
#  'Andhra_Pradesh',
#  'Atlanta_Braves',
#  'Internet_Explorer',
#  'user_friendly',
#  'corporate_governance',
#  'US_backed',
#  '##.##_plus_GST',
#  'pop_culture',
#  'South_Ossetia',
#  'Section_##A',
#  'Spider_Man',
#  'Climate_Change',
#  'Boston_Celtics',
#  'middle_aged',
#  'license_plate',
#  'investor_relations',
#  'Dallas_Morning_News',
#  'UEFA_Cup',
#  'search_engines',
#  'Pittsburgh_Steelers',
#  'non_governmental',
#  'Charlotte_NC',
#  '#.####_gallon',
#  'Steve_Jobs',
#  'rush_hour',
#  'Palo_Alto',
#  'Mother_Day',
#  'France_CAC',
#  'al_Maliki',
#  'presidential_nominee',
#  'multimillion_dollar',
#  'Persian_Gulf',
#  'foreseeable_future',
#  'McClatchy_Tribune_Information',
#  'General_Ban_Ki',
#  'fully_integrated',
#  'Kentucky_Derby',
#  'Joint_Chiefs',
#  'informational_purposes',
#  'Film_Festival',
#  'Daily_Mail',
#  'Adjusted_EBITDA',
#  'Windows_Mobile',
#  'Gov._Arnold_Schwarzenegger',
#  'San_Juan',
#  'News_Alert',
#  'ages_#-##',
#  'sex_couples',
#  'X_Factor',
#  'sex_offender',
#  '#:##-#:##_pm',
#  'elect_Barack_Obama',
#  'Class_B',
#  'solo_homer',
#  'fund_raiser',
#  'Michael_Vick',
#  'eco_friendly',
#  'air_pollution',
#  'Twin_Cities',
#  'Internal_Revenue_Service',
#  'Bowling_Green',
#  'Credit_Union',
#  'hamstring_injury',
#  'Minnesota_Twins',
#  'Pope_Benedict_XVI',
#  'Natural_gas',
#  'Korean_War',
#  'metric_tons',
#  'Walt_Disney',
#  'New_Yorker',
#  'self_esteem',
#  'Profile_Research',
#  'date_hereof',
#  'fossil_fuels',
#  'wheel_drive',
#  'coal_fired',
#  'bottled_water',
#  'Salt_Lake',
#  'civil_servants',
#  'Head_Coach',
#  'paid_tribute',
#  'pro_democracy',
#  'sexually_assaulted',
#  'Election_Commission',
#  'Paris_Hilton',
#  'Veterans_Affairs',
#  'Circuit_Judge',
#  'Foreign_Relations',
#  'user_interface',
#  'Wayne_Rooney',
#  'Santa_Claus',
#  'Independence_Day',
#  'Lady_Gaga',
#  'balance_sheets',
#  'FBI_agents',
#  'Higher_Education',
#  'PGA_Championship',
#  'offensive_lineman',
#  'grass_roots',
#  'joint_ventures',
#  'Analysts_polled',
#  'Phase_II',
#  'Rio_de_Janeiro',
#  'Lockheed_Martin',
#  'suicide_bombings',
#  'Chapel_Hill',
#  'feet_tall',
#  'Blue_Cross',
#  'registered_trademark',
#  'moving_averages',
#  'Serena_Williams',
#  'Los_Angeles_Angels',
#  'Getty_Images',
#  'fast_paced',
#  'cash_strapped',
#  'solar_panels',
#  'fatally_shot',
#  'parking_lots',
#  'Division_III',
#  "Shaquille_O'Neal",
#  'Miami_Herald',
#  'Golden_Eagles',
#  'Florida_Marlins',
#  'Minnesota_Vikings',
#  'X_rays',
#  'Inter_Milan',
#  'West_Side',
#  'civil_liberties',
#  'Southeast_Asian',
#  'Sao_Paulo',
#  'thousand_dollars',
#  'Cleveland_Indians',
#  'Lindsay_Lohan',
#  'Senate_Majority_Leader_Harry',
#  'Sir_Alex_Ferguson',
#  'Golf_Course',
#  'tax_evasion',
#  'space_shuttle',
#  'Regional_Medical',
#  'materially_different',
#  'Bin_Laden',
#  'most_populous',
#  'Rotary_Club',
#  'Santa_Monica',
#  'alma_mater',
#  '€_™_s',
#  'Britain_FTSE',
#  'hotel_rooms',
#  'singer_songwriter',
#  'Episcopal_Church',
#  'Public_Relations',
#  'Indianapolis_Colts',
#  'Angelina_Jolie',
#  'Port_Authority',
#  'Yellow_Jackets',
#  'rock_n_roll',
#  'cubic_meters',
#  'gift_cards',
#  'sexual_harassment',
#  'Human_Resources',
#  'No_Child_Left',
#  'foul_trouble',
#  'Federal_Emergency_Management',
#  'medium_sized',
#  'JPMorgan_Chase_&',
#  'Star_Trek',
#  'Philadelphia_Eagles',
#  'St._Cloud',
#  'House_Speaker_Nancy',
#  'Mountain_View',
#  'grocery_stores',
#  'touchdown_pass',
#  'transfer_window',
#  'finance_ministers',
#  'digital_cameras',
#  'Fort_Myers',
#  'Fidel_Castro',
#  'Lok_Sabha',
#  'Japan_Nikkei',
#  'trillion_yen',
#  'Miami_Dolphins',
#  'Mitt_Romney',
#  'Robert_Mugabe',
#  'risks_uncertainties',
#  'Fenway_Park',
#  'n_newspaper',
#  'intellectual_property_rights',
#  '##.##.##_#:##',
#  'Myrtle_Beach',
#  'pinch_hitter',
#  'analysts_polled',
#  'miles_southeast',
#  'More_importantly',
#  'wholly_owned',
#  'Federal_Communications',
#  'President_Vladimir_Putin',
#  '###-###-####_ext',
#  'Lt._Gov.',
#  'Defense_Ministry',
#  'NBC_Universal',
#  'stainless_steel',
#  'Civic_Center',
#  'Sioux_Falls',
#  'Al_Qaida',
#  'American_Civil_Liberties',
#  'polling_stations',
#  'Financial_Results',
#  'President_Hu_Jintao',
#  'Brad_Pitt',
#  'Star_Tribune',
#  'focal_point',
#  'batted_.###',
#  'mentally_ill',
#  'Light_sweet_crude',
#  'Cincinnati_Reds',
#  'Oval_Office',
#  'Houston_Astros',
#  'Performing_Arts',
#  'expressly_prohibited_without',
#  'suicide_bombing',
#  'Nobel_Peace_Prize',
#  'precious_metals',
#  'Jay_Z',
#  'President_Hosni_Mubarak',
#  'Jimmy_Carter',
#  'Staff_writer',
#  'Columbus_Ohio',
#  'miles_northwest',
#  'al_Sadr',
#  'Cape_Cod',
#  'stem_cell',
#  'jobless_claims',
#  'Stamford_Bridge',
#  'Delta_Air_Lines',
#  'co_op',
#  'Oprah_Winfrey',
#  'collective_bargaining',
#  'John_Boehner',
#  'stave_off',
#  'Bar_Association',
#  'socio_economic',
#  'Primary_School',
#  'Inspector_General',
#  'draft_picks',
#  'social_networking_sites',
#  'endangered_species',
#  'Jeff_Gordon',
#  'west_coast',
#  'President_Hugo_Chavez',
#  'relied_upon',
#  'San_Joaquin',
#  'Geological_Survey',
#  'Dwyane_Wade',
#  'THIS_IS',
#  'Sacred_Heart',
#  'Buenos_Aires',
#  'humanitarian_aid',
#  'San_Mateo',
#  'Windows_XP',
#  'medical_examiner',
#  'Toronto_Blue_Jays',
#  'Bayern_Munich',
#  'Or_maybe',
#  'Sprint_Cup',
#  'bronze_medal',
#  'newly_formed',
#  'constitutional_amendment',
#  'Prime_Minister_Ehud_Olmert',
#  'BAGHDAD_Iraq',
#  'newly_elected',
#  'compensation_expense',
#  'blood_sugar',
#  'rights_reserved',
#  'Windows_Vista',
#  'groin_injury',
#  'Robert_Gibbs',
#  'immigration_reform',
#  'feasibility_study',
#  'Corpus_Christi',
#  'east_coast',
#  'multibillion_dollar',
#  'tropical_storm',
#  'Night_Live',
#  'El_Salvador',
#  'Roman_Catholic',
#  'Chicago_Bulls',
#  'Liberal_Democrats',
#  'Transportation_Safety',
#  'designated_hitter',
#  'Peyton_Manning',
#  'Secret_Service',
#  'Baltimore_Orioles',
#  'Gulf_War',
#  'Prime_Minister_Stephen_Harper',
#  'Santa_Rosa',
#  'lieutenant_governor',
#  'Sunni_Arab',
#  '&_P',
#  'Certain_statements',
#  'insider_trading',
#  'mid_sized',
#  'Niger_Delta',
#  'silver_medal',
#  'silent_auction',
#  'opinion_polls',
#  'peanut_butter',
#  'analysts_surveyed',
#  'Colorado_Rockies',
#  'Winter_Olympics',
#  'Planned_Parenthood',
#  'profanity_obscenity_spam',
#  '•_Stay',
#  'readily_available',
#  'mutual_respect',
#  'drug_paraphernalia',
#  'King_Abdullah',
#  'Taliban_militants',
#  'athletic_director',
#  'Staples_Center',
#  'International_Space_Station',
#  'rate_hikes',
#  'Dow_Jones_Newswires',
#  'Special_Olympics',
#  'Mike_Huckabee',
#  'Blue_Jackets',
#  'presidential_nomination',
#  'martial_arts',
#  'corresponding_period',
#  'Environmental_Protection',
#  'miles_northeast',
#  'Downing_Street',
#  'Maple_Leafs',
#  'gunshot_wound',
#  'Pacific_Ocean',
#  'cross_examination',
#  'Not_surprisingly',
#  'Sadr_City',
#  'St._Clair',
#  'West_Brom',
#  'Red_Raiders',
#  'Six_Nations',
#  'blue_collar',
#  '•_Published',
#  'Red_Devils',
#  'science_fiction',
#  'Red_Hat',
#  'Triple_Crown',
#  'golf_courses',
#  'infield_single',
#  'Islamic_Republic',
#  'Royal_Dutch_Shell',
#  'Wildlife_Service',
#  'wind_farm',
#  'Staff_Sgt',
#  'Nextel_Cup',
#  'Nobel_Prize',
#  'San_Diego_Padres',
#  'Advisory_Board',
#  'Lance_Armstrong',
#  'Boston_Globe',
#  'PRNewswire_USNewswire',
#  'politically_motivated',
#  'Sun_Microsystems',
#  'coffee_shop',
#  'Islamic_militants',
#  'life_expectancy',
#  '##rd_minute',
#  'Ivy_League',
#  'SmarTrend_R',
#  'ex_girlfriend',
#  'Devil_Rays',
#  'risk_appetite',
#  'Cleveland_Cavaliers',
#  'national_anthem',
#  'International_Speedway',
#  'plastic_bags',
#  'Burger_King',
#  'Time_Warner_Cable',
#  'please_log',
#  'double_bogey',
#  'probable_cause',
#  'AFL_CIO',
#  'St._Francis',
#  'Atlanta_Falcons',
#  '£_##million',
#  'West_Palm_Beach',
#  'Ernst_&',
#  'junior_varsity',
#  'St._Louis_Cardinals',
#  'Trade_Organization',
#  'slot_machines',
#  '£_#.#bn',
#  'full_fledged',
#  'commenting_policies',
#  'Seattle_Mariners',
#  'Toyota_Motor_Corp.',
#  'Life_Insurance',
#  'highly_regarded',
#  'Sony_Ericsson',
#  'stem_cell_research',
#  'Milwaukee_Brewers',
#  'Detroit_Pistons',
#  'Rolls_Royce',
#  'Abu_Ghraib',
#  'Privacy_Policy',
#  'Tom_Cruise',
#  'Prime_Minister_Nouri_al',
#  'First_Quarter',
#  'file_sharing',
#  'Northern_Rock',
#  'Dallas_Mavericks',
#  'red_tape',
#  'Orlando_Fla.',
#  'voted_unanimously',
#  'Procter_&',
#  'CHARLOTTE_NC',
#  'text_messaging',
#  'Barclays_Capital',
#  'Detroit_Red_Wings',
#  'Tony_Stewart',
#  'Far_East',
#  'Islamic_Jihad',
#  'insurance_premiums',
#  'President_Pervez_Musharraf',
#  'smoking_ban',
#  'Secretary_General_Kofi',
#  'Derek_Jeter',
#  'Germany_DAX_index',
#  'wind_turbines',
#  'Viet_Nam',
#  '#-#:##_pm',
#  'Kevin_Garnett',
#  'X_ray',
#  'Advisory_Committee',
#  '0_Comments',
#  'Girls_Club',
#  'COLUMBUS_Ohio',
#  'quarterly_dividend',
#  'Federal_Trade',
#  'Senate_Majority_Leader',
#  'Senate_Judiciary_Committee',
#  'Pacific_Northwest',
#  'Symphony_Orchestra',
#  'yellow_card',
#  'diesel_fuel',
#  'crack_cocaine',
#  'Holy_Cross',
#  'live_webcast',
#  'Annual_Meeting',
#  'Judiciary_Committee',
#  'performing_arts',
#  'Mac_OS_X',
#  'Fort_Collins',
#  'Defence_Minister',
#  'unanimously_approved',
#  'inches_tall',
#  'BREAKING_NEWS_UPDATE',
#  'intangible_assets',
#  'power_outages',
#  'Associated_Press_Writers',
#  'disciplinary_action',
#  'weighted_average',
#  'asylum_seekers',
#  'web_pages',
#  'budget_deficits',
#  'fielder_choice',
#  'Andy_Murray',
#  'theme_park',
#  'instant_messaging',
#  'News_Desk',
#  'blood_vessels',
#  'comparison_purposes',
#  'sci_fi',
#  'defensive_lineman',
#  'Cristiano_Ronaldo',
#  'miles_southwest',
#  'Jimmie_Johnson',
#  'Andy_Roddick',
#  'background_checks',
#  'voter_registration',
#  'classical_music',
#  'Pittsburgh_Pirates',
#  'Boy_Scouts',
#  'East_Side',
#  'Denver_Broncos',
#  'Verizon_Communications',
#  'Nittany_Lions',
#  'RTT_Staff_Writer',
#  'Music_Awards',
#  'tractor_trailer',
#  'Orlando_Magic',
#  'Pittsburgh_Penguins',
#  'President_Dmitry_Medvedev',
#  'copyright_infringement',
#  'Analysts_surveyed',
#  'hot_spots',
#  'Rocky_Mountain',
#  'co_ordinator',
#  'stolen_bases',
#  'Arizona_Diamondbacks',
#  'Crown_Court',
#  'Staten_Island',
#  'Urban_Development',
#  'Crimson_Tide',
#  'defending_champions',
#  'Information_Administration',
#  'shutout_innings',
#  'debit_card',
#  'An_autopsy',
#  'baby_boomers',
#  'Border_Patrol',
#  '£_##.#m',
#  'Public_Affairs',
#  'Assistant_Secretary',
#  'Air_Force_Base',
#  'Timothy_Geithner',
#  'BNP_Paribas',
#  'olive_oil',
#  'publicly_update',
#  'Jose_Mourinho',
#  'annualized_return',
#  'Portland_Ore.',
#  'Winston_Salem',
#  'grand_prize',
#  'Palm_Springs',
#  'USA_TODAY',
#  'Emergency_Management',
#  'Mount_Vernon',
#  'carbon_footprint',
#  'hedged_play',
#  '0_0',
#  'star_studded',
#  'Phoenix_Suns',
#  'Manny_Ramirez',
#  'North_Koreans',
#  'Manmohan_Singh',
#  'Nelson_Mandela',
#  'RALEIGH_NC',
#  'Exxon_Mobil',
#  'HONG_KONG',
#  'horse_racing',
#  'AL_East',
#  'educational_institutions',
#  'cardiovascular_disease',
#  'Fitch_Ratings',
#  'Winter_Games',
#  'Sonia_Gandhi',
#  'CPI_M',
#  'JPMorgan_Chase',
#  'Presbyterian_Church',
#  'Wrigley_Field',
#  'Heart_Association',
#  'California_Highway_Patrol',
#  'PM_ET',
#  '##st_Century',
#  'smart_phones',
#  'Oakland_Raiders',
#  'Buffalo_Bills',
#  'Middle_Tennessee',
#  'AME_Info_FZ_LLC',
#  'parking_garage',
#  'David_Letterman',
#  'parking_spaces',
#  'Prince_Charles',
#  'wide_array',
#  'Liberal_Party',
#  'takeover_bid',
#  'Fine_Arts',
#  '+#.#_%',
#  'Carmelo_Anthony',
#  'Fashion_Week',
#  'Sun_Devils',
#  'degrees_Celsius',
#  'sectarian_violence',
#  'midterm_elections',
#  'sheriff_deputies',
#  'David_Petraeus',
#  'civilian_casualties',
#  '.###_batting',
#  'San_Antonio_Spurs',
#  'Kyoto_Protocol',
#  'Kanye_West',
#  'News_Alerts',
#  'punitive_damages',
#  'Nasdaq_Stock',
#  'Henry_Paulson',
#  'labor_unions',
#  'George_Mason',
#  'New_Zealanders',
#  'birth_certificate',
#  'IN_THE',
#  'HD_DVD',
#  'ETF_trade',
#  'sheriff_deputy',
#  'Kyodo_News',
#  'Liberal_Democrat',
#  'Taliban_fighters',
#  'State_Patrol',
#  'LPGA_Tour',
#  'Cleveland_Browns',
#  'Black_Sea',
#  'ETF_traders_successfully',
#  'TPS_trading_strategy',
#  'TPS_strategy',
#  'Oakland_Athletics',
#  'Heisman_Trophy',
#  'Hudson_River',
#  'Alcatel_Lucent',
#  'Lone_Star',
#  'Venus_Williams',
#  'Roland_Garros',
#  'job_seekers',
#  'timely_manner',
#  'NASHVILLE_Tenn.',
#  'Mother_Nature',
#  'First_Baptist_Church',
#  'wide_receivers',
#  'mass_transit',
#  'David_Ortiz',
#  'Iron_Man',
#  'St._Jude',
#  'dividend_yield',
#  'Roger_Clemens',
#  'revolves_around',
#  'metropolitan_areas',
#  'Jay_Leno',
#  'shopping_mall',
#  'accounting_principles',
#  'East_Timor',
#  'Harley_Davidson',
#  'white_collar',
#  'Gross_profit',
#  'Parkinson_disease',
#  'Great_Falls',
#  'soft_drinks',
#  'maximum_sentence',
#  'Boca_Raton',
#  'Congressional_District',
#  'United_Auto_Workers',
#  'Free_Trade',
#  'Kyle_Busch',
#  'Tim_Duncan',
#  'taxi_driver',
#  'proxy_statement',
#  'foul_language',
#  'Abraham_Lincoln',
#  'throwing_error',
#  'Interest_expense',
#  'Ray_Allen',
#  'remain_anonymous',
#  'Sierra_Club',
#  'Fort_Hood',
#  'Comedy_Central',
#  'SALT_LAKE_CITY',
#  'Dow_Jones_industrials',
#  'self_employed',
#  'Carling_Cup',
#  'Montreal_Canadiens',
#  'Seton_Hall',
#  'Conservative_Party',
#  'blog_entry',
#  'George_W',
#  'single_digits',
#  'coal_mine',
#  'regulatory_approvals',
#  'Tampa_Fla.',
#  'emerging_economies',
#  '##:##_AM_ET',
#  'Baltimore_Ravens',
#  'Real_estate',
#  'Farm_Bureau',
#  'guest_speaker',
#  'Electronic_Arts',
#  'Maj._Gen.',
#  'civil_unions',
#  'east_Jerusalem',
#  'Prime_Minister_Ariel_Sharon',
#  'Champions_Tour',
#  'Sky_Sports',
#  'Boston_Bruins',
#  'Non_GAAP',
#  'NBA_Finals',
#  'Capital_Partners',
#  'food_stamps',
#  'foot_birdie_putt',
#  'Federal_Deposit_Insurance',
#  'Blue_Shield',
#  'Central_Command',
#  'longest_serving',
#  'Northwest_Airlines',
#  'offshore_drilling',
#  '##/##/##_##:##',
#  'Thomson_First',
#  'deadly_weapon',
#  'Philadelphia_Flyers',
#  'keynote_speaker',
#  'counter_terrorism',
#  'sovereign_debt',
#  'underwent_surgery',
#  'Cancer_Research',
#  'stark_contrast',
#  'Press_Release',
#  'retail_outlets',
#  'wireless_broadband',
#  'Anheuser_Busch',
#  'capital_expenditure',
#  'Mr_Rudd',
#  'opposite_direction',
#  'Gov._Rick',
#  'New_Jersey_Nets',
#  'hunger_strike',
#  'National_Geographic',
#  'Tata_Motors',
#  ...]

# %%
ttemb.num_tokens
# Out:
# ['1',
#  '2',
#  '3',
#  '5',
#  '4',
#  '6',
#  '7',
#  '8',
#  '9',
#  '0',
#  '2nd',
#  '1st',
#  '3_pointer',
#  '3rd',
#  '3D',
#  '4th',
#  '3_pointers',
#  '3G',
#  '5th',
#  '6th',
#  '7th',
#  '8th',
#  '9th',
#  'Q1',
#  'F1',
#  'Q3',
#  'Q2',
#  'Q4',
#  'PS3',
#  'CO2',
#  'MP3',
#  '4A',
#  '7pm',
#  'G8',
#  '8pm',
#  '4G',
#  '3M',
#  '3s',
#  '5pm',
#  '3A',
#  'U2',
#  'No.1',
#  '6pm',
#  '5A',
#  '3pm',
#  '0_Comments',
#  '5K',
#  'O2',
#  '2pm',
#  '4pm',
#  '0_0',
#  'E3',
#  '9pm',
#  '9am',
#  '+1',
#  '2A',
#  '2B',
#  'Class_4A',
#  '1pm',
#  '2D',
#  'ESPN2',
#  'F.3d',
#  'AZ_az_,0_9',
#  '1B',
#  '1A',
#  'CO2_emissions',
#  'Class_3A',
#  'B2B',
#  'Proposition_8',
#  '8am',
#  'VH1',
#  'G7',
#  '1Q',
#  'H1',
#  'Class_2A',
#  '4Q',
#  'Windows_Phone_7',
#  '3B',
#  'A1',
#  'Class_5A',
#  '3Q',
#  'MP3_player',
#  'iPhone_3G',
#  '3_PTR',
#  '2Q',
#  'PS2',
#  'R2',
#  '6am',
#  'IPv6',
#  '0_errors',
#  '£_1m',
#  '7am',
#  'Comments_0',
#  'G1',
#  'P2P',
#  '+##_0',
#  '2b',
#  '3Com',
#  'omega_3',
#  'V8',
#  'No.2',
#  'MI5',
#  '1m',
#  'K2',
#  'P1',
#  'R1',
#  '1st_Class',
#  '2G',
#  '2GB',
#  '-1',
#  'Update1',
#  '3am',
#  'Class_1A',
#  'ITV1',
#  '1GB',
#  '2am',
#  'G8_summit',
#  'M1',
#  'M3',
#  '6A',
#  '-2',
#  'Ligue_1',
#  'M2M',
#  '4GB',
#  '3b',
#  '1am',
#  '1bn',
#  '4am',
#  '3DS',
#  '£_2m',
#  'A2',
#  '5am',
#  '1st_Lt.',
#  '1b',
#  'P2',
#  'QE2',
#  'London_E1_8AA_telephone',
#  '1st_Battalion',
#  '-3',
#  'BBC1',
#  'Toy_Story_3',
#  'A3',
#  '2m',
#  '+2',
#  '8GB',
#  '£_5m',
#  '9th_Circuit',
#  '3_rd',
#  '1M',
#  '0_recs',
#  'G2',
#  '+1_###-###-####',
#  'iPhone_3GS',
#  'T3',
#  'MI6',
#  '2d',
#  'Class_6A',
#  'HTML5',
#  '£_1bn',
#  'A4',
#  '2theadvocate.com',
#  'MPEG_4',
#  'H2',
#  'M2',
#  'P3',
#  'M2_PressWIRE',
#  'info@m2.com',
#  'within_M2_PressWIRE',
#  '£_3m',
#  '3m',
#  'C4',
#  'No.3',
#  'GP2',
#  'Update2',
#  'M2_PRESSWIRE_via_COMTEX',
#  'par_5s',
#  'V6',
#  '-5',
#  'M4',
#  '4th_Infantry_Division',
#  'C2',
#  '3i',
#  '5m',
#  'No1',
#  '-4',
#  'Cal.App.4th',
#  '£_1million',
#  'C3',
#  'G4',
#  '2K',
#  'TV3',
#  'MP3s',
#  'F5',
#  '5k',
#  '0_LOB',
#  'Rs.1',
#  'B2',
#  'Fahrenheit_9',
#  '.5',
#  'B1',
#  'mp3',
#  'T1',
#  'SW3d',
#  'A1GP',
#  '+3',
#  'F.2d',
#  '3rd_Infantry_Division',
#  '2nd_Battalion',
#  '1_#/#-mile',
#  'RM1',
#  '-6',
#  'R3',
#  'X2',
#  '£_4m',
#  '3D_graphics',
#  '----------------------------------------------------------_1',
#  'BBC2',
#  'F3',
#  'M6',
#  '3Q_profit',
#  '7PressRelease',
#  '£_6m',
#  '3PAR',
#  '4Q_profit',
#  'Cal.4th',
#  '1H',
#  '1Q_profit',
#  '5km',
#  'Prop_8',
#  'N1',
#  'D1',
#  'S3',
#  '2Q_profit',
#  'S1',
#  '4WD',
#  '-7',
#  'P5',
#  '2bn',
#  'Item_1A',
#  'SP1',
#  'C1',
#  'i2',
#  '2c',
#  '3Par',
#  'af2',
#  'US1',
#  'T2',
#  '4m',
#  'Maroon_5',
#  'Nintendo_3DS',
#  'SW2d',
#  'J2EE',
#  'G3',
#  'NewsChannel_8',
#  'H_1B',
#  '-8',
#  'No.4',
#  'SP2',
#  '7s',
#  'D2',
#  '£_2million',
#  'A1_Team',
#  '5th_Annual',
#  '2M',
#  '%_2F',
#  'D3',
#  '1st_Cavalry_Division',
#  'DDR2',
#  'R5',
#  '5c',
#  'MP4',
#  '+5',
#  '1s',
#  'CBS4',
#  '£_8m',
#  'R6',
#  'X3',
#  '1c',
#  'GT2',
#  '£_5million',
#  'R8',
#  'V8_Supercar',
#  '1st_Infantry_Division',
#  'M5',
#  'O2_Arena',
#  '1f',
#  '#.#_liter_V6',
#  'NY1',
#  'Modern_Warfare_2',
#  'MISSED_3',
#  'Update3',
#  '3c',
#  'K9',
#  'E1',
#  '1st_Armored_Division',
#  '6m',
#  'No.8',
#  'NW2d',
#  'SE2d',
#  '3d',
#  'Rs1',
#  'A5',
#  '4K',
#  '+4',
#  'P4',
#  '#.#_liter_V8',
#  'G5',
#  'Insiders_file_Form_4s',
#  '-9',
#  'S2',
#  '£_7m',
#  'A.2d',
#  '6th_Annual',
#  '7th_Annual',
#  'B2C',
#  '3bn',
#  'IPv4',
#  '2f',
#  '£_2bn',
#  '5M',
#  '3rd_Battalion',
#  'm2',
#  'DB2',
#  'N2',
#  '2x',
#  '£_3million',
#  'H2O',
#  'B3',
#  'F2',
#  'X5',
#  '5bn',
#  '8th_Annual',
#  'R4',
#  '9th_Cir',
#  'km2',
#  'M2_Communications_disclaims',
#  'COX_2',
#  'DDR3',
#  'X1',
#  '3D_glasses',
#  'Prop._8',
#  '4c',
#  '0_Recommend',
#  '5th_Circuit',
#  '3C',
#  'A6',
#  'R7',
#  '4D',
#  '3GS',
#  'Rs.2',
#  'Y2K',
#  'A8',
#  'ABC7',
#  'M2_Communications_Ltd',
#  'RM2',
#  '£_6million',
#  'W3C',
#  '2G_spectrum',
#  'A9',
#  'E2',
#  '8K',
#  '3km',
#  '1TB',
#  'IE8',
#  '1million',
#  '2km',
#  '2s',
#  '9th_Annual',
#  '.2',
#  '5s',
#  '2K_Sports',
#  '1_=_.####',
#  '.1',
#  'IE9',
#  '6ft',
#  'No.5',
#  '3D_seismic',
#  '4th_Quarter',
#  '9th_Circuit_Court',
#  '1p',
#  '8m',
#  'T5',
#  '3G_spectrum',
#  '+7',
#  '2p',
#  'iPhone_4G',
#  '1km',
#  '5p',
#  'H3',
#  'Tele2',
#  '4B',
#  'No.7',
#  'GT3',
#  '+6',
#  '%_2Fmedia',
#  '%_2Fmedia.washingtonpost.com',
#  '%_2Fmeta',
#  '4bn',
#  'T4',
#  '4x',
#  'P.2d',
#  '1st_Marine_Expeditionary',
#  'No.6',
#  'Pentium_4',
#  '7m',
#  '3rd_Quarter',
#  'E4',
#  'Taepodong_2',
#  '.3',
#  '4s',
#  'IE7',
#  'MP3_files',
#  'C5',
#  '8s',
#  'Rs.5',
#  'Average_+_-1',
#  '7A',
#  'V8_Supercars',
#  'Comments_0_TrackBacks',
#  '2C',
#  'WP7',
#  '2nd_Infantry_Division',
#  '1st_Brigade',
#  '1st_Quarter',
#  'P6',
#  'N8',
#  '£_3bn',
#  '4G_LTE',
#  'L2',
#  '.4',
#  '0_Comment',
#  '3_URLs',
#  '3x',
#  '5th_Fleet',
#  "'3",
#  '1m_##.###s',
#  '£_4million',
#  'Gran_Turismo_5',
#  'Internet2',
#  '2nd_Quarter',
#  '2nd_Brigade',
#  '9_mm_handgun',
#  '£_9m',
#  'K1',
#  'E._coli_O###_H7',
#  'Lower_9th',
#  'US2',
#  'L1',
#  'P.3d',
#  'IE6',
#  'WKBT_News_8',
#  '.6',
#  'F5_Networks',
#  '3_KEY_Moderate',
#  'Navy_5th_Fleet',
#  'MTV2',
#  'G4S',
#  'KPLC_7',
#  '+8',
#  '2X',
#  'carbon_dioxide_CO2',
#  '3GPP',
#  'Shahab_3',
#  'Nokia_N8',
#  'MP3_format',
#  'No._1s',
#  '2d_Cir',
#  'V2',
#  '6c',
#  'FTEU3',
#  'WW2',
#  'ADSL2_+',
#  '-0',
#  "'1",
#  '2G_scam',
#  '2nds',
#  'Rs2',
#  '8PM',
#  '.7',
#  '3p',
#  'NE2d',
#  'N3',
#  '-0_*_T',
#  'RM5',
#  'Ariane_5',
#  'RM3',
#  '4Cast',
#  'Rs.3',
#  '4M',
#  'H_1B_visas',
#  'Update4',
#  '3_Idiots',
#  '3D_TVs',
#  'BRCA1',
#  '.8',
#  '£_5bn',
#  '4km',
#  'PS3s',
#  '9m',
#  '4H',
#  '1C',
#  '9_mm_pistol',
#  '5B',
#  '£_8million',
#  'TF1',
#  'Game_7s',
#  'Item_1A_Risk_Factors',
#  '+9',
#  'Tel_+##_0',
#  'ITV2',
#  'Amazon_EC2',
#  'Baa3',
#  '9s',
#  '5pc',
#  'V8_engine',
#  '3GSM_World',
#  'RAV4',
#  '£_4bn',
#  'G8_Summit',
#  '3GSM',
#  '7c',
#  '6bn',
#  '1st_Battalion_###th',
#  'PLAYSTATION_3',
#  'S4',
#  '9mm',
#  'London_O2_Arena',
#  'Q4_EPS',
#  'S4C',
#  '6M',
#  '2H',
#  '3D_animation',
#  'Q1_EPS',
#  '1a',
#  'Rule_##b#_1',
#  'm3',
#  '4p',
#  '3rd_Brigade',
#  '8th_graders',
#  'Flash_Player_9',
#  'C7',
#  'Q3_EPS',
#  'Mazda3',
#  '£_7million',
#  '##am_5pm',
#  'No.9',
#  'A1C',
#  'stereoscopic_3D',
#  'Internet_Explorer_IE7',
#  '##am_4pm',
#  '8c',
#  '.9',
#  '2G_spectrum_scam',
#  'Q2_EPS',
#  '2K_Games',
#  '3K',
#  '3PL',
#  '7th_Heaven',
#  '5GB',
#  'ev3',
#  '3D_CAD',
#  '5ft',
#  '4X',
#  'US5',
#  '4_KEY_Low',
#  'Schedule_##D_9',
#  'NBC5',
#  'No2',
#  'P7',
#  '0_##mph',
#  'Ener1',
#  '1st_Brigade_Combat',
#  'Sprint_4G',
#  '1_#/##-mile',
#  '2_Duo_processor',
#  'Core_i7',
#  '9M',
#  'HER2',
#  'EUR1',
#  'Unreal_Engine_3',
#  'A1A',
#  'GT1',
#  'Baa1',
#  '2MB',
#  '5th_Cir',
#  '2nd_Brigade_Combat_Team',
#  '1GHz',
#  'X6',
#  '7PM',
#  '4C',
#  'A1_Grand_Prix',
#  'HbA1c',
#  'EC2',
#  'Aa2',
#  'i4i',
#  'The9',
#  'CH2M_Hill',
#  'So.2d',
#  '3G_handsets',
#  'G6',
#  "'2",
#  '3D_modeling',
#  'M2_EQUITYBITES_via_COMTEX',
#  'BMW_M3',
#  'On2',
#  '1K',
#  'N5',
#  'C6',
#  'Audi_A4',
#  '3rd_Brigade_Combat_Team',
#  'HTC_EVO_4G',
#  '5x',
#  '8km',
#  '7p',
#  'LMP2',
#  '9News',
#  'V3',
#  'par_3s',
#  '4th_Brigade_Combat',
#  'H_1B_visa',
#  'par_4s',
#  'Audi_R8',
#  '2TB',
#  'Soles4Souls',
#  'FTEU3_index',
#  '7p.m.',
#  'Sh1',
#  'omega_3s',
#  '8p',
#  'KPRC_Local_2',
#  '2OT',
#  '2G_spectrum_allocation',
#  'RC2',
#  'GP2_Series',
#  '3_fatty_acids',
#  'TV2',
#  'Rs.1_###.##',
#  'Cal.3d',
#  '1U',
#  '4INFO_#####',
#  'A7',
#  '9mm_pistol',
#  '3pc',
#  '7bn',
#  'BMW_X5',
#  'Moto2',
#  'Petty_Officer_2nd',
#  'H_2A',
#  'R9',
#  'M8',
#  'LMP1',
#  'S5',
#  '8th_Congressional',
#  '€_1bn',
#  'C2C',
#  'Army_3rd_Infantry',
#  '6B',
#  'U2_Bono',
#  '2pc',
#  'O2_arena',
#  '5K_Run',
#  'C8',
#  '6K',
#  '1kg',
#  '8bn',
#  'Q7',
#  'US3',
#  'euro1',
#  'no.1',
#  'HD2',
#  '8mm',
#  '4th_Battalion',
#  '5K_Run_Walk',
#  '3_Be_Truthful',
#  'Dh1',
#  'Ba1',
#  '5_Be_Proactive',
#  '9c',
#  'SS7',
#  'D4',
#  '£_6bn',
#  'euro1_billion',
#  '3X',
#  '1Malaysia',
#  '3GB',
#  'P8',
#  '3AW',
#  'US1_###.##',
#  '3d_Cir',
#  '6p',
#  '6km',
#  'KTVN_Channel_2',
#  'GS1',
#  'K4',
#  'H_2B',
#  '7th_Cir',
#  'Mazda6',
#  '1x',
#  'W2',
#  'Rs5',
#  '4th_Brigade',
#  '9NEWS',
#  'Rs3',
#  '8M',
#  '2nd_Floor',
#  'Appendix_3B',
#  'Cal.App.3d',
#  'W1',
#  'Airman_1st_Class',
#  'VDSL2',
#  'Ba2',
#  'VH1_reality',
#  '1D',
#  '3DTV',
#  'G7_finance',
#  '6ft_tall',
#  '9p',
#  '5V',
#  'B5',
#  '3f',
#  '3rd_Armored_Cavalry_Regiment',
#  'Aa3',
#  'p2pnet',
#  'E7',
#  '3i_Infotech',
#  "'4",
#  'Rs.4',
#  'DDR3_memory',
#  'B2_Networks',
#  'Hummer_H2',
#  'PLAYSTATION_®_3',
#  '5_FU',
#  'Ba3',
#  'Zap2it',
#  '9PM',
#  '7M',
#  'V8s',
#  'B4',
#  'BBC3',
#  'RAID_0',
#  '1pc',
#  '6s',
#  '8_Anonymous_commenters',
#  '4pc',
#  'Petty_Officer_3rd',
#  '7NEWS',
#  'Q5',
#  'mp3_player',
#  'Amazon_MP3',
#  '1MB',
#  'H1_B',
#  'No8',
#  'WESH_2',
#  '----------_-----------------------------------------------_1',
#  '9mm_handgun',
#  'Baa2',
#  '1st_Squadron',
#  'M2_PressWIRE_Via_Acquire',
#  'V1',
#  'Control4',
#  '4INFO',
#  'J2ME',
#  'WWAY_NewsChannel_3',
#  'SX4',
#  'IMAX_3D',
#  'Toyota_RAV4',
#  'P2P_networks',
#  'ESPN3.com',
#  'Windows_XP_SP2',
#  '3rd_Infantry',
#  'SP3',
#  'CN8',
#  '8A',
#  '6th_Cir',
#  '2k',
#  'H5',
#  'P5_+1',
#  'R2_D2',
#  '1min_##.###secs',
#  '1_HOME_TEAM',
#  '1billion',
#  'Mazda2',
#  'p2p',
#  "'5",
#  'N4',
#  '8th_Cir',
#  'SW1_4',
#  'MP3_WMA',
#  'machine_M2M',
#  'M7',
#  'L3',
#  '2PM',
#  'HTC_HD2',
#  'AD3d',
#  'MX1',
#  '2million',
#  'i3',
#  'TV5',
#  'EU3',
#  'SE1_4',
#  '1UP',
#  '8x',
#  '9th_Ward',
#  'S._G1',
#  'Mazda_MX_5',
#  '£_1billion',
#  'GBP1',
#  'Eight_G8',
#  'B6',
#  'V4',
#  'Numb3rs',
#  '2a',
#  'KWES_NewsWest_9',
#  'Spring_TX_newswest9.com',
#  'Update5',
#  'Toyota_4Runner',
#  'CD4_cell',
#  'PS3_Xbox',
#  'Z4',
#  '2WD',
#  '6PM',
#  'Renault_F1',
#  'S7',
#  'PS1',
#  'News4',
#  '7B',
#  '£_7bn',
#  'POP3',
#  '8th_grader',
#  '2D_seismic',
#  '6pc',
#  'VH1_Classic',
#  '5C',
#  'F4',
#  'NDM_1',
#  'GPLv3',
#  'CD4',
#  'Audi_A6',
#  'Ohio_St.3d',
#  '3D_visualization',
#  '3PM',
#  'Tempel_1',
#  'DDR2_memory',
#  '3rd_Floor',
#  '4th_Cir',
#  'H7',
#  '2nd_Battalion_###th',
#  'CO2_emission',
#  'Tel_+1',
#  '€_1m',
#  'TiO2',
#  'mg/m2',
#  'x2',
#  'NW1_4',
#  'NE1_4',
#  "4_H'ers",
#  'euro2',
#  '1b_unassisted',
#  '2kg',
#  'D5',
#  'CH2M_HILL',
#  'Wn.2d',
#  'BBC4',
#  'tru2way',
#  'K3',
#  'euro5_billion',
#  'Rule_3b_6',
#  '3g',
#  'v2',
#  '9bn',
#  'KIRO_7',
#  '1E',
#  '2nd_XI',
#  'L2_cache',
#  '2_KEY_Considerable',
#  'FP7',
#  'Al_Samoud_2',
#  'S6',
#  '5PM',
#  '£_9million',
#  'i5',
#  'Rustavi_2',
#  'V5',
#  '##am_6pm',
#  '6NEWS',
#  'Sh2',
#  '2U',
#  'Aa1',
#  '7km',
#  'British_F3',
#  'V6_engine',
#  '9A',
#  '5mm',
#  'Stargate_SG_1',
#  '2K_Sports_Classic',
#  'US4',
#  'NBC4',
#  '£_8bn',
#  '4th_Floor',
#  'Proposition_1A',
#  'Rs4',
#  '5th_Grader',
#  'Vista_SP1',
#  'E5',
#  '5million',
#  'E6',
#  'BMW_X3',
#  'S8',
#  'carbon_dioxide_CO2_emissions',
#  'Audi_A3',
#  'Rs.6',
#  '7pc',
#  'RM4',
#  '##b#_1',
#  'P4P',
#  'MPEG4',
#  '1G',
#  '8pc',
#  '7th_Fleet',
#  'ProSiebenSat.1',
#  'U3',
#  'CS3',
#  'WSO2',
#  'MX2',
#  'Core_i5',
#  '1p.m.',
#  '5kg',
#  '1X',
#  'S._G2',
#  'Route1',
#  'SEND2PRESS_NEWSWIRE',
#  'Petty_Officer_1st',
#  'Rs.7',
#  '2GHz',
#  'Symbian_^_3',
#  'Q1_Q2',
#  'H2O_Innovation',
#  'reducing_CO2_emissions',
#  'D8',
#  '3rds',
#  '4Runner',
#  'KATV_Channel_7',
#  '5cm',
#  'CP3',
#  '8_Cyl',
#  'rlk1',
#  'D6',
#  "'9",
#  'Power_Mac_G5',
#  'Pontiac_G6',
#  '1m_##.##s',
#  '5_interims_history',
#  'Audi_Q7',
#  'X4',
#  '3_ODST',
#  'DS3',
#  'NewsChannel5',
#  '3mm',
#  '5_COMPANIES_IN',
#  'C4ISR',
#  'ps3',
#  'Audi_A8',
#  'IBM_DB2',
#  '5D',
#  '2Mbps',
#  'Mazda5',
#  'J2',
#  'GT3_RSR',
#  '+1_###.###.####',
#  'GP2_Asia',
#  '2_Duo_processors',
#  '8B',
#  'arenafootball2',
#  '1ST',
#  'USF1',
#  '3P',
#  'No3',
#  '8p.m.',
#  'Cash4Gold',
#  'T6',
#  '3ft',
#  'A2DP',
#  '6x',
#  '4_WOAI',
#  'Q1_FY##',
#  'HER2_positive',
#  'Road_A1A',
#  '5lb',
#  'Net2Phone',
#  'BMW_Sauber_F1',
#  'By_WSBT_News1',
#  'RC1',
#  '2mm',
#  '5_interims',
#  'cs4',
#  '8k',
#  'Raw_Sky5_Video',
#  '----------------------------------------------------------_3',
#  'T9',
#  '6C',
#  ...]

# %%
ttemb.one_symb_tokens
# Out:
# ["'re",
#  "'ve",
#  "'m",
#  "'ll",
#  'Inc.',
#  'Mr.',
#  'No.',
#  "'d",
#  'St.',
#  'Dr.',
#  'Sept.',
#  'Jan.',
#  'Dec.',
#  'Corp.',
#  'Oct.',
#  'Nov.',
#  'Feb.',
#  'Aug.',
#  'Co.',
#  'in.',
#  'Jr.',
#  'Sen.',
#  'vs.',
#  'Rep.',
#  'J.',
#  'A.',
#  'Ms.',
#  'E.',
#  'S.',
#  'W.',
#  'M.',
#  'Gov.',
#  'Ltd.',
#  'Calif.',
#  'etc.',
#  'L.',
#  'Mrs.',
#  'R.',
#  'C.',
#  'N.',
#  'D.',
#  'Rev.',
#  'B.',
#  "O'Brien",
#  "It'sa",
#  'Lt.',
#  'Capt.',
#  'P.',
#  'v.',
#  'T.',
#  'Sr.',
#  'G.',
#  'H.',
#  "I'ma",
#  'F.',
#  'Gen.',
#  'Fla.',
#  "O'Connor",
#  "it'sa",
#  'Pa.',
#  'K.',
#  "O'Neill",
#  "O'Neal",
#  'Yahoo!',
#  'Q.',
#  "isn'ta",
#  'Mo.',
#  'Mass.',
#  "wasn'ta",
#  "O'Donnell",
#  'Col.',
#  'Ill.',
#  'Amazon.com',
#  'Sacbee.com',
#  'FXstreet.com',
#  'Va.',
#  'Mich.',
#  'I.',
#  "'S",
#  "there'sa",
#  "o'clock",
#  'Maj.',
#  'Minn.',
#  'Md.',
#  "O'Reilly",
#  'V.',
#  'Mar.',
#  'Ga.',
#  "O'Connell",
#  'MLB.com',
#  'Ind.',
#  'Prof.',
#  'Wis.',
#  "O'Malley",
#  "O'Leary",
#  "There'sa",
#  'Colo.',
#  'Café',
#  'Apr.',
#  'La.',
#  "O'Sullivan",
#  'Ky.',
#  'Tenn.',
#  'O.',
#  'Ark.',
#  'Wash.',
#  "Shi'ite",
#  'Conn.',
#  'Miss.',
#  "O'Keefe",
#  "O'Neil",
#  'Kan.',
#  'Ala.',
#  "He'sa",
#  'Dept.',
#  'newsday.com',
#  'Sens.',
#  "Hawai'i",
#  "that'sa",
#  'café',
#  "That'sa",
#  'U.',
#  "O'Hara",
#  'ESPN.com',
#  'SanLuisObispo.com',
#  'Reps.',
#  'Nos.',
#  'Ariz.',
#  'Applause.',
#  "O'Shea",
#  "D'",
#  'Sep.',
#  "he'sa",
#  "Yar'Adua",
#  'Chávez',
#  'Salesforce.com',
#  'Ore.',
#  'Jun.',
#  'Okla.',
#  'Del.',
#  'Neb.',
#  "O'Hare",
#  "O'Rourke",
#  'cliché',
#  'décor',
#  'Jul.',
#  'PR.com',
#  'CNSNews.com',
#  "O'Grady",
#  'naïve',
#  'Y.',
#  "O'Toole",
#  'fiancé',
#  "gov't",
#  'sunherald.com',
#  'ft.',
#  "y'all",
#  'Briefing.com',
#  'Rivals.com',
#  'fiancée',
#  'Malacañang',
#  "Gov't",
#  "d'",
#  "Eto'o",
#  'Vt.',
#  'TMZ.com',
#  'Scout.com',
#  'Z.',
#  'E.ON',
#  'Cos.',
#  "C'mon",
#  "O'Driscoll",
#  "L'",
#  "O'Dell",
#  'Prop.',
#  'façade',
#  "Shi'ites",
#  'Nev.',
#  "aren'ta",
#  'INC.',
#  "Qur'an",
#  'MiamiHerald.com',
#  'communiqué',
#  "OK'd",
#  "O'Meara",
#  'José',
#  'Laughter.',
#  'Guantánamo',
#  'X.',
#  'clichés',
#  'Goal.com',
#  'lb.',
#  "don't",
#  'SQUEEZETRIGGER.COM',
#  'Nestlé',
#  "O'Callaghan",
#  'MySpace.com',
#  'MoveOn.org',
#  'Ottawasun.com',
#  'Edmunds.com',
#  'Beyoncé',
#  'Québec',
#  'Bros.',
#  'SI.com',
#  'Messrs.',
#  'Erdoğan',
#  "Here'sa",
#  'salesforce.com',
#  'Adm.',
#  'BND.com',
#  "O'Fallon",
#  "Kaua'i",
#  "She'sa",
#  'Bankrate.com',
#  "Int'l",
#  'Peña',
#  'noticias.info',
#  "O'Gara",
#  'BUYINS.NET',
#  "O'Dowd",
#  'ap.org',
#  'Wyo.',
#  'GMANews.TV',
#  'IsraelNN.com',
#  'Tex.',
#  "Sana'a",
#  'Forbes.com',
#  "O'Loughlin",
#  "O'Hair",
#  "O'Keeffe",
#  "O'Donoghue",
#  'twitter.com',
#  'André',
#  'Ask.com',
#  'Ph.D',
#  'EMAILWIRE.COM',
#  'gardaí',
#  'pp.',
#  "O'Dea",
#  'entrée',
#  'People.com',
#  'TVGuide.com',
#  'Montréal',
#  'Hollywood.com',
#  "don'ts",
#  "she'sa",
#  'CNN.com',
#  "Xi'an",
#  'Gardaí',
#  'cafés',
#  'Overstock.com',
#  "Mo'Nique",
#  'TheStreet.com',
#  'So.',
#  'İstanbul',
#  'P.Geo',
#  'Match.com',
#  'PRLEAP.COM',
#  "I'm",
#  "O'Hanlon",
#  "weren'ta",
#  "O'Halloran",
#  'Dáil',
#  'Calderón',
#  'NFL.com',
#  "must've",
#  'Pokémon',
#  "Shi'a",
#  "l'",
#  'p.',
#  'García',
#  "O'Day",
#  'Alibaba.com',
#  'YouTube.com',
#  'Zacks.com',
#  "O'Gorman",
#  'Twitter.com',
#  "Y'all",
#  'thе',
#  'Facebook.com',
#  "O'Byrne",
#  "O'Bannon",
#  'ASP.NET',
#  'clichéd',
#  "Brind'Amour",
#  'οf',
#  'Muñoz',
#  'About.com',
#  'RadarOnline.com',
#  'CO.',
#  'Barça',
#  'MaineToday.com',
#  'tο',
#  "O'Dwyer",
#  'RTÉ',
#  "can't",
#  "O'Shaughnessy",
#  'Fr.',
#  'S.Korea',
#  'Amarillo.com',
#  'Etc.',
#  'OpenOffice.org',
#  'Id.',
#  'ticketmaster.com',
#  "ma'am",
#  'Schröder',
#  'Walmart.com',
#  'Juárez',
#  'François',
#  'MSNBC.com',
#  'González',
#  "O'Boyle",
#  "O'Kane",
#  'newratings.com',
#  'Monster.com',
#  'Pérez',
#  'Telefónica',
#  'azstarnet.com',
#  "O'ahu",
#  "O'Quinn",
#  'Priceline.com',
#  "they're",
#  'N.Korea',
#  "O'Donovan",
#  'exposé',
#  'Bhd.',
#  "Baha'i",
#  'PriceQuotes.com',
#  "How'd",
#  'Baidu.com',
#  "San'a",
#  "here'sa",
#  'OTCPicks.com',
#  'Last.fm',
#  "O'Farrell",
#  "O'Hagan",
#  "O'Mahony",
#  'est.',
#  'SqueezeTrigger.com',
#  'WWD.COM',
#  'Google.cn',
#  'Hotels.com',
#  'Rodríguez',
#  "nor'easter",
#  'MTV.com',
#  'CNNMoney.com',
#  "O'Bryan",
#  'Düsseldorf',
#  "O'Mara",
#  'CareerBuilder.com',
#  'Gül',
#  'washingtonpost.com',
#  'Streetinvesting.com',
#  'FOXSports.com',
#  'Audible.com',
#  "O'Conner",
#  'Nuñez',
#  "c'mon",
#  'approx.',
#  'René',
#  "Ha'aretz",
#  'BlockShopper.com',
#  'NWHerald.com',
#  'risqué',
#  'Martínez',
#  'Ticketmaster.com',
#  'López',
#  "O'Hern",
#  'Billboard.com',
#  'Pinnacledigest.com',
#  "we're",
#  'Cars.com',
#  "'M",
#  'document.write',
#  'Ancestry.com',
#  'amazon.com',
#  "y'know",
#  'P.Eng',
#  'FT.com',
#  'GoDaddy.com',
#  'Google.com',
#  "B'Tselem",
#  'Sportsbook.com',
#  'PanARMENIAN.Net',
#  'AllHipHop.com',
#  'Zenit.org',
#  'Examiner.com',
#  'Sánchez',
#  "Na'vi",
#  'myspace.com',
#  'LateRooms.com',
#  'Müller',
#  'NBA.com',
#  'über',
#  'J.Lo',
#  "N'Djamena",
#  'Hernández',
#  'News.com',
#  'CBSSports.com',
#  'LifeSiteNews.com',
#  'LiveSoccerTV.com',
#  'Benítez',
#  "O'Brian",
#  'sautéed',
#  'Osmeña',
#  'Buy.com',
#  "ID'd",
#  'Economy.com',
#  "N'Zogbia",
#  'said.The',
#  'Citroën',
#  'TradingMarkets.com',
#  'Salon.com',
#  'thestate.com',
#  "int'l",
#  'WWE.com',
#  'passé',
#  'NYTimes.com',
#  "you're",
#  'AccuWeather.com',
#  "O'Kelly",
#  'NHL.com',
#  "O'Flaherty",
#  'sauté',
#  'Ramírez',
#  'E.coli',
#  'Shopping.com',
#  "ya'll",
#  'registercitizen.com',
#  'delcotimes.com',
#  'nhregister.com',
#  'Caller.com',
#  'Wired.com',
#  'Force.com',
#  'resumé',
#  'Raúl',
#  'Bogotá',
#  'Bancorp.',
#  'Chrétien',
#  'YourDomain.com',
#  'Fig.',
#  'facebook.com',
#  "O'Bryant",
#  'S.Africa',
#  'pnj.com',
#  'WSJ.com',
#  'entrées',
#  'globeandmail.com',
#  'index.html',
#  'Boston.com',
#  'clean.Comments',
#  'FoxNews.com',
#  'pottsmerc.com',
#  "O'Flynn",
#  'Métis',
#  'Océ',
#  'adobe.com',
#  'attaché',
#  "Baha'is",
#  'E.On',
#  "O'Regan",
#  'Fernández',
#  "S'pore",
#  'Yahoo.com',
#  "ne'er",
#  'AutoTrader.com',
#  'LifeNews.com',
#  'Treviño',
#  'Rs.',
#  'NASCAR.COM',
#  'μm',
#  'BeaconEquity.com',
#  "won't",
#  "Bil'in",
#  "Ma'am",
#  'Nürburgring',
#  'HeraldTribune.com',
#  'Metalunderground.com',
#  'Bodog.com',
#  'Stockwire.com',
#  'ABQTrib.com',
#  'montgomeryadvertiser.com',
#  'CareerStructure.com',
#  'Politico.com',
#  'Zillow.com',
#  'm²',
#  'silicon.com',
#  'Local.com',
#  'Ph.Ds',
#  'themorningsun.com',
#  'edmontonjournal.com',
#  'LCH.Clearnet',
#  "O'REILLY",
#  'Expedia.com',
#  'Cancún',
#  'Māori',
#  'middletownpress.com',
#  'WGRZ.com',
#  'іn',
#  'moneysupermarket.com',
#  'coupé',
#  'Renée',
#  "Hallowe'en",
#  'Fenerbahçe',
#  'naiveté',
#  "O'Ryan",
#  'blasé',
#  "KO'd",
#  'HealthNewsDigest.com',
#  'prMac.com',
#  'Salary.com',
#  "SANA'A",
#  'piñata',
#  'Hulu.com',
#  'NapaValleyRegister.com',
#  "O'Charley",
#  'yahoo.com',
#  'FOXNews.com',
#  'sr.',
#  'GoErie.com',
#  'crèche',
#  "it's",
#  'Thе',
#  'PR.COM',
#  'CBNNews.com',
#  'TimesRecordNews.com',
#  "s'mores",
#  'Target.com',
#  'skysports.com',
#  "O'Riordan",
#  'Björk',
#  "Punk'd",
#  'CORP.',
#  'KCChronicle.com',
#  'Stéphane',
#  'ie.',
#  'msnbc.com',
#  "who'sa",
#  'SalisburyPost.com',
#  'IRS.gov',
#  'Shop.org',
#  'AnnArbor.com',
#  'J.Crew',
#  'ibnlive.com',
#  'LoHud.com',
#  'trentonian.com',
#  'Kč',
#  'reuters.com',
#  "O'Doherty",
#  'PinnacleDigest.com',
#  'morningjournal.com',
#  "Shari'a",
#  'uefa.com',
#  'FoxSports.com',
#  'Forex.com',
#  'Canpages.ca',
#  'rosé',
#  'fοr',
#  'CBSNews.com',
#  'Mint.com',
#  'Hermès',
#  'wіth',
#  'IslamOnline.net',
#  'thereporteronline.com',
#  "Ma'an",
#  "Chang'e",
#  'AA.com',
#  'Málaga',
#  'PhysOrg.com',
#  'd.',
#  'MLSnet.com',
#  'youtube.com',
#  "I've",
#  "didn't",
#  'Gómez',
#  'ABCNews.com',
#  'AOL.com',
#  "O'Jays",
#  'eBay.com',
#  'rapidcityjournal.com',
#  'Realtor.com',
#  'ABC.com',
#  'winnipegfreepress.com',
#  'Jiménez',
#  "O'Hearn",
#  "let's",
#  'İzmir',
#  'PWMForums.com',
#  'contactmusic.com',
#  'Díaz',
#  'FIFA.com',
#  'USATODAY.com',
#  'pop.',
#  "Kapa'a",
#  'Sina.com',
#  'TheWBALChannel.com',
#  'NPR.org',
#  'SPACE.com',
#  'Advertising.com',
#  'CalcuttaTube.Com',
#  'Sohu.com',
#  'mélange',
#  'b.',
#  'Seibertron.com',
#  'ČTK',
#  'sq.m',
#  'Gutiérrez',
#  'MMAjunkie.com',
#  'Jos.',
#  'TSX.V',
#  'Seán',
#  "Nat'l",
#  "Don't",
#  'priceline.com',
#  'FareCompare.com',
#  "isn't",
#  'Curaçao',
#  'gasp!',
#  'Ch.',
#  'Myspace.com',
#  'Spokesman.com',
#  "O'Carroll",
#  'Diyarbakır',
#  'oneidadispatch.com',
#  'Stamps.com',
#  'UsMagazine.com',
#  'Jürgen',
#  'Ibid.',
#  'Usmagazine.com',
#  'canapés',
#  'México',
#  'Atatürk',
#  'Answers.com',
#  'Préval',
#  'EW.com',
#  'StockMarketWire.com',
#  "who's",
#  "doesn't",
#  'GlobeSt.com',
#  'María',
#  'Erdoðan',
#  'Tickets.com',
#  'timesherald.com',
#  "T'Wolves",
#  'Time.com',
#  'dailytribune.com',
#  'SmallCapVoice.com',
#  'rivals.com',
#  'uSwitch.com',
#  'Asiantribune.com',
#  "Yar'adua",
#  'Atlético',
#  'Moveon.org',
#  'NewsOK.com',
#  'eg.',
#  'CNBC.com',
#  "Jo'burg",
#  'Kaká',
#  'Malmö',
#  'more.',
#  "O'BRIEN",
#  'lastminute.com',
#  "Te'o",
#  'Ret.',
#  "Where'd",
#  'inc.com',
#  'nepalnews.com',
#  'hotels.com',
#  'León',
#  'delta.com',
#  'gr.',
#  'cf.',
#  'Coupé',
#  'India.Arie',
#  'jr.',
#  'Google.org',
#  "you'll",
#  'Sébastien',
#  'CHICAGOPRESSRELEASE.COM',
#  'GamesIndustry.biz',
#  "Dep't",
#  'Reykjavík',
#  'Gay.com',
#  'Mamma.com',
#  'GlobalSecurity.org',
#  'tulsaworld.com',
#  'BetUS.com',
#  'l.',
#  'Niño',
#  'LG.Philips',
#  'Zappos.com',
#  'détente',
#  "Y'know",
#  'c.bank',
#  'MarketResearch.com',
#  'BuffaloNews.com',
#  'Bloomberg.com',
#  'Touré',
#  'troyrecord.com',
#  'Battle.net',
#  "Hon'ble",
#  'Confused.com',
#  'première',
#  "Cam'ron",
#  'Pelé',
#  'soufflé',
#  'BRIEFING.COM',
#  "what's",
#  'LJWorld.com',
#  'Register.com',
#  'beliefnet.com',
#  "how'd",
#  'NBC.com',
#  'worldâ',
#  'bristolpress.com',
#  'moneycontrol.com',
#  'Playbill.com',
#  "Terre'Blanche",
#  "Sa'ada",
#  'MSN.com',
#  'nytimes.com',
#  "I'll",
#  'César',
#  'drugstore.com',
#  'Insiderslab.com',
#  'FLOWERS.COM',
#  'Youbet.com',
#  'MovieTickets.com',
#  'DonorsChoose.org',
#  'saratogian.com',
#  'jalapeño',
#  'One.Tel',
#  'Tánaiste',
#  "we've",
#  'Box.net',
#  'élan',
#  'MEMRIFilms.org',
#  'thаt',
#  'NBCOlympics.com',
#  'Décor',
#  "Amar'e",
#  "Mi'kmaq",
#  'MSNsportsNET.com',
#  'KansasCity.com',
#  'Learn.com',
#  'NME.COM',
#  'née',
#  'weather.com',
#  'TV.com',
#  'Sherdog.com',
#  'Björn',
#  'Zoë',
#  "Nor'easter",
#  'Jörg',
#  'purée',
#  'Brasília',
#  'google.com',
#  'swissinfo.ch',
#  'crème',
#  "Bo'ness",
#  'MYFOXNY.COM',
#  "O'Rear",
#  'España',
#  'Laughs.',
#  'BoxingScene.com',
#  "Don'ts",
#  'TrueCar.com',
#  "Lady'Backs",
#  'index.htm',
#  'Cézanne',
#  'Portfolio.com',
#  "O'Barry",
#  'Philly.com',
#  'Mfg.',
#  'MSC.Software',
#  'Española',
#  'Orléans',
#  "What'sa",
#  'TheBullionDesk.com',
#  'Play.com',
#  'Gawker.com',
#  'Davutoğlu',
#  'οr',
#  'Castañeda',
#  'c.',
#  'CreditCards.com',
#  'Ivanhoe.com',
#  'DailyFreeman.com',
#  'INQUIRER.net',
#  'Lastminute.com',
#  'Standoutstocks.com',
#  "Nuku'alofa",
#  'Córdoba',
#  "M'sia",
#  'e.tv',
#  'Colón',
#  'gmail.com',
#  "T'PURAM",
#  'Carbonfund.org',
#  'Blogcritics.org',
#  'AsiaRooms.com',
#  'Web.com',
#  'Piñera',
#  'Jesús',
#  'Foxsports.com',
#  'sq.',
#  'für',
#  'Moneysupermarket.com',
#  "Shari'ah",
#  "Ma'ariv",
#  'Andrés',
#  'BusinessWeek.com',
#  "Li'l",
#  'Dalí',
#  'liveauctioneers.com',
#  'thenewsmarket.com',
#  'Slate.com',
#  "ain'ta",
#  'Buyins.net',
#  'MarketWatch.com',
#  'Kayak.com',
#  'Parañaque',
#  'iStockAnalyst.com',
#  'Ramón',
#  'Drugstore.com',
#  'BullMarket.com',
#  'Townhall.com',
#  'bit.ly',
#  "What'd",
#  'newbritainherald.com',
#  'Tomás',
#  "O'Riley",
#  'PennyStockChaser.com',
#  'companiesandmarkets.com',
#  'IGN.com',
#  'Traffic.com',
#  'Guzmán',
#  'début',
#  'Brüno',
#  'Présentation',
#  'incl.',
#  'Inc.com',
#  'Martín',
#  'united.com',
#  'Recovery.gov',
#  'PinnacleSports.com',
#  'Zürich',
#  "women's",
#  'latimes.com',
#  'kbb.com',
#  'FactCheck.org',
#  'possible.Copyright',
#  "Ya'alon",
#  "Moloka'i",
#  'Sun.Star',
#  'year.The',
#  'Rosé',
#  'SchaeffersResearch.com',
#  "Amp'd",
#  'WAVY.com',
#  'Newswire.com',
#  'communiqués',
#  'S.Korean',
#  'Ordoñez',
#  'index.php',
#  "Ka'aihue",
#  "Ba'athists",
#  "we'll",
#  'GasBuddy.com',
#  'IndiaMART.com',
#  'Sat.',
#  'ESPNNewYork.com',
#  "Ba'athist",
#  "O'Kelley",
#  'espn.com',
#  'CIO.com',
#  'Change.org',
#  "O'Laughlin",
#  'dot.com',
#  'NADAguides.com',
#  "So'oialo",
#  'João',
#  'Deadline.com',
#  "Why'd",
#  'mlb.com',
#  'aol.com',
#  'HollywoodNews.com',
#  'freep.com',
#  "what'sa",
#  'Doğan',
#  'www.',
#  "B'way",
#  'BestBuy.com',
#  'Orbitz.com',
#  'AXcessNews.Com',
#  'Škoda',
#  'οn',
#  'Rediff.com',
#  'KickOff.com',
#  'co.uk',
#  'China.com',
#  'Disney.com',
#  "'VE",
#  'jalapeños',
#  'COS.',
#  'Bernabéu',
#  'ingénue',
#  'Gérard',
#  'Amazon.Com',
#  'worldā',
#  'www.the',
#  'no.',
#  'Márquez',
#  'Velázquez',
#  'Château',
#  'Investorideas.com',
#  'AmmoLand.com',
#  'Vázquez',
#  'CNET.com',
#  "Wai'anae",
#  'NASCAR.com',
#  'Lulu.com',
#  'Superpages.com',
#  'Dictionary.com',
#  'Points.com',
#  'Almería',
#  'Justin.tv',
#  "Hold'em",
#  "K'naan",
#  'WWD.com',
#  'Napavalleyregister.com',
#  'Vol.',
#  'piñatas',
#  'NJ.com',
#  'Tierramérica',
#  'wfaa.com',
#  'ret.',
#  'DrStockPick.com',
#  'imdb.com',
#  'Gagné',
#  "O'Ree",
#  'ComingSoon.net',
#  'Variety.com',
#  'att.net',
#  "Lihu'e",
#  'CBS.com',
#  'MoneyExpert.com',
#  'Borders.com',
#  'Digg.com',
#  'Hervé',
#  'Molière',
#  'μg',
#  'rediff.com',
#  'Señor',
#  'Hardbeatnews.com',
#  "Ga'Hoole",
#  'WakeUpWalMart.com',
#  'Advocate.com',
#  'ComicBookMovie.com',
#  'Chloé',
#  'Oprah.com',
#  'PriceGrabber.com',
#  'ESPNBoston.com',
#  'Motorsport.com',
#  'ESPNChicago.com',
#  'OrlandoSentinel.com',
#  'GoldenPalace.com',
#  'Richmond.com',
#  'eagletribune.com',
#  "O'Clock",
#  'Lancôme',
#  'NME.com',
#  'Youtube.com',
#  'Entrée',
#  'kgw.com',
#  'usa.com',
#  'ecPulse.com',
#  'Petfinder.com',
#  "n't",
#  'CTV.ca',
#  'Oñate',
#  'Bublé',
#  'Camagüey',
#  'Style.com',
#  'St.Louis',
#  'Crème',
#  'TSN.ca',
#  'Almodóvar',
#  "Ya'll",
#  'MLB.TV',
#  'Pharm.D',
#  'SmallCapInvestor.com',
#  'Thinkfinity.org',
#  'Agency.com',
#  'Weather.com',
#  "O'Mahoney",
#  'TheLadders.com',
#  "they've",
#  'Voices.com',
#  'eDiets.com',
#  ...]

# %% [markdown]
# ### Tokenize data and build vocab

# %%
train = pd.read_csv(train_csv)['question_text'].values.tolist()
test = pd.read_csv(test_csv)['question_text'].values.tolist()
data = train + test

# %%
# %%time
with open(train_csv) as f:
    for l in f:
        l.split()
# Out:
# CPU times: user 878 ms, sys: 12 ms, total: 889 ms
# Wall time: 888 ms

# %%
# %%time
unknown_tokens = []
vocab = Counter()
spacy_en = spacy.load('en')
tokenizer = spacy_en.tokenizer
emb_tokens_set = set(emb_tokens)
for question in data:
    doc = tokenizer(question)
    for token in doc:
        tok_text = token.text
        vocab.update([tok_text])
        if vocab[tok_text] == 1:
            if tok_text not in emb_tokens_set:
                unknown_tokens.append(tok_text)
        
#doc = nlp(u'Apple is looking at buying U.K. startup for $1 billion')
#for token in doc:
#    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
#          token.shape_, token.is_alpha, token.is_stop)
# Out:
# CPU times: user 2min 31s, sys: 243 ms, total: 2min 31s
# Wall time: 2min 30s

# %%
vocab_tokens = dict(vocab.most_common()).keys()

# %%
ttvocab = TokenTypes()
ttvocab(vocab_tokens)
# Out:
# Number of num tokens:  29530
# Number of symbol tokens:  1727
# Number of lowcase tokens:  132699
# Number of upper case tokens:  113484
# Nubmer of capslock tokens:  15169
# Nubmer of merged tokens:  714
#
#
# Freq num tokens:  ['2', '2017', '2018', '1', '3', '10', '5', '4', '12', '6', '100', '20', '7', '12th', '15', '8', '30', '50', '18', '11', '9', '16', '14', '17', '40', '2016', '13', '1st', '25', '0', '10th', '2019', '2nd', '60', 'WW2', '90', '500', '1000', '200', '11th', '3D', '24', '80', '21', '70', '3rd', '19', '2000', '2020', '22']
# Rare num tokens:  ['10–12', '61850', 'Feb-2018', '2200-$2500/mo', '4000/mo', '999999', '450cc', '78.53', '900va', '6740']
#
# Freq symbol tokens:  ['?', ',', '.', '"', '-', ')', '(', '/', "'", '&']
# Rare symbol tokens:  ['τῆς', 'κατὰ', 'τὴν', 'ἡμετέραν', 'χρῆσιν', 'συνηθείας', '=--', '中庸', '中庸之道', '∅⊂']
#
# Freq low tokens:  ['the', 'to', 'a', 'in', 'is', 'of', 'and', 'do', 'are', 'for']
# Rare low tokens:  ['noumber', 'sml', 'sgill', 'jauhar', 'clearly"bad', 'myAIR', 'cybershot', 'ganpat', 'rabels', 'photopicker']
#
# Freq up tokens:  ['What', 'I', 'How', 'Why', 'Is', 'Can', 'Which', 'Do', 'If', 'India']
# Rare up tokens:  ['Dime', 'Entanglements', 'Tamilar', 'Flurry', 'Routines', 'ULTIMATELY', 'Hb', 'Generate', 'Khayami', 'Thetis']
#
# Freq caps tokens:  ['I', 'US', 'USA', 'A', 'JEE', 'TV', 'UK', 'IIT', 'MBA', 'IT']
# Rare caps tokens:  ['IPOS', 'MANAV', 'ICSIL', 'RCZ', 'PPW', 'AOTS', 'THEORETICAL', 'FRAMEWORK', 'EPAM', 'ULTIMATELY']
# Freq merged tokens:  ['_', 'a_n', 'x_2', 'math]\\displaystyle\\int_0^\\infty', 'a_1', 'a_2', '\\log_2', '\\lim_{n', 'math]\\lim_{n', '\\sum_{n=1}^{x', 'x_3', 'x_1', 'math]\\lim_{x\\rightarrow', '\\lim_{x', 'x_k', '\\sum_{i=1}^{\\n', 'p_3', '.bash_profile', 'math]f(x_1,x_2)=\\sqrt[3]{x_1', 'x_2}[/math']

# %% [markdown]
# ### Capslock tokens

# %%
caps_tokens = ttvocab.caps_tokens
emotional_caps_tokens = []
for t in caps_tokens:
    if t not in emb_tokens_set and t.lower() in emb_tokens_set:
        emotional_caps_tokens.append(t)
print(len(emotional_caps_tokens))
# Out:
# 433

# %%
emotional_caps_tokens
# Out:
# ['ENGG',
#  'DUCAT',
#  'BLAT',
#  'IYO',
#  'BODS',
#  'ETHER',
#  'DEMAT',
#  'VOLTE',
#  'SYLLABUS',
#  'NARCOS',
#  'VANI',
#  'VEDAS',
#  'PRELIMS',
#  'ANONYMOUSLY',
#  'ODES',
#  'GOLEM',
#  'RESONANCE',
#  'CEOL',
#  'STUPIDEST',
#  'DISCOM',
#  'DEPR',
#  'BABI',
#  'WASE',
#  'EUCALYPTUS',
#  'GEFORCE',
#  'DUOS',
#  'BIBS',
#  'RATNA',
#  'COPR',
#  'MATHEMATICAL',
#  'QUANT',
#  'HYMEN',
#  'WEKA',
#  'ARTICLESHIP',
#  'NAVEL',
#  'CALCULATE',
#  'GOTRA',
#  'VLOG',
#  'FREQUENCIES',
#  'STANKY',
#  'STANK',
#  'URDU',
#  'CRISPER',
#  'ROSCA',
#  'SMITE',
#  'CLOAK',
#  'SMOK',
#  'ACHEIVEMENTS',
#  'IRRESPONSIBILITY',
#  'PERSISTED',
#  'MEDICORE',
#  'HANGERS',
#  'GASSES',
#  'EXPLAINATION',
#  'COMMAS',
#  'INSITED',
#  'WEBCAMS',
#  'CENSE',
#  'SABOT',
#  'ALLERGENS',
#  'IRRITANTS',
#  'TOXICS',
#  'VOCATION',
#  'INFL',
#  'OLYMPIADS',
#  'JUCHE',
#  'UNWORKABLE',
#  'BRAHMAN',
#  'BLASPHEMING',
#  'COCKSUCKERS',
#  'KINEMATIC',
#  'VISCOSITY',
#  'PREDESTINATION',
#  'KASPERSKY',
#  'ASPIRANTS',
#  'MANAGMENT',
#  'COLLATE',
#  'JOKA',
#  'OCAL',
#  'AMPLIFIER',
#  'ANSD',
#  'POEPLE',
#  'NAMO',
#  'ESCORTS',
#  'EYELASHES',
#  'BIHARI',
#  'YED',
#  'LANDLESS',
#  'MEMORIZE',
#  'SURAH',
#  'REMAP',
#  'DIDNOT',
#  'UTTAR',
#  'PRACTICED',
#  'PREACHED',
#  'ADRESS',
#  'PYRAMIDS',
#  'OLIO',
#  'MUSK',
#  'CUTT',
#  'RATIONALIZE',
#  'COLANDER',
#  'SOLIDWORKS',
#  'HAAR',
#  'JITTERBUG',
#  'ROSSA',
#  'MANGANESE',
#  'BIOME',
#  'IGNEOUS',
#  'UNDEFINED',
#  'NUMERATOR',
#  'TRANSPORTING',
#  'VEDIC',
#  'THET',
#  'THRO',
#  'MONGERING',
#  'SHITHOLE',
#  'BLOWFISH',
#  'JAVASCRIPT',
#  'DOCH',
#  'SKIMMING',
#  'COMMY',
#  'WATU',
#  'CUDS',
#  'CURCUMIN',
#  'TURMERIC',
#  'SGND',
#  'NONVERBAL',
#  'CIVILIZATIONS',
#  'RIYAZ',
#  'MILDLY',
#  'MATHEMATICIAN',
#  'CPUS',
#  'WOTH',
#  'SUPARI',
#  'HELPFULL',
#  'ACCOUSTICS',
#  'CASTRATION',
#  'KASHMIRIS',
#  'PLEBISCITE',
#  'VACATING',
#  'HTACCESS',
#  'CREAMY',
#  'TALEN',
#  'VIOLENTLY',
#  'STUMPS',
#  'PALEO',
#  'KILOMETERS',
#  'DESTRUCTIONS',
#  'HOMINIDS',
#  'INFIDELS',
#  'SPORK',
#  'COMMISION',
#  'SIRAH',
#  'BRAINWASHED',
#  'VAPORIZE',
#  'KNOTTED',
#  'PUSSIES',
#  'PATIL',
#  'NINCOMPOOPS',
#  'ABORTIVE',
#  'MUTILATED',
#  'SIHS',
#  'DEMONETIZATION',
#  'FLIT',
#  'SITTIN',
#  'INSTA',
#  'HOES',
#  'FOURTY',
#  'ANGLED',
#  'CASHLESS',
#  'BIBLIOGRAPHY',
#  'CHARSET',
#  'MATTE',
#  'POLITICANS',
#  'NOTARIZED',
#  'FIREBUG',
#  'COCKSUCKER',
#  'DERMOID',
#  'HARPING',
#  'PANTY',
#  'CHALLAN',
#  'KASAB',
#  'SHAK',
#  'TECNOLOGY',
#  'DIFFERNCE',
#  'OUTCALL',
#  'SPYGATE',
#  'ARCHICAD',
#  'DIOXIDE',
#  'RETRENCH',
#  'INTERGRATED',
#  'COHORTS',
#  'LATIMES',
#  'DROPPER',
#  'PRON',
#  'INFERIOR',
#  'GUESSWORK',
#  'INERTIA',
#  'SQAURE',
#  'RUDRAKSH',
#  'WIERD',
#  'OXIDATION',
#  'IMPOTENT',
#  'GRIME',
#  'TRANSDUCER',
#  'FFMPEG',
#  'ABHIYAN',
#  'HYDROCHLORIC',
#  'ACIDS',
#  'FRICTIONLESS',
#  'FLAKES',
#  'ABSENTIA',
#  'FURTHEST',
#  'YOUVE',
#  'TRAITOROUS',
#  'SAMPARK',
#  'MILLIGRAM',
#  'BONER',
#  'WORSENED',
#  'NAXAL',
#  'SMOTE',
#  'LEAVED',
#  'ALPHABETS',
#  'KHATA',
#  'MUDRA',
#  'AUNTY',
#  'BASELESS',
#  'UNPROVEN',
#  'PLACEMENTS',
#  'SMARTNESS',
#  'PULI',
#  'MIGRATE',
#  'ADULTERY',
#  'NAKBA',
#  'SHAREMARKETS',
#  'WAXING',
#  'SADAR',
#  'TARI',
#  'MOAI',
#  'COWORKERS',
#  'SMOOTHLY',
#  'VALIDITY',
#  'STITCHED',
#  'BREIFLY',
#  'MICROBIOLOGY',
#  'BIOCHEMISTRY',
#  'TABACCO',
#  'DOBERMAN',
#  'PINCHERS',
#  'ALLTIME',
#  'MIRCHI',
#  'MANDIR',
#  'HEMM',
#  'KISHORE',
#  'PSYCOLOGICAL',
#  'REGEX',
#  'LIBERATE',
#  'COALESCE',
#  'CIVILS',
#  'MECHATRONICS',
#  'KUP',
#  'NOTIFICATIONS',
#  'TOMMORROW',
#  'NEPHROLOGY',
#  'SHASTRA',
#  'PRACTICALS',
#  'MOSTEST',
#  'ZIONISM',
#  'JAGRAN',
#  'UNFORSEEN',
#  'AUTONOMOUS',
#  'GURUJI',
#  'UNFILTERED',
#  'ZOOLOGY',
#  'DIZ',
#  'MUKHIYA',
#  'ELECTRONS',
#  'RESPIRATION',
#  'FIBROIDS',
#  'KAFFIRS',
#  'OBOE',
#  'REVIT',
#  'EXCLAMATION',
#  'REFRIGERATORS',
#  'MULTICULTURALISM',
#  'BENEFICAL',
#  'BOOLEAN',
#  'REORDER',
#  'NOOBS',
#  'COMMING',
#  'CATHODE',
#  'DEFINETLY',
#  'ULTIMA',
#  'PROFFESSIONAL',
#  'HANDGUNS',
#  'DESING',
#  'WATERGATE',
#  'ENCLAVE',
#  'FLEAS',
#  'MOTHERFUCKERS',
#  'DEPRIVING',
#  'SPITEFUL',
#  'POTASSIUM',
#  'CYANIDE',
#  'UNAMERICAN',
#  'EARPHONE',
#  'NICER',
#  'TRIGONOMETRIC',
#  'SERVICEMAN',
#  'WHITENESS',
#  'ENDOCRINE',
#  'GLAND',
#  'MASSE',
#  'IMPERIALIST',
#  'UNDYING',
#  'DOUCHEBAGGERY',
#  'BROWSING',
#  'DILDO',
#  'ACNES',
#  'AQUAINTANCE',
#  'CHEAPLY',
#  'THOT',
#  'PRESERVES',
#  'COMPLETENESS',
#  'TRIPHALA',
#  'INU',
#  'MOTUS',
#  'IBIG',
#  'THUMBNAIL',
#  'MAMU',
#  'PSYCHOTHERAPY',
#  'WAVELENGTH',
#  'VACCUM',
#  'BRIGHTENING',
#  'APESHIT',
#  'BEETWEEN',
#  'CHOLA',
#  'LATEX',
#  'TRAPPIST',
#  'FORMULATE',
#  'HYPOTHESES',
#  'DELINK',
#  'JEU',
#  'PATHOLOGISTS',
#  'PROSECUTING',
#  'MAINTAINCE',
#  'CONSUMES',
#  'UNEDUCATED',
#  'OOMPA',
#  'SIMCARD',
#  'DIGUSTING',
#  'RAZER',
#  'VAGINAL',
#  'MADHYA',
#  'ANESTHESIOLOGY',
#  'SINUS',
#  'RESUBMIT',
#  'NEUTRON',
#  'GOURD',
#  'CRAPOLA',
#  'MRAD',
#  'FINASTERIDE',
#  'DEVIATION',
#  'AUDITING',
#  'CHATBOT',
#  'REALEST',
#  'CONTRACEPTIVE',
#  'GOUGED',
#  'PUBIC',
#  'PRIVILAGE',
#  'INSTITUE',
#  'PRIMES',
#  'NITES',
#  'PENETRATE',
#  'NOTARY',
#  'FORBIDS',
#  'SYMBIOSIS',
#  'FINITE',
#  'PLANKS',
#  'ONLIN',
#  'ARCHITECTURES',
#  'PERCENTILE',
#  'GOODISM',
#  'UNDERSERVED',
#  'HINDUISM',
#  'COMPAT',
#  'SPANDEX',
#  'PIROUETTE',
#  'TELUGU',
#  'PAPAD',
#  'OPIOIDS',
#  'HALVED',
#  'GRAMIN',
#  'SEVAK',
#  'ALKANE',
#  'ALKENE',
#  'ALKYNE',
#  'TATKAL',
#  'NUMER',
#  'GMAE',
#  'SHITTING',
#  'BRITCHES',
#  'PAKKA',
#  'REHIRE',
#  'SYRINGES',
#  'FRESHER',
#  'UNEXPLAINED',
#  'GAUSS',
#  'ECONOMICAL',
#  'FINACIAL',
#  'YIELDING',
#  'BERET',
#  'WEND',
#  'CATHOLICISM',
#  'BAPTIZED',
#  'KHADI',
#  'IOCTL',
#  'NOTI',
#  'CONTAGION',
#  'TRANSGENDERS',
#  'ENZYME',
#  'INVERTEBRATES',
#  'BITH',
#  'DECIMATING',
#  'HIJRAH',
#  'LADDU',
#  'SEMEN',
#  'BATHTUB',
#  'SPELLED',
#  'LISH',
#  'MANAV',
#  'THEORETICAL']

# %% [markdown]
# ### Unknown tokens

# %%
unk_vocab = {}
for w in unknown_tokens:
    unk_vocab[w] = vocab[w]
unk_vocab = Counter(unk_vocab)

# %%
print('Total number of tokens: ', sum(vocab.values()))
print('Number of unique tokens: ', len(vocab))
print('Total number of unknown tokens: ', sum(unk_vocab.values()))
print('Number of unique unknown tokens: ', len(unknown_tokens))
print('Percent of unknown tokens: ', 100 * sum(unk_vocab.values())/sum(vocab.values()))
# Out:
# Total number of tokens:  19837964
# Number of unique tokens:  268601
# Total number of unknown tokens:  3986997
# Number of unique unknown tokens:  121310
# Percent of unknown tokens:  20.097813465131804

# %%
unk_common = dict(unk_vocab.most_common())
print('Number of 100 most common unk tokens: ', sum(list(unk_common.values())[:100]))
# Out:
# Number of 100 most common unk tokens:  3749654

# %%
unk_common
# Out:
# {'?': 1440556,
#  'to': 423732,
#  'a': 421001,
#  'of': 347358,
#  'and': 263940,
#  ',': 240502,
#  '.': 99408,
#  '"': 75829,
#  "'s": 73188,
#  '-': 58940,
#  ')': 58022,
#  '(': 55035,
#  '/': 32971,
#  "'": 20582,
#  '2017': 9010,
#  '’s': 8778,
#  '2018': 7589,
#  ':': 7266,
#  '10': 6945,
#  'n’t': 6897,
#  '”': 4035,
#  '“': 4029,
#  '12': 3551,
#  '100': 3062,
#  '20': 2849,
#  '’m': 2683,
#  '12th': 2651,
#  '15': 2384,
#  '!': 2311,
#  '30': 2129,
#  '[': 2039,
#  ']': 2027,
#  '…': 2009,
#  '50': 2007,
#  '18': 1974,
#  '11': 1863,
#  '16': 1512,
#  ';': 1493,
#  '14': 1426,
#  '}': 1425,
#  '17': 1343,
#  '40': 1315,
#  'favourite': 1300,
#  '2016': 1291,
#  '13': 1271,
#  '’ve': 1256,
#  '25': 1185,
#  '10th': 1105,
#  '2019': 1098,
#  'and/or': 1098,
#  '60': 1066,
#  'bitcoin': 1045,
#  'colour': 1022,
#  '{': 993,
#  'centre': 914,
#  '..': 888,
#  '90': 885,
#  'Quorans': 882,
#  '500': 875,
#  '1000': 871,
#  '200': 870,
#  '‘': 861,
#  'cryptocurrency': 856,
#  '11th': 855,
#  'Snapchat': 848,
#  'e.g.': 808,
#  '24': 802,
#  'C++': 750,
#  '’re': 734,
#  '80': 733,
#  '21': 729,
#  'travelling': 724,
#  '70': 701,
#  '19': 693,
#  'counselling': 668,
#  'i.e.': 592,
#  '2000': 553,
#  '2020': 534,
#  '22': 531,
#  '300': 520,
#  'Brexit': 510,
#  'btech': 507,
#  'cryptocurrencies': 506,
#  '23': 504,
#  'blockchain': 491,
#  'behaviour': 485,
#  '35': 477,
#  'upvotes': 451,
#  '150': 449,
#  'programme': 421,
#  'Redmi': 394,
#  'realise': 391,
#  '45': 387,
#  '2015': 385,
#  '26': 384,
#  '28': 380,
#  '75': 375,
#  'defence': 373,
#  'KVPY': 361,
#  'Paytm': 350,
#  '21st': 347,
#  '9/11': 342,
#  '32': 341,
#  '<': 337,
#  '400': 328,
#  '95': 323,
#  'organisation': 321,
#  '27': 316,
#  'grey': 311,
#  '2014': 307,
#  'cancelled': 302,
#  "''": 298,
#  '1.5': 297,
#  '65': 279,
#  '20th': 279,
#  '85': 275,
#  '250': 270,
#  'bitcoins': 268,
#  '99': 267,
#  'honours': 266,
#  '120': 265,
#  'upvote': 259,
#  'learnt': 256,
#  'Ethereum': 255,
#  'licence': 255,
#  '10,000': 252,
#  '55': 244,
#  '5000': 243,
#  '2008': 240,
#  '\xa0': 239,
#  '–': 235,
#  '29': 232,
#  '/math': 231,
#  'colours': 224,
#  '19th': 222,
#  '2012': 221,
#  '360': 221,
#  'mtech': 220,
#  '72': 220,
#  '2013': 218,
#  '1/2': 218,
#  'Whatis': 217,
#  '20s': 217,
#  '2010': 213,
#  'theatre': 212,
#  '600': 208,
#  '1500': 207,
#  'labour': 205,
#  'x^2': 205,
#  '2.5': 203,
#  'aluminium': 193,
#  '10000': 192,
#  '3000': 191,
#  '36': 190,
#  '350': 190,
#  'centres': 187,
#  '--': 186,
#  'favour': 182,
#  'INTJ': 180,
#  '2011': 180,
#  'f(x': 179,
#  '800': 179,
#  '48': 178,
#  '64': 176,
#  '33': 175,
#  'organisations': 172,
#  '31': 172,
#  '180': 172,
#  'Pinterest': 171,
#  '52': 170,
#  'INFJ': 166,
#  'cheque': 166,
#  '3.5': 166,
#  '160': 164,
#  'b.tech': 162,
#  'aadhar': 161,
#  '90s': 160,
#  '100,000': 160,
#  'c++': 158,
#  '38': 155,
#  '80s': 154,
#  '130': 153,
#  '700': 152,
#  '34': 151,
#  'modelling': 151,
#  'Fiverr': 150,
#  'Btech': 150,
#  '110': 149,
#  'judgement': 149,
#  '42': 149,
#  'Xiaomi': 148,
#  '2.0': 147,
#  '10k': 147,
#  '^2': 147,
#  '’ll': 146,
#  '’d': 145,
#  '51': 145,
#  '37': 144,
#  '30s': 143,
#  'Coursera': 143,
#  '98': 141,
#  'coloured': 140,
#  '2009': 140,
#  'Fortnite': 138,
#  '1980s': 138,
#  '18th': 133,
#  'i.e': 132,
#  '2001': 130,
#  'AFCAT': 130,
#  'OnePlus': 130,
#  '2007': 128,
#  'recognise': 128,
#  'Lyft': 127,
#  '1947': 127,
#  'UCEED': 126,
#  'jewellery': 126,
#  '1,000': 126,
#  'B.tech': 125,
#  '4000': 124,
#  '1990': 124,
#  '1984': 124,
#  '1980': 122,
#  '911': 121,
#  '1960s': 120,
#  'WeChat': 120,
#  'practise': 120,
#  'bcom': 120,
#  'vape': 119,
#  'INFP': 118,
#  '39': 114,
#  'analyse': 114,
#  'travelled': 113,
#  '2050': 112,
#  '1945': 112,
#  '2003': 112,
#  'recognised': 112,
#  'Blockchain': 111,
#  'UPSEE': 111,
#  '140': 110,
#  'GDPR': 110,
#  '2002': 110,
#  '0.5': 110,
#  'demonetisation': 109,
#  'neighbour': 108,
#  '125': 108,
#  'programmes': 107,
#  '4.0': 107,
#  '1970s': 107,
#  'Coinbase': 105,
#  '2004': 105,
#  'upvoted': 104,
#  '24/7': 104,
#  'BNBR': 104,
#  'Machedo': 103,
#  'litre': 103,
#  '3.0': 103,
#  'Manaphy': 102,
#  '49': 102,
#  'sulphuric': 102,
#  '93': 101,
#  '1991': 100,
#  '56': 100,
#  '220': 99,
#  'B.E': 99,
#  'neighbours': 98,
#  '—': 98,
#  '53': 98,
#  'tyres': 97,
#  '1990s': 97,
#  'valency': 97,
#  '60s': 97,
#  'Boruto': 96,
#  'selfies': 96,
#  '\\frac': 96,
#  'Udacity': 95,
#  '2005': 95,
#  '96': 95,
#  'ethereum': 95,
#  '6000': 95,
#  '？': 95,
#  '100k': 95,
#  '50k': 95,
#  '6.5': 95,
#  '66': 94,
#  'specialisation': 94,
#  'realised': 94,
#  '62': 93,
#  'DCEU': 93,
#  '1800': 93,
#  '44': 92,
#  '1200': 92,
#  'tyre': 92,
#  '1960': 91,
#  '50,000': 90,
#  '170': 90,
#  'Laravel': 89,
#  '40s': 89,
#  'm/s': 88,
#  '47': 88,
#  '97': 88,
#  '450': 87,
#  'organised': 87,
#  'selfie': 86,
#  'downvote': 86,
#  'traveller': 86,
#  '4.5': 86,
#  '20k': 85,
#  '16th': 84,
#  '20,000': 84,
#  '1080p': 84,
#  'SJWs': 84,
#  'E.g.': 84,
#  '43': 84,
#  '70s': 84,
#  '14th': 83,
#  '1997': 83,
#  '1996': 83,
#  'offence': 83,
#  '365': 82,
#  '13th': 82,
#  '900': 82,
#  '46': 82,
#  '54': 82,
#  '94': 81,
#  '1970': 81,
#  'Qoura': 81,
#  '15th': 81,
#  '1998': 81,
#  'vapour': 81,
#  'litres': 81,
#  '1989': 81,
#  '5.5': 81,
#  '1600': 81,
#  '20000': 80,
#  'AR-15': 80,
#  'M.tech': 80,
#  '1/3': 80,
#  '7.5': 79,
#  '63': 79,
#  '101': 79,
#  'aeroplane': 79,
#  '1940': 79,
#  'fibre': 79,
#  'ICOs': 79,
#  '1/4': 79,
#  '320': 78,
#  '190': 78,
#  '68': 78,
#  '57': 78,
#  '1950': 78,
#  '92': 78,
#  '17th': 78,
#  '2000s': 77,
#  'B.A.': 76,
#  '81': 76,
#  '5,000': 76,
#  '128': 75,
#  '1950s': 75,
#  '2021': 75,
#  '88': 75,
#  'humour': 74,
#  'e.g': 74,
#  '78': 74,
#  '58': 74,
#  '3/4': 73,
#  'CTMU': 73,
#  '1992': 73,
#  'L&T': 73,
#  'civilisation': 73,
#  'utilise': 73,
#  '2006': 73,
#  'JIIT': 73,
#  'hairfall': 73,
#  'LNMIIT': 72,
#  '2030': 72,
#  '69': 72,
#  'INTPs': 71,
#  '61': 71,
#  '2022': 70,
#  'sulphur': 70,
#  'B.E.': 70,
#  '84': 70,
#  '59': 69,
#  '2025': 69,
#  '2/3': 69,
#  'T20': 69,
#  'Zerodha': 69,
#  'A+': 69,
#  'masterbate': 69,
#  '1971': 69,
#  'archaeology': 69,
#  '1999': 69,
#  '2,000': 68,
#  'criticise': 68,
#  '50s': 68,
#  'Upwork': 68,
#  '105': 68,
#  '30k': 68,
#  '1962': 68,
#  '2500': 68,
#  '1994': 67,
#  'Kavalireddi': 67,
#  'neurotypicals': 67,
#  '0.1': 66,
#  'labelled': 66,
#  'organise': 66,
#  '76': 66,
#  'm.tech': 66,
#  '25th': 66,
#  'Xamarin': 66,
#  'adhar': 66,
#  '1993': 66,
#  '87': 66,
#  'Uchiha': 66,
#  '.22': 65,
#  'B.A': 65,
#  '1939': 65,
#  '750': 65,
#  'judgemental': 65,
#  '1/': 65,
#  '17-year': 65,
#  '1948': 64,
#  '1900': 64,
#  'ASOIAF': 64,
#  'INTJs': 64,
#  '1800s': 64,
#  '15k': 64,
#  '30000': 63,
#  '15000': 63,
#  'dreamt': 63,
#  '1930s': 63,
#  '25000': 63,
#  'R&D': 63,
#  'I.e.': 62,
#  'Doklam': 62,
#  '401k': 62,
#  '390': 61,
#  'F-1': 61,
#  'Vajiram': 61,
#  '13-year': 61,
#  'fiitjee': 61,
#  "D'Angelo": 60,
#  'ENTP': 60,
#  'neighbouring': 60,
#  'D&D': 60,
#  '30,000': 60,
#  '1.6': 60,
#  '1857': 60,
#  'Unacademy': 60,
#  'emojis': 60,
#  '\\': 60,
#  '14-year': 59,
#  '40k': 59,
#  'ENFP': 59,
#  'B12': 59,
#  'honour': 59,
#  '1400': 59,
#  '...': 58,
#  '1995': 58,
#  '15-year': 58,
#  '50000': 58,
#  '89': 58,
#  'globalisation': 58,
#  'INFJs': 58,
#  '8.1': 58,
#  '41': 58,
#  'cancelling': 58,
#  'H2SO4': 58,
#  '86': 57,
#  'practising': 57,
#  '77': 57,
#  '1979': 57,
#  '|': 57,
#  'metre': 57,
#  '1300': 57,
#  '74': 57,
#  'numericals': 57,
#  'w/': 56,
#  'AlShamsi': 56,
#  'B1/B2': 56,
#  'behavioural': 56,
#  'Kotlin': 56,
#  'H1-B': 56,
#  'WooCommerce': 56,
#  'MOOC': 55,
#  '83': 55,
#  'MUOET': 55,
#  'chsl': 55,
#  'U.S.A': 55,
#  '1941': 55,
#  'AT&T': 55,
#  '1988': 55,
#  '240': 55,
#  'masterbation': 55,
#  'x^3': 55,
#  'MOOCs': 55,
#  '115': 54,
#  '82': 54,
#  '91': 54,
#  '71': 54,
#  '1967': 54,
#  "5'4": 53,
#  '1973': 53,
#  'AngularJS': 53,
#  'worshipped': 52,
#  'sinx': 52,
#  'F-35': 52,
#  'Bhakts': 52,
#  'HackerRank': 52,
#  '7000': 51,
#  '1.2': 51,
#  '370': 51,
#  'Litecoin': 51,
#  'Snapdeal': 51,
#  '550': 51,
#  'theatres': 50,
#  'worshipping': 50,
#  'Duolingo': 50,
#  'VNIT': 50,
#  '79': 50,
#  '500,000': 50,
#  '200,000': 50,
#  '16-year': 50,
#  'B.SC': 50,
#  'memorise': 50,
#  '67': 49,
#  'U.K': 49,
#  '7.0': 49,
#  '12v': 49,
#  "A2A'd": 49,
#  'PUBG': 49,
#  'Hyperloop': 49,
#  'flavour': 49,
#  '73': 49,
#  '1972': 49,
#  'altcoin': 49,
#  '1986': 49,
#  '1976': 48,
#  '747': 48,
#  'behaviours': 48,
#  'apologise': 48,
#  'y^2': 48,
#  '1080': 48,
#  '165': 48,
#  'J&K': 47,
#  'convolutional': 47,
#  '175': 47,
#  'eLitmus': 47,
#  '1700': 47,
#  '256': 47,
#  'altcoins': 47,
#  'speciality': 47,
#  'Cryptocurrency': 47,
#  '135': 47,
#  '1920s': 46,
#  '3.6': 46,
#  'metres': 46,
#  '25k': 46,
#  '270': 46,
#  'PCMB': 46,
#  'Ryzen': 46,
#  '2100': 46,
#  '1920': 46,
#  'macOS': 46,
#  '650': 46,
#  "5'9": 46,
#  'SRMJEE': 46,
#  'councelling': 45,
#  '1964': 45,
#  '\\sqrt': 44,
#  'Baahubali': 44,
#  '^3': 44,
#  'F-22': 44,
#  '1965': 44,
#  'Zomato': 44,
#  "5'5": 44,
#  'travellers': 44,
#  '12-year': 44,
#  'Amazon.in': 43,
#  '8000': 43,
#  'whisky': 43,
#  '1050': 43,
#  'neighbourhood': 43,
#  '1100': 43,
#  'M.A.': 43,
#  '1969': 42,
#  '5.1': 42,
#  "5'3": 42,
#  'Obito': 42,
#  'analysing': 42,
#  'parlour': 42,
#  '1,000,000': 42,
#  'SGSITS': 42,
#  'j7': 42,
#  'rahu': 42,
#  '6.0': 42,
#  '1812': 42,
#  '108': 42,
#  'iMessage': 42,
#  'Beerus': 42,
#  'MNIT': 42,
#  '145': 41,
#  'M.S.': 41,
#  '1944': 41,
#  'S&P': 41,
#  'h1b': 41,
#  '1982': 41,
#  'coinbase': 41,
#  'Whar': 41,
#  '1987': 41,
#  'B+': 41,
#  'What\u200b': 41,
#  '1968': 41,
#  'a+b': 40,
#  '000': 40,
#  'Howdo': 40,
#  '30th': 40,
#  '3,000': 40,
#  '35000': 40,
#  '1975': 40,
#  'molarity': 40,
#  '2024': 40,
#  '2.4': 40,
#  '31st': 40,
#  'H-1B': 40,
#  'jipmer': 40,
#  '8.5': 39,
#  '155': 39,
#  "5'7": 39,
#  'Q&A': 39,
#  "5'2": 39,
#  '23rd': 39,
#  '1900s': 39,
#  'rumours': 39,
#  '9000': 39,
#  '380': 39,
#  '666': 39,
#  'M.A': 39,
#  'BMSCE': 38,
#  'cisgender': 38,
#  'Gurugram': 38,
#  '40000': 38,
#  'bahubali': 38,
#  "5'6": 38,
#  'Whatare': 38,
#  'MeToo': 38,
#  'aeroplanes': 38,
#  'Binance': 38,
#  'A.I.': 38,
#  '520': 38,
#  'armour': 37,
#  'cosx': 37,
#  '118': 37,
#  'Rhaegar': 37,
#  '1974': 37,
#  '420': 37,
#  '103': 37,
#  '1930': 37,
#  '60k': 37,
#  'M.S': 37,
#  'SRMJEEE': 37,
#  'Zebpay': 37,
#  '22nd': 37,
#  'PDPU': 37,
#  '1985': 37,
#  '102': 37,
#  'ageing': 37,
#  'Truecaller': 37,
#  'Swachh': 36,
#  'masterbating': 36,
#  'upvoting': 36,
#  '1940s': 36,
#  "5'10": 36,
#  'odour': 36,
#  '310': 36,
#  'josaa': 36,
#  'lpa': 36,
#  'AK-47': 36,
#  '1060': 36,
#  '1.8': 35,
#  '29th': 35,
#  '330': 35,
#  '3500': 35,
#  '2017/18': 35,
#  'downvotes': 35,
#  '1933': 35,
#  '100000': 35,
#  'Golang': 35,
#  '1963': 35,
#  'R15': 35,
#  '230': 35,
#  '\\math': 35,
#  '1936': 35,
#  'empaths': 35,
#  '210': 35,
#  'OBOR': 34,
#  'colonisation': 34,
#  'litecoin': 34,
#  'organisational': 34,
#  'M&A': 34,
#  'km/h': 34,
#  'ww1': 34,
#  "5'8": 34,
#  'formulae': 34,
#  '40,000': 34,
#  '60,000': 34,
#  'friendzoned': 34,
#  '06': 33,
#  '1.3': 33,
#  'clickbait': 33,
#  'Roblox': 33,
#  'upwork': 33,
#  'I.e': 33,
#  'arihant': 33,
#  '2010s': 33,
#  'iisc': 33,
#  '1983': 33,
#  'friendzone': 33,
#  'B.S.': 33,
#  'Euron': 33,
#  'practised': 33,
#  'mastrubation': 33,
#  'MHCET': 33,
#  '\\infty': 33,
#  'counsellor': 33,
#  'TensorFlow': 32,
#  'gaslighting': 32,
#  '3.8': 32,
#  'IITK': 32,
#  'node.js': 32,
#  '0.2': 32,
#  '^n': 32,
#  "5'11": 32,
#  'Google+': 32,
#  '111': 32,
#  'colonise': 32,
#  'e^x': 32,
#  'A-10': 32,
#  '25,000': 32,
#  'Sharingan': 32,
#  'acknowledgement': 32,
#  '126': 32,
#  'playstore': 32,
#  '3.2': 32,
#  'mould': 31,
#  'Quora.com': 31,
#  '280': 31,
#  '12V': 31,
#  'moustache': 31,
#  '104': 31,
#  '.what': 31,
#  '12000': 31,
#  '2-year': 31,
#  '107': 31,
#  'MS-13': 31,
#  '24th': 31,
#  'maximise': 31,
#  'fibres': 31,
#  '1966': 31,
#  '1981': 31,
#  'CDSE': 31,
#  ':(': 31,
#  'Chromecast': 31,
#  '777': 31,
#  '10-year': 31,
#  '117': 31,
#  'Greyjoy': 31,
#  'y=': 30,
#  '1917': 30,
#  'cheques': 30,
#  'Adhaar': 30,
#  '1914': 30,
#  '500k': 30,
#  '1.4': 30,
#  'addmission': 30,
#  'smartwatch': 30,
#  'judgements': 30,
#  'Kasol': 30,
#  '4-year': 30,
#  'PESSAT': 30,
#  '900k': 30,
#  'O+': 30,
#  'g(x': 30,
#  'nationalised': 30,
#  'NodeJS': 30,
#  'GoFundMe': 30,
#  'u.s': 30,
#  '1935': 29,
#  'adhaar': 29,
#  '50/50': 29,
#  'demonitisation': 29,
#  'axe': 29,
#  'psycopath': 29,
#  'civilised': 29,
#  '50th': 29,
#  '51st': 29,
#  'downvoted': 29,
#  "y'": 29,
#  'realising': 29,
#  'x^4': 29,
#  'socialise': 29,
#  'minimise': 29,
#  'cryptos': 29,
#  'Koinex': 29,
#  'x-1': 29,
#  'metoo': 29,
#  '737': 29,
#  'INFPs': 29,
#  '9.5': 29,
#  'LBSNAA': 29,
#  '\\int': 29,
#  'Galgotia': 29,
#  '3310': 29,
#  'dependant': 28,
#  'LGBT+': 28,
#  'JOSAA': 28,
#  '5-year': 28,
#  '.45': 28,
#  'x-2': 28,
#  '123': 28,
#  'MIUI': 28,
#  '15,000': 28,
#  '132': 28,
#  '3.7': 28,
#  'LGBTQ+': 28,
#  'favours': 28,
#  '401': 28,
#  '1700s': 28,
#  '5.6': 28,
#  'Patreon': 28,
#  'legalised': 28,
#  '8.0': 28,
#  'unacademy': 28,
#  '10x': 28,
#  '.I': 28,
#  'w/o': 28,
#  'US$': 28,
#  'hyperloop': 28,
#  '1937': 27,
#  'haemoglobin': 27,
#  'mahadasha': 27,
#  '189': 27,
#  'A380': 27,
#  'intership': 27,
#  'microservices': 27,
#  '720': 27,
#  'K-12': 27,
#  'Whst': 27,
#  'non-': 27,
#  'PSIR': 27,
#  'A&M': 27,
#  'Hiw': 27,
#  '1918': 27,
#  '8)': 27,
#  'colonised': 27,
#  'Quara': 27,
#  'M.SC': 27,
#  'favourable': 27,
#  '480': 27,
#  '5.7': 27,
#  'fortnite': 27,
#  'USICT': 27,
#  '172': 27,
#  'ReactJS': 27,
#  '1942': 27,
#  'realisation': 27,
#  'authorised': 27,
#  'isomerism': 27,
#  '19-year': 27,
#  'factorise': 27,
#  'analyses': 26,
#  '1922': 26,
#  '35k': 26,
#  '1956': 26,
#  '2x^2': 26,
#  '2.7': 26,
#  'H+': 26,
#  'x+1': 26,
#  '1.0': 26,
#  '1949': 26,
#  'lpu': 26,
#  '1919': 26,
#  '2.8': 26,
#  '1099': 26,
#  '340': 26,
#  '300,000': 26,
#  '109': 26,
#  '144': 26,
#  '1911': 26,
#  '18-year': 26,
#  'Zamasu': 26,
#  'x=0': 26,
#  '440': 26,
#  'nootropics': 26,
#  '\\sum': 26,
#  '200k': 26,
#  'mc^2': 25,
#  'B.Des': 25,
#  'Codeforces': 25,
#  '156': 25,
#  '64-bit': 25,
#  'Gamora': 25,
#  'brexit': 25,
#  'Fiitjee': 25,
#  'A-': 25,
#  '1:1': 25,
#  '225': 25,
#  'ACIO': 25,
#  '1776': 25,
#  'pisces': 25,
#  'Trumpcare': 25,
#  '163': 25,
#  '28th': 25,
#  'benzoic': 25,
#  'Aliexpress': 25,
#  'PhD.': 25,
#  '152': 25,
#  '5.0': 25,
#  'Bittrex': 25,
#  'Irodov': 25,
#  '32-bit': 25,
#  'FTRE': 25,
#  'tensorflow': 25,
#  '\\left': 25,
#  'specialised': 25,
#  'dysfuntional': 24,
#  'b.ed': 24,
#  'M.E': 24,
#  '106': 24,
#  'colourful': 24,
#  'Tensorflow': 24,
#  'spoilt': 24,
#  '3x^2': 24,
#  'organising': 24,
#  'a.k.a': 24,
#  'ENFPs': 24,
#  'i20': 24,
#  'Demonetization': 24,
#  '99.9': 24,
#  'CodeChef': 24,
#  '3.1': 24,
#  '3-D': 24,
#  '410': 24,
#  '301': 24,
#  '2400': 24,
#  '127': 24,
#  '250,000': 24,
#  'PewDiePie': 24,
#  'customised': 24,
#  'Simpliv': 24,
#  '1070': 24,
#  'coc': 24,
#  'Howcan': 24,
#  'Howto': 24,
#  'DAVV': 24,
#  '540': 24,
#  'iitjee': 24,
#  '560': 24,
#  '112': 24,
#  '153': 24,
#  '1978': 24,
#  'watsapp': 24,
#  '185': 24,
#  '₹': 24,
#  '2049': 24,
#  '260': 24,
#  'e^': 24,
#  '300k': 24,
#  'freelancer.com': 24,
#  '999': 24,
#  'Monero': 24,
#  'JoSAA': 24,
#  'criticised': 24,
#  '\\to': 24,
#  'OneDrive': 24,
#  '27th': 24,
#  '\\right': 24,
#  'F-16': 24,
#  '512': 24,
#  '.How': 24,
#  'AR15': 23,
#  '70000': 23,
#  'NLUs': 23,
#  '124': 23,
#  'femdom': 23,
#  'Vegito': 23,
#  '2023': 23,
#  '℅': 23,
#  'Tarly': 23,
#  'E.g': 23,
#  'MHTCET': 23,
#  '0.01': 23,
#  'ethanoic': 23,
#  'IIITH': 23,
#  'Howmuch': 23,
#  'y.o': 23,
#  'IGDTUW': 23,
#  '^1/2': 23,
#  '2.6': 23,
#  '3.3': 23,
#  ...}

# %%
ttunk = TokenTypes()
ttunk(list(unk_common.keys()))
# Out:
# Number of num tokens:  28150
# Number of symbol tokens:  1563
# Number of lowcase tokens:  63525
# Number of upper case tokens:  36140
# Nubmer of capslock tokens:  3458
# Nubmer of merged tokens:  708
#
#
# Freq num tokens:  ['2017', '2018', '10', '12', '100', '20', '12th', '15', '30', '50', '18', '11', '16', '14', '17', '40', '2016', '13', '25', '10th', '2019', '60', '90', '500', '1000', '200', '11th', '24', '80', '21', '70', '19', '2000', '2020', '22', '300', '23', '35', '150', '45', '2015', '26', '28', '75', '21st', '9/11', '32', '400', '95', '27']
# Rare num tokens:  ['10–12', '61850', 'Feb-2018', '2200-$2500/mo', '4000/mo', '999999', '450cc', '78.53', '900va', '6740']
#
# Freq symbol tokens:  ['?', ',', '.', '"', '-', ')', '(', '/', "'", ':']
# Rare symbol tokens:  ['τῆς', 'κατὰ', 'τὴν', 'ἡμετέραν', 'χρῆσιν', 'συνηθείας', '=--', '中庸', '中庸之道', '∅⊂']
#
# Freq low tokens:  ['to', 'a', 'of', 'and', 'n’t', 'favourite', 'and/or', 'bitcoin', 'colour', 'centre']
# Rare low tokens:  ['enrollnment', 'noumber', 'sgill', 'jauhar', 'clearly"bad', 'myAIR', 'cybershot', 'ganpat', 'rabels', 'photopicker']
#
# Freq up tokens:  ['Quorans', 'Snapchat', 'C++', 'Brexit', 'Redmi', 'KVPY', 'Paytm', 'Ethereum', 'Whatis', 'INTJ']
# Rare up tokens:  ['Kiccha', 'Bhangani', 'GS-', 'Magick++', 'NotJesseChen', 'THEORETICAL', 'Sakoku', 'Question(JQ', 'Feb-2018', 'Minesotan']
#
# Freq caps tokens:  ['KVPY', 'INTJ', 'INFJ', 'AFCAT', 'UCEED', 'INFP', 'UPSEE', 'GDPR', 'BNBR', 'DCEU']
# Rare caps tokens:  ['SPCOMM', 'SPELLED', 'LISH', 'COMPTIA', 'SPJIMSR', 'OPENCAPI', 'HYSPM', 'MANAV', 'ICSIL', 'THEORETICAL']
# Freq merged tokens:  ['a_n', 'x_2', 'math]\\displaystyle\\int_0^\\infty', 'a_1', 'a_2', '\\log_2', '\\lim_{n', 'math]\\lim_{n', '\\sum_{n=1}^{x', 'x_3', 'x_1', 'math]\\lim_{x\\rightarrow', '\\lim_{x', 'x_k', '\\sum_{i=1}^{\\n', 'p_3', '.bash_profile', 'math]f(x_1,x_2)=\\sqrt[3]{x_1', 'x_2}[/math', 'j_ws']

# %%
ttunk.num_tokens
# Out:
# ['2017',
#  '2018',
#  '10',
#  '12',
#  '100',
#  '20',
#  '12th',
#  '15',
#  '30',
#  '50',
#  '18',
#  '11',
#  '16',
#  '14',
#  '17',
#  '40',
#  '2016',
#  '13',
#  '25',
#  '10th',
#  '2019',
#  '60',
#  '90',
#  '500',
#  '1000',
#  '200',
#  '11th',
#  '24',
#  '80',
#  '21',
#  '70',
#  '19',
#  '2000',
#  '2020',
#  '22',
#  '300',
#  '23',
#  '35',
#  '150',
#  '45',
#  '2015',
#  '26',
#  '28',
#  '75',
#  '21st',
#  '9/11',
#  '32',
#  '400',
#  '95',
#  '27',
#  '2014',
#  '1.5',
#  '65',
#  '20th',
#  '85',
#  '250',
#  '99',
#  '120',
#  '10,000',
#  '55',
#  '5000',
#  '2008',
#  '29',
#  '19th',
#  '2012',
#  '360',
#  '72',
#  '2013',
#  '1/2',
#  '20s',
#  '2010',
#  '600',
#  '1500',
#  'x^2',
#  '2.5',
#  '10000',
#  '3000',
#  '36',
#  '350',
#  '2011',
#  '800',
#  '48',
#  '64',
#  '33',
#  '31',
#  '180',
#  '52',
#  '3.5',
#  '160',
#  '90s',
#  '100,000',
#  '38',
#  '80s',
#  '130',
#  '700',
#  '34',
#  '110',
#  '42',
#  '2.0',
#  '10k',
#  '^2',
#  '51',
#  '37',
#  '30s',
#  '98',
#  '2009',
#  '1980s',
#  '18th',
#  '2001',
#  '2007',
#  '1947',
#  '1,000',
#  '4000',
#  '1990',
#  '1984',
#  '1980',
#  '911',
#  '1960s',
#  '39',
#  '2050',
#  '1945',
#  '2003',
#  '140',
#  '2002',
#  '0.5',
#  '125',
#  '4.0',
#  '1970s',
#  '2004',
#  '24/7',
#  '3.0',
#  '49',
#  '93',
#  '1991',
#  '56',
#  '220',
#  '53',
#  '1990s',
#  '60s',
#  '2005',
#  '96',
#  '6000',
#  '100k',
#  '50k',
#  '6.5',
#  '66',
#  '62',
#  '1800',
#  '44',
#  '1200',
#  '1960',
#  '50,000',
#  '170',
#  '40s',
#  '47',
#  '97',
#  '450',
#  '4.5',
#  '20k',
#  '16th',
#  '20,000',
#  '1080p',
#  '43',
#  '70s',
#  '14th',
#  '1997',
#  '1996',
#  '365',
#  '13th',
#  '900',
#  '46',
#  '54',
#  '94',
#  '1970',
#  '15th',
#  '1998',
#  '1989',
#  '5.5',
#  '1600',
#  '20000',
#  'AR-15',
#  '1/3',
#  '7.5',
#  '63',
#  '101',
#  '1940',
#  '1/4',
#  '320',
#  '190',
#  '68',
#  '57',
#  '1950',
#  '92',
#  '17th',
#  '2000s',
#  '81',
#  '5,000',
#  '128',
#  '1950s',
#  '2021',
#  '88',
#  '78',
#  '58',
#  '3/4',
#  '1992',
#  '2006',
#  '2030',
#  '69',
#  '61',
#  '2022',
#  '84',
#  '59',
#  '2025',
#  '2/3',
#  'T20',
#  '1971',
#  '1999',
#  '2,000',
#  '50s',
#  '105',
#  '30k',
#  '1962',
#  '2500',
#  '1994',
#  '0.1',
#  '76',
#  '25th',
#  '1993',
#  '87',
#  '.22',
#  '1939',
#  '750',
#  '1/',
#  '17-year',
#  '1948',
#  '1900',
#  '1800s',
#  '15k',
#  '30000',
#  '15000',
#  '1930s',
#  '25000',
#  '401k',
#  '390',
#  'F-1',
#  '13-year',
#  '30,000',
#  '1.6',
#  '1857',
#  '14-year',
#  '40k',
#  'B12',
#  '1400',
#  '1995',
#  '15-year',
#  '50000',
#  '89',
#  '8.1',
#  '41',
#  'H2SO4',
#  '86',
#  '77',
#  '1979',
#  '1300',
#  '74',
#  'B1/B2',
#  'H1-B',
#  '83',
#  '1941',
#  '1988',
#  '240',
#  'x^3',
#  '115',
#  '82',
#  '91',
#  '71',
#  '1967',
#  "5'4",
#  '1973',
#  'F-35',
#  '7000',
#  '1.2',
#  '370',
#  '550',
#  '79',
#  '500,000',
#  '200,000',
#  '16-year',
#  '67',
#  '7.0',
#  '12v',
#  "A2A'd",
#  '73',
#  '1972',
#  '1986',
#  '1976',
#  '747',
#  'y^2',
#  '1080',
#  '165',
#  '175',
#  '1700',
#  '256',
#  '135',
#  '1920s',
#  '3.6',
#  '25k',
#  '270',
#  '2100',
#  '1920',
#  '650',
#  "5'9",
#  '1964',
#  '^3',
#  'F-22',
#  '1965',
#  "5'5",
#  '12-year',
#  '8000',
#  '1050',
#  '1100',
#  '1969',
#  '5.1',
#  "5'3",
#  '1,000,000',
#  'j7',
#  '6.0',
#  '1812',
#  '108',
#  '145',
#  '1944',
#  'h1b',
#  '1982',
#  '1987',
#  '1968',
#  '000',
#  '30th',
#  '3,000',
#  '35000',
#  '1975',
#  '2024',
#  '2.4',
#  '31st',
#  'H-1B',
#  '8.5',
#  '155',
#  "5'7",
#  "5'2",
#  '23rd',
#  '1900s',
#  '9000',
#  '380',
#  '666',
#  '40000',
#  "5'6",
#  '520',
#  '118',
#  '1974',
#  '420',
#  '103',
#  '1930',
#  '60k',
#  '22nd',
#  '1985',
#  '102',
#  '1940s',
#  "5'10",
#  '310',
#  'AK-47',
#  '1060',
#  '1.8',
#  '29th',
#  '330',
#  '3500',
#  '2017/18',
#  '1933',
#  '100000',
#  '1963',
#  'R15',
#  '230',
#  '1936',
#  '210',
#  'ww1',
#  "5'8",
#  '40,000',
#  '60,000',
#  '06',
#  '1.3',
#  '2010s',
#  '1983',
#  '3.8',
#  '0.2',
#  "5'11",
#  '111',
#  'A-10',
#  '25,000',
#  '126',
#  '3.2',
#  '280',
#  '12V',
#  '104',
#  '12000',
#  '2-year',
#  '107',
#  'MS-13',
#  '24th',
#  '1966',
#  '1981',
#  '777',
#  '10-year',
#  '117',
#  '1917',
#  '1914',
#  '500k',
#  '1.4',
#  '4-year',
#  '900k',
#  '1935',
#  '50/50',
#  '50th',
#  '51st',
#  'x^4',
#  'x-1',
#  '737',
#  '9.5',
#  '3310',
#  '5-year',
#  '.45',
#  'x-2',
#  '123',
#  '15,000',
#  '132',
#  '3.7',
#  '401',
#  '1700s',
#  '5.6',
#  '8.0',
#  '10x',
#  '1937',
#  '189',
#  'A380',
#  '720',
#  'K-12',
#  '1918',
#  '8)',
#  '480',
#  '5.7',
#  '172',
#  '1942',
#  '19-year',
#  '1922',
#  '35k',
#  '1956',
#  '2x^2',
#  '2.7',
#  'x+1',
#  '1.0',
#  '1949',
#  '1919',
#  '2.8',
#  '1099',
#  '340',
#  '300,000',
#  '109',
#  '144',
#  '1911',
#  '18-year',
#  'x=0',
#  '440',
#  '200k',
#  'mc^2',
#  '156',
#  '64-bit',
#  '1:1',
#  '225',
#  '1776',
#  '163',
#  '28th',
#  '152',
#  '5.0',
#  '32-bit',
#  '106',
#  '3x^2',
#  'i20',
#  '99.9',
#  '3.1',
#  '3-D',
#  '410',
#  '301',
#  '2400',
#  '127',
#  '250,000',
#  '1070',
#  '540',
#  '560',
#  '112',
#  '153',
#  '1978',
#  '185',
#  '2049',
#  '260',
#  '300k',
#  '999',
#  '27th',
#  'F-16',
#  '512',
#  'AR15',
#  '70000',
#  '124',
#  '2023',
#  '0.01',
#  '^1/2',
#  '2.6',
#  '3.3',
#  '4/5',
#  '640',
#  '0,1',
#  'G20',
#  '26th',
#  '3.4',
#  '1/x',
#  '720p',
#  '4.2',
#  '195',
#  '168',
#  '162',
#  '2.1',
#  '16000',
#  '555',
#  "6'1",
#  '6500',
#  '220V',
#  's^2',
#  '457',
#  '01',
#  '290',
#  '1955',
#  '121',
#  'a^2',
#  'Bet365',
#  '60000',
#  "6'2",
#  '122',
#  '.50',
#  '401(k',
#  '2040',
#  '16.04',
#  '10.5',
#  '430',
#  '8086',
#  '7500',
#  '3/5',
#  '133',
#  'F35',
#  '0.05',
#  '113',
#  '3.14',
#  '8051',
#  '138',
#  '325',
#  '23andMe',
#  '1929',
#  'h2so4',
#  '14k',
#  '510',
#  '1957',
#  '3.9',
#  '154',
#  '2.2',
#  '186',
#  '760',
#  '1.7',
#  '2/5',
#  '17000',
#  '26/11',
#  '950',
#  '149',
#  '18000',
#  '1943',
#  '4.1',
#  '1024',
#  '6.1',
#  'A6000',
#  '70k',
#  '80k',
#  '336',
#  '1,500',
#  '20-year',
#  '158',
#  '02',
#  '787',
#  '201',
#  '1,2',
#  '139',
#  '1/5',
#  '6/6',
#  '131',
#  '303',
#  '/2',
#  '2200',
#  '2.3',
#  '55k',
#  '.30',
#  '811',
#  '1946',
#  '2600',
#  '630',
#  '1924',
#  '136',
#  '1/8',
#  '11000',
#  '1958',
#  '1-year',
#  '0.3',
#  '116',
#  '8,000',
#  '20/20',
#  'D3300',
#  '305',
#  '200000',
#  '18k',
#  '45k',
#  '12k',
#  '580',
#  '3200',
#  '6.2',
#  '1.9',
#  '730',
#  '1927',
#  '1861',
#  '6-year',
#  '2017/2018',
#  '182',
#  '1905',
#  '1953',
#  'M16',
#  '4x4',
#  '1.1',
#  '4500',
#  '3600',
#  '150k',
#  'n+1',
#  'x-3',
#  '9.8',
#  '1910',
#  'I-20',
#  '129',
#  '114',
#  '315',
#  '333',
#  '489',
#  '220v',
#  '530',
#  '100s',
#  '1860',
#  '65k',
#  '16k',
#  '7.6',
#  '80,000',
#  '0.25',
#  '1/n',
#  '0.9',
#  '1907',
#  '99.99',
#  '4,000',
#  '04',
#  '198',
#  '1Z0',
#  '148',
#  '322',
#  '11-year',
#  '0.6',
#  '1600s',
#  '8.2',
#  '1850',
#  '176',
#  '167',
#  '100th',
#  "6'4",
#  '2026',
#  '610',
#  '12.5',
#  '141',
#  '150,000',
#  '22-year',
#  'class11',
#  '157',
#  '500ml',
#  '529',
#  '6.8',
#  '75th',
#  '7.1',
#  '616',
#  '1450',
#  '1865',
#  '45th',
#  '1/6',
#  '0/0',
#  '620',
#  '1934',
#  '90k',
#  '2k17',
#  '.308',
#  '8085',
#  '870',
#  '202',
#  '400,000',
#  '=3',
#  "5'1",
#  '1952',
#  '404',
#  'D5200',
#  '11:11',
#  'PG-13',
#  '5.3',
#  '1913',
#  '1977',
#  '164',
#  'i10',
#  '925',
#  '24-hour',
#  '1.25',
#  'b^2',
#  '4.4',
#  '1=2',
#  '460',
#  '7400',
#  '134',
#  '740',
#  '7.2',
#  '786',
#  '166',
#  '4.8',
#  '30-year',
#  '235',
#  'H20',
#  '5.4',
#  '2x-1',
#  'RS200',
#  'MH370',
#  '731',
#  '22/7',
#  '1.00',
#  '240v',
#  'dream11',
#  '.38',
#  'CaCl2',
#  '2-in-1',
#  '142',
#  '2-',
#  '1954',
#  '7,000',
#  '504',
#  '143',
#  '188',
#  '323',
#  '1931',
#  'F22',
#  '245',
#  '0.8',
#  '13000',
#  '0.7',
#  '490',
#  '2,500',
#  '1959',
#  '1789',
#  '1862',
#  '11k',
#  '9.7',
#  '1961',
#  '32bit',
#  '1925',
#  '8-year',
#  '213',
#  '6,000',
#  '125cc',
#  '1750',
#  'Dream11',
#  '309',
#  'CS50',
#  '08',
#  '850',
#  '12,000',
#  '710',
#  'x+2',
#  'D7200',
#  '.410',
#  '1000s',
#  '275',
#  '6.3',
#  'k6',
#  '1921',
#  '7567',
#  '9.0',
#  '45,000',
#  '1[/math',
#  '2.9',
#  '146',
#  '45000',
#  '311',
#  '318',
#  '3-year',
#  'MH17',
#  'I-130',
#  '151',
#  '24v',
#  '137',
#  '.357',
#  '2028',
#  '570',
#  'n-1',
#  '2027',
#  '171',
#  '22k',
#  '70,000',
#  '4.6',
#  '23k',
#  '25-year',
#  '306',
#  '14000',
#  '80/20',
#  '24k',
#  '1916',
#  '9.4',
#  '960',
#  '6400',
#  '7.62',
#  '1520',
#  '780',
#  '5.2',
#  'A320',
#  '21000',
#  '255',
#  '1350',
#  '500000',
#  '205',
#  '1932',
#  '7-year',
#  '375',
#  '21-year',
#  '.25',
#  'B-52',
#  '9.2',
#  '219',
#  '196',
#  '476',
#  'ww3',
#  'X^2',
#  '2.00',
#  '03',
#  '700,000',
#  '100/100',
#  '4600',
#  '625',
#  'M1A2',
#  '80000',
#  '35,000',
#  "CAT'17",
#  '2x+1',
#  '173',
#  '451',
#  '304',
#  '4x^3',
#  '10years',
#  '27000',
#  '7700k',
#  '1906',
#  '174',
#  '24000',
#  '75k',
#  '194',
#  '1+x',
#  '23-year',
#  '12.9',
#  'HQ2',
#  '241',
#  '3/8',
#  '26k',
#  'KMnO4',
#  '2x^3',
#  '2800',
#  '223',
#  '5.1.1',
#  '660',
#  '183',
#  'sin^2',
#  '215',
#  '5.8',
#  '1/10',
#  '10/10',
#  '/3',
#  '99.5',
#  'FZ25',
#  '366',
#  '1440',
#  '221',
#  'a^3',
#  '2^x',
#  'NaHCO3',
#  '15.6',
#  '7/8',
#  'Na2CO3',
#  '0.4',
#  '0[/math',
#  'SR-71',
#  '1877',
#  '222',
#  '1763',
#  '273',
#  'Cl2',
#  'J-1',
#  '5’3',
#  '327',
#  '1915',
#  '17k',
#  '50hz',
#  'c^2',
#  '486',
#  '22000',
#  '5400',
#  '5.56',
#  'F16',
#  '216',
#  'S400',
#  '1928',
#  'A350',
#  '285',
#  'H2O2',
#  '1938',
#  '2060',
#  '150cc',
#  '499',
#  '9.6',
#  '2300',
#  '√2',
#  '8.6',
#  '203',
#  'x86',
#  '24hrs',
#  '64bit',
#  '206',
#  '1.50',
#  '1923',
#  '535',
#  '250k',
#  '6:30',
#  '13k',
#  'x+3',
#  '308',
#  '501',
#  'class9',
#  '236',
#  '159',
#  '263',
#  'U-17',
#  '2:1',
#  'B-2',
#  '0,0',
#  '835',
#  '169',
#  '3:00',
#  'AK47',
#  '147',
#  '200cc',
#  '4.9',
#  'GE14',
#  '184',
#  '1898',
#  'T-34',
#  'Sense8',
#  '6.0.1',
#  '242',
#  '335',
#  '545',
#  '217',
#  'k-1',
#  'I-140',
#  '.44',
#  'kmno4',
#  '60fps',
#  '1300D',
#  '1000000',
#  '130,000',
#  '212',
#  '7plus',
#  '9-year',
#  '65,000',
#  '0.75',
#  '00',
#  '6.6',
#  '82nd',
#  '11.5',
#  '5500',
#  '295',
#  '498',
#  '-20',
#  '1951',
#  'D5100',
#  '2k18',
#  "6'5",
#  ...]

# %% [markdown]
# ### custom tokenisation

# %%
num_symb_re = re.compile('^[^a-zA-Z]*[0-9]+[^a-zA-Z]*$')

# %%
num_alpha_re = re.compile('^[0-9]+[a-zA-Z]+$')

# %%
one_symb_re = re.compile('^[a-zA-Z]*[^0-9a-zA-Z][a-zA-Z]*$')

# %%
one_symb_re.match('!')
# Out:
# <_sre.SRE_Match object; span=(0, 1), match='!'>

# %%
def tokenize_numbers(tok):
    num_symb_re = re.compile('^[^a-zA-Z]*[0-9]+[^a-zA-Z]*$')
    sub_re = re.compile('[0-9]')
    if num_symb_re.match(tok) and len(tok) > 1:
        tok = sub_re.sub('#', tok)
    return tok

# %%
def tokenize_numbers(tok):
    num_symb_re = re.compile('^[^a-zA-Z]*[0-9]+[^a-zA-Z]*$')
    sub_re = re.compile('[0-9]')
    num_alpha_re = re.compile('^[0-9][0-9]+[a-zA-Z]+$')
    split_re = 
    if num_symb_re.match(tok) and len(tok) > 1:
        tok = sub_re.sub('#', tok)
    if num_alpha_repha_re.match(tok):
        split_re
    return tok

# %%
tokenize_numbers('23.23')
# Out:
# '##.##'

# %%
re.sub('[0-9]', '#', '2aa')
# Out:
# '#aa'

# %%
# %%time
unknown_tokens = []
vocab = Counter()
spacy_en = spacy.load('en')
tokenizer = spacy_en.tokenizer
emb_tokens_set = set(emb_tokens)
num_symb_re = re.compile('^[^a-zA-Z]*[0-9]+[^a-zA-Z]*$')
sub_re = re.compile('[0-9]')
for question in data:
    doc = tokenizer(question)
    for token in doc:
        tok_text = token.text
        if num_symb_re.match(tok_text) and len(tok_text) > 1:
            tok_text = sub_re.sub('#', tok_text)
        vocab.update([tok_text])
        if vocab[tok_text] == 1:
            if tok_text not in emb_tokens_set:
                unknown_tokens.append(tok_text)
        
#doc = nlp(u'Apple is looking at buying U.K. startup for $1 billion')
#for token in doc:
#    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
#          token.shape_, token.is_alpha, token.is_stop)
# Out:
# CPU times: user 2min 36s, sys: 184 ms, total: 2min 37s
# Wall time: 2min 35s

# %%
unk_vocab = {}
for w in unknown_tokens:
    unk_vocab[w] = vocab[w]
unk_vocab = Counter(unk_vocab)

# %%
print('Total number of tokens: ', sum(vocab.values()))
print('Number of unique tokens: ', len(vocab))
print('Total number of unknown tokens: ', sum(unk_vocab.values()))
print('Number of unique unknown tokens: ', len(unknown_tokens))
print('Percent of unknown tokens: ', 100 * sum(unk_vocab.values())/sum(vocab.values()))
# Out:
# Total number of tokens:  19837964
# Number of unique tokens:  259996
# Total number of unknown tokens:  3877055
# Number of unique unknown tokens:  112510
# Percent of unknown tokens:  19.543613447428374

# %%
unk_common = dict(unk_vocab.most_common())

# %%
unk_common
# Out:
# {'?': 1440556,
#  'to': 423732,
#  'a': 421001,
#  'of': 347358,
#  'and': 263940,
#  ',': 240502,
#  '.': 99408,
#  '"': 75829,
#  "'s": 73188,
#  '-': 58940,
#  ')': 58022,
#  '(': 55035,
#  '/': 32971,
#  "'": 20582,
#  '’s': 8778,
#  ':': 7266,
#  'n’t': 6897,
#  '”': 4035,
#  '“': 4029,
#  '’m': 2683,
#  '12th': 2651,
#  '!': 2311,
#  '[': 2039,
#  ']': 2027,
#  '…': 2009,
#  ';': 1493,
#  '}': 1425,
#  'favourite': 1300,
#  '’ve': 1256,
#  '10th': 1105,
#  'and/or': 1098,
#  'bitcoin': 1045,
#  'colour': 1022,
#  '{': 993,
#  'centre': 914,
#  '..': 888,
#  'Quorans': 882,
#  '#/#': 873,
#  '‘': 861,
#  'cryptocurrency': 856,
#  '11th': 855,
#  'Snapchat': 848,
#  'e.g.': 808,
#  'C++': 750,
#  '’re': 734,
#  'travelling': 724,
#  'counselling': 668,
#  'i.e.': 592,
#  'Brexit': 510,
#  'btech': 507,
#  'cryptocurrencies': 506,
#  'blockchain': 491,
#  'behaviour': 485,
#  '#/##': 480,
#  'upvotes': 451,
#  'programme': 421,
#  'Redmi': 394,
#  'realise': 391,
#  'defence': 373,
#  '-#': 369,
#  'KVPY': 361,
#  'Paytm': 350,
#  '21st': 347,
#  '<': 337,
#  'organisation': 321,
#  'grey': 311,
#  'cancelled': 302,
#  "''": 298,
#  '##/##': 298,
#  '20th': 279,
#  '###/###': 268,
#  'bitcoins': 268,
#  'honours': 266,
#  'upvote': 259,
#  'learnt': 256,
#  'Ethereum': 255,
#  'licence': 255,
#  '\xa0': 239,
#  '–': 235,
#  '/math': 231,
#  '^#': 226,
#  'colours': 224,
#  '19th': 222,
#  'mtech': 220,
#  'Whatis': 217,
#  '20s': 217,
#  'theatre': 212,
#  'labour': 205,
#  'x^2': 205,
#  'aluminium': 193,
#  'centres': 187,
#  '--': 186,
#  'favour': 182,
#  'INTJ': 180,
#  'f(x': 179,
#  'organisations': 172,
#  'Pinterest': 171,
#  'INFJ': 166,
#  'cheque': 166,
#  'b.tech': 162,
#  'aadhar': 161,
#  '90s': 160,
#  '##/#': 160,
#  'c++': 158,
#  '80s': 154,
#  'modelling': 151,
#  'Fiverr': 150,
#  'Btech': 150,
#  'judgement': 149,
#  'Xiaomi': 148,
#  '10k': 147,
#  '’ll': 146,
#  '’d': 145,
#  '30s': 143,
#  'Coursera': 143,
#  'coloured': 140,
#  'Fortnite': 138,
#  '1980s': 138,
#  '18th': 133,
#  'i.e': 132,
#  'AFCAT': 130,
#  'OnePlus': 130,
#  'recognise': 128,
#  'Lyft': 127,
#  'UCEED': 126,
#  'jewellery': 126,
#  'B.tech': 125,
#  '1960s': 120,
#  'WeChat': 120,
#  'practise': 120,
#  'bcom': 120,
#  'vape': 119,
#  'INFP': 118,
#  'analyse': 114,
#  'travelled': 113,
#  'recognised': 112,
#  'Blockchain': 111,
#  'UPSEE': 111,
#  'GDPR': 110,
#  'demonetisation': 109,
#  'neighbour': 108,
#  'programmes': 107,
#  '1970s': 107,
#  'Coinbase': 105,
#  'upvoted': 104,
#  'BNBR': 104,
#  'Machedo': 103,
#  'litre': 103,
#  'Manaphy': 102,
#  'sulphuric': 102,
#  'B.E': 99,
#  'neighbours': 98,
#  '—': 98,
#  'tyres': 97,
#  '1990s': 97,
#  'valency': 97,
#  '60s': 97,
#  'Boruto': 96,
#  '#’#': 96,
#  'selfies': 96,
#  '\\frac': 96,
#  'Udacity': 95,
#  'ethereum': 95,
#  '？': 95,
#  '100k': 95,
#  '50k': 95,
#  '##/###': 94,
#  'specialisation': 94,
#  'realised': 94,
#  'DCEU': 93,
#  'tyre': 92,
#  '#=#': 91,
#  'Laravel': 89,
#  '40s': 89,
#  'm/s': 88,
#  'organised': 87,
#  'selfie': 86,
#  'downvote': 86,
#  'traveller': 86,
#  '20k': 85,
#  '16th': 84,
#  '1080p': 84,
#  'SJWs': 84,
#  'E.g.': 84,
#  '70s': 84,
#  '14th': 83,
#  'offence': 83,
#  '13th': 82,
#  'Qoura': 81,
#  '15th': 81,
#  'vapour': 81,
#  'litres': 81,
#  'AR-15': 80,
#  'M.tech': 80,
#  'aeroplane': 79,
#  'fibre': 79,
#  'ICOs': 79,
#  '17th': 78,
#  '2000s': 77,
#  'B.A.': 76,
#  '1950s': 75,
#  'humour': 74,
#  'e.g': 74,
#  'CTMU': 73,
#  'L&T': 73,
#  'civilisation': 73,
#  'utilise': 73,
#  'JIIT': 73,
#  'hairfall': 73,
#  'LNMIIT': 72,
#  '#/': 72,
#  'INTPs': 71,
#  'sulphur': 70,
#  'B.E.': 70,
#  'T20': 69,
#  'Zerodha': 69,
#  'A+': 69,
#  'masterbate': 69,
#  'archaeology': 69,
#  'criticise': 68,
#  '50s': 68,
#  'Upwork': 68,
#  '30k': 68,
#  'Kavalireddi': 67,
#  'neurotypicals': 67,
#  '####/####': 66,
#  'labelled': 66,
#  'organise': 66,
#  'm.tech': 66,
#  '25th': 66,
#  'Xamarin': 66,
#  'adhar': 66,
#  'Uchiha': 66,
#  'B.A': 65,
#  '####/##': 65,
#  'judgemental': 65,
#  '17-year': 65,
#  'ASOIAF': 64,
#  'INTJs': 64,
#  '1800s': 64,
#  '15k': 64,
#  'dreamt': 63,
#  '1930s': 63,
#  'R&D': 63,
#  'I.e.': 62,
#  'Doklam': 62,
#  '401k': 62,
#  'F-1': 61,
#  'Vajiram': 61,
#  '13-year': 61,
#  'fiitjee': 61,
#  "D'Angelo": 60,
#  'ENTP': 60,
#  'neighbouring': 60,
#  'D&D': 60,
#  'Unacademy': 60,
#  'emojis': 60,
#  '\\': 60,
#  '14-year': 59,
#  '40k': 59,
#  'ENFP': 59,
#  'B12': 59,
#  'honour': 59,
#  '...': 58,
#  '15-year': 58,
#  'globalisation': 58,
#  'INFJs': 58,
#  'cancelling': 58,
#  'H2SO4': 58,
#  'practising': 57,
#  '|': 57,
#  'metre': 57,
#  'numericals': 57,
#  'w/': 56,
#  'AlShamsi': 56,
#  'B1/B2': 56,
#  'behavioural': 56,
#  'Kotlin': 56,
#  'H1-B': 56,
#  'WooCommerce': 56,
#  'MOOC': 55,
#  'MUOET': 55,
#  'chsl': 55,
#  'U.S.A': 55,
#  'AT&T': 55,
#  'masterbation': 55,
#  'x^3': 55,
#  'MOOCs': 55,
#  'AngularJS': 53,
#  'worshipped': 52,
#  'sinx': 52,
#  'F-35': 52,
#  'Bhakts': 52,
#  'HackerRank': 52,
#  'Litecoin': 51,
#  'Snapdeal': 51,
#  'theatres': 50,
#  'worshipping': 50,
#  'Duolingo': 50,
#  'VNIT': 50,
#  '16-year': 50,
#  'B.SC': 50,
#  'memorise': 50,
#  'U.K': 49,
#  '12v': 49,
#  "A2A'd": 49,
#  'PUBG': 49,
#  'Hyperloop': 49,
#  'flavour': 49,
#  'altcoin': 49,
#  'behaviours': 48,
#  'apologise': 48,
#  'y^2': 48,
#  'J&K': 47,
#  'convolutional': 47,
#  'eLitmus': 47,
#  'altcoins': 47,
#  'speciality': 47,
#  'Cryptocurrency': 47,
#  '1920s': 46,
#  'metres': 46,
#  '25k': 46,
#  'PCMB': 46,
#  'Ryzen': 46,
#  'macOS': 46,
#  'SRMJEE': 46,
#  '-#/#': 45,
#  'councelling': 45,
#  '\\sqrt': 44,
#  'Baahubali': 44,
#  'F-22': 44,
#  'Zomato': 44,
#  'travellers': 44,
#  '12-year': 44,
#  'Amazon.in': 43,
#  'whisky': 43,
#  'neighbourhood': 43,
#  '/#': 43,
#  'M.A.': 43,
#  'Obito': 42,
#  '#-': 42,
#  'analysing': 42,
#  'parlour': 42,
#  'SGSITS': 42,
#  'j7': 42,
#  'rahu': 42,
#  'iMessage': 42,
#  'Beerus': 42,
#  'MNIT': 42,
#  'M.S.': 41,
#  'S&P': 41,
#  'h1b': 41,
#  'coinbase': 41,
#  'Whar': 41,
#  'B+': 41,
#  '#×#': 41,
#  'What\u200b': 41,
#  'a+b': 40,
#  'Howdo': 40,
#  '30th': 40,
#  'molarity': 40,
#  '31st': 40,
#  'H-1B': 40,
#  'jipmer': 40,
#  '.#': 39,
#  'Q&A': 39,
#  '23rd': 39,
#  '1900s': 39,
#  'rumours': 39,
#  'M.A': 39,
#  'BMSCE': 38,
#  'cisgender': 38,
#  'Gurugram': 38,
#  'bahubali': 38,
#  'Whatare': 38,
#  'MeToo': 38,
#  'aeroplanes': 38,
#  'Binance': 38,
#  'A.I.': 38,
#  '#=': 38,
#  'armour': 37,
#  'cosx': 37,
#  'Rhaegar': 37,
#  '###/##': 37,
#  '60k': 37,
#  'M.S': 37,
#  'SRMJEEE': 37,
#  'Zebpay': 37,
#  '22nd': 37,
#  'PDPU': 37,
#  'ageing': 37,
#  'Truecaller': 37,
#  'Swachh': 36,
#  'masterbating': 36,
#  'upvoting': 36,
#  '1940s': 36,
#  'odour': 36,
#  'josaa': 36,
#  'lpa': 36,
#  'AK-47': 36,
#  '##%+': 36,
#  '29th': 35,
#  '₹####': 35,
#  'downvotes': 35,
#  'Golang': 35,
#  'R15': 35,
#  '\\math': 35,
#  '^#/#': 35,
#  'empaths': 35,
#  'OBOR': 34,
#  'colonisation': 34,
#  'litecoin': 34,
#  'organisational': 34,
#  'M&A': 34,
#  '#=##': 34,
#  'km/h': 34,
#  'ww1': 34,
#  'formulae': 34,
#  'friendzoned': 34,
#  'clickbait': 33,
#  'Roblox': 33,
#  'upwork': 33,
#  'I.e': 33,
#  'arihant': 33,
#  '2010s': 33,
#  'iisc': 33,
#  'friendzone': 33,
#  'B.S.': 33,
#  'Euron': 33,
#  'practised': 33,
#  'mastrubation': 33,
#  'MHCET': 33,
#  '\\infty': 33,
#  'counsellor': 33,
#  'TensorFlow': 32,
#  'gaslighting': 32,
#  'IITK': 32,
#  'node.js': 32,
#  '^n': 32,
#  'Google+': 32,
#  'colonise': 32,
#  'e^x': 32,
#  'A-10': 32,
#  'Sharingan': 32,
#  'acknowledgement': 32,
#  'playstore': 32,
#  'mould': 31,
#  'Quora.com': 31,
#  '12V': 31,
#  'moustache': 31,
#  '.what': 31,
#  '2-year': 31,
#  'MS-13': 31,
#  '24th': 31,
#  'maximise': 31,
#  'fibres': 31,
#  'CDSE': 31,
#  ':(': 31,
#  'Chromecast': 31,
#  '10-year': 31,
#  '√#': 31,
#  'Greyjoy': 31,
#  'y=': 30,
#  'cheques': 30,
#  'Adhaar': 30,
#  '500k': 30,
#  'addmission': 30,
#  'smartwatch': 30,
#  'judgements': 30,
#  'Kasol': 30,
#  '4-year': 30,
#  'PESSAT': 30,
#  '900k': 30,
#  'O+': 30,
#  'g(x': 30,
#  'nationalised': 30,
#  'NodeJS': 30,
#  'GoFundMe': 30,
#  'u.s': 30,
#  '₹#####': 30,
#  'adhaar': 29,
#  'demonitisation': 29,
#  '~##': 29,
#  'axe': 29,
#  'psycopath': 29,
#  'civilised': 29,
#  '50th': 29,
#  '51st': 29,
#  'downvoted': 29,
#  "y'": 29,
#  'realising': 29,
#  'x^4': 29,
#  'socialise': 29,
#  'minimise': 29,
#  'cryptos': 29,
#  'Koinex': 29,
#  'x-1': 29,
#  'metoo': 29,
#  'INFPs': 29,
#  'LBSNAA': 29,
#  '\\int': 29,
#  'Galgotia': 29,
#  'dependant': 28,
#  'LGBT+': 28,
#  'JOSAA': 28,
#  '5-year': 28,
#  'x-2': 28,
#  'MIUI': 28,
#  'LGBTQ+': 28,
#  'favours': 28,
#  '1700s': 28,
#  'Patreon': 28,
#  'legalised': 28,
#  'unacademy': 28,
#  '10x': 28,
#  '.I': 28,
#  'w/o': 28,
#  'US$': 28,
#  'hyperloop': 28,
#  '#"#': 28,
#  'haemoglobin': 27,
#  'mahadasha': 27,
#  'A380': 27,
#  'intership': 27,
#  'microservices': 27,
#  'K-12': 27,
#  'Whst': 27,
#  'non-': 27,
#  'PSIR': 27,
#  'A&M': 27,
#  'Hiw': 27,
#  '#)': 27,
#  'colonised': 27,
#  'Quara': 27,
#  'M.SC': 27,
#  'favourable': 27,
#  'fortnite': 27,
#  'USICT': 27,
#  'ReactJS': 27,
#  'realisation': 27,
#  'authorised': 27,
#  'isomerism': 27,
#  '19-year': 27,
#  'factorise': 27,
#  'analyses': 26,
#  '35k': 26,
#  '2x^2': 26,
#  'H+': 26,
#  'x+1': 26,
#  'lpu': 26,
#  '18-year': 26,
#  'Zamasu': 26,
#  'x=0': 26,
#  'nootropics': 26,
#  '\\sum': 26,
#  '200k': 26,
#  'mc^2': 25,
#  'B.Des': 25,
#  'Codeforces': 25,
#  '64-bit': 25,
#  'Gamora': 25,
#  'brexit': 25,
#  'Fiitjee': 25,
#  'A-': 25,
#  'ACIO': 25,
#  'pisces': 25,
#  'Trumpcare': 25,
#  '28th': 25,
#  'benzoic': 25,
#  'Aliexpress': 25,
#  'PhD.': 25,
#  'Bittrex': 25,
#  'Irodov': 25,
#  '32-bit': 25,
#  'FTRE': 25,
#  'tensorflow': 25,
#  '\\left': 25,
#  'specialised': 25,
#  'dysfuntional': 24,
#  'b.ed': 24,
#  'M.E': 24,
#  'colourful': 24,
#  'Tensorflow': 24,
#  'spoilt': 24,
#  '3x^2': 24,
#  'organising': 24,
#  'a.k.a': 24,
#  'ENFPs': 24,
#  'i20': 24,
#  'Demonetization': 24,
#  'CodeChef': 24,
#  '3-D': 24,
#  'PewDiePie': 24,
#  'customised': 24,
#  'Simpliv': 24,
#  'coc': 24,
#  'Howcan': 24,
#  'Howto': 24,
#  'DAVV': 24,
#  'iitjee': 24,
#  'watsapp': 24,
#  '₹': 24,
#  'e^': 24,
#  '300k': 24,
#  'freelancer.com': 24,
#  'Monero': 24,
#  'JoSAA': 24,
#  '#√#': 24,
#  'criticised': 24,
#  '\\to': 24,
#  'OneDrive': 24,
#  '27th': 24,
#  '\\right': 24,
#  'F-16': 24,
#  '.How': 24,
#  'AR15': 23,
#  'NLUs': 23,
#  'femdom': 23,
#  'Vegito': 23,
#  '℅': 23,
#  'Tarly': 23,
#  'E.g': 23,
#  'MHTCET': 23,
#  'ethanoic': 23,
#  'IIITH': 23,
#  'Howmuch': 23,
#  'y.o': 23,
#  'IGDTUW': 23,
#  'Monjee': 23,
#  'Fyers': 23,
#  'clg': 23,
#  'G20': 23,
#  'Baelish': 23,
#  '26th': 23,
#  'MGTOW': 23,
#  'rumour': 23,
#  '1/x': 23,
#  'crossdress': 22,
#  'kilometres': 22,
#  'harbour': 22,
#  'tumour': 22,
#  '720p': 22,
#  'anaesthesia': 22,
#  'Grammarly': 22,
#  'Hashirama': 22,
#  'intercaste': 22,
#  'GSoC': 22,
#  'otp': 22,
#  'ENTJ': 22,
#  'bisector': 22,
#  'moulding': 22,
#  '220V': 22,
#  'Varys': 22,
#  'muhammed': 22,
#  'musical.ly': 22,
#  's^2': 22,
#  'DeepMind': 22,
#  'carbocation': 22,
#  'enquiry': 22,
#  'Howmany': 22,
#  'Undertale': 22,
#  'puc': 22,
#  'Jungkook': 22,
#  'flavoured': 22,
#  'apist': 21,
#  'Magoosh': 21,
#  'Trumpers': 21,
#  'Arrowverse': 21,
#  'a^2': 21,
#  'Bet365': 21,
#  'Xiomi': 21,
#  'Whydo': 21,
#  'chapterwise': 21,
#  'JCPOA': 21,
#  'undergraduation': 21,
#  'sin(x': 21,
#  'BTECH': 21,
#  'Klux': 21,
#  'rohingya': 21,
#  'incels': 21,
#  'CAPF': 21,
#  'KIITEE': 21,
#  'ENFJ': 21,
#  'Despacito': 21,
#  '401(k': 21,
#  'genderfluid': 21,
#  'legalise': 21,
#  'schizoids': 21,
#  'IIITD': 21,
#  'wierdest': 21,
#  'gsoc': 21,
#  'b.arch': 21,
#  'Mahadasha': 21,
#  'Geass': 21,
#  'licences': 21,
#  '\\times': 21,
#  'hotstar': 21,
#  'F35': 21,
#  'Kubernetes': 20,
#  'WannaCry': 20,
#  'JioFi': 20,
#  '₹##,###': 20,
#  'VSSUT': 20,
#  'AKTU': 20,
#  'GRRM': 20,
#  'AIATS': 20,
#  'saviour': 20,
#  'dx[/math': 20,
#  'precum': 20,
#  '₹##': 20,
#  '23andMe': 20,
#  'mastrubate': 20,
#  'mensuration': 20,
#  'zebpay': 20,
#  '\\cdot': 20,
#  'flavours': 20,
#  'h2so4': 20,
#  '14k': 20,
#  'book(s': 20,
#  'BookMyShow': 20,
#  'kyc': 20,
#  'Rinnegan': 20,
#  'doughnuts': 20,
#  'twinflame': 20,
#  'WeWork': 20,
#  'HBTU': 20,
#  'Theranos': 20,
#  'edX': 20,
#  'Zenfone': 20,
#  'Veerwal': 20,
#  'uttrakhand': 20,
#  'JLPT': 20,
#  'MMMUT': 20,
#  'SICSR': 20,
#  'nanodegree': 19,
#  'tanx': 19,
#  'fullform': 19,
#  'electronegativity': 19,
#  'socialising': 19,
#  'Hotstar': 19,
#  'A6000': 19,
#  'quadcopter': 19,
#  'kundli': 19,
#  '70k': 19,
#  'PMAY': 19,
#  '80k': 19,
#  'Kgp': 19,
#  '\\in': 19,
#  "#'#.#": 19,
#  'NIMCET': 19,
#  'oxalic': 19,
#  'catalogue': 19,
#  '20-year': 19,
#  'sharingan': 19,
#  '#,-#': 19,
#  'Tommen': 19,
#  'subliminals': 19,
#  'roblox': 19,
#  'EXTC': 19,
#  'math]x[/math': 19,
#  'Na+': 19,
#  'favoured': 19,
#  'quora': 19,
#  'J.K.': 19,
#  'curriculars': 19,
#  'criticising': 19,
#  'Petyr': 19,
#  'Dominar': 19,
#  'hyperbola': 19,
#  'madheshi': 19,
#  'language(s': 19,
#  'polarisation': 19,
#  'Cryptocurrencies': 19,
#  '55k': 19,
#  'Sarahah': 19,
#  'Padmaavat': 18,
#  'aliexpress': 18,
#  'kotak': 18,
#  'afmc': 18,
#  'U.P.': 18,
#  'ethyne': 18,
#  'inhand': 18,
#  'blockchains': 18,
#  'biharis': 18,
#  'M&M': 18,
#  'ISTP': 18,
#  'KEAM': 18,
#  '#(#': 18,
#  'IITG': 18,
#  'x+y': 18,
#  '"-': 18,
#  '1-year': 18,
#  'equipotential': 18,
#  'React.js': 18,
#  'How\u200b': 18,
#  'aspies': 18,
#  'BHIM': 18,
#  'D3300': 18,
#  'majora': 18,
#  '\\displaystyle': 18,
#  'cuttoff': 18,
#  'ansys': 18,
#  '18k': 18,
#  'Bhagwad': 18,
#  '45k': 18,
#  'Kaneki': 18,
#  '^##': 18,
#  'AirPods': 18,
#  'paedophile': 18,
#  'Nanodegree': 18,
#  '-x': 18,
#  'Valinor': 18,
#  'a+b+c': 18,
#  'ISTJ': 18,
#  'AB+': 18,
#  'centralised': 18,
#  '12k': 18,
#  '\\lim': 18,
#  'pcod': 18,
#  'visualise': 18,
#  'HackerEarth': 18,
#  'iims': 18,
#  'M.Des': 17,
#  'shinchan': 17,
#  'TISSNET': 17,
#  'theBest': 17,
#  '6-year': 17,
#  'Swiggy': 17,
#  'don´t': 17,
#  'cuck': 17,
#  'fanfictions': 17,
#  'Jupyter': 17,
#  'CSGO': 17,
#  '\\leq': 17,
#  'M16': 17,
#  '4x4': 17,
#  'RLWL': 17,
#  'P.S': 17,
#  'Instacart': 17,
#  'Odoo': 17,
#  'mht': 17,
#  '150k': 17,
#  'n+1': 17,
#  'dicot': 17,
#  'mhtcet': 17,
#  'x-3': 17,
#  '\\pi': 17,
#  'Articleship': 17,
#  'labelling': 17,
#  'Galgotias': 17,
#  '−': 17,
#  'factorize': 17,
#  'करना': 17,
#  't.v': 17,
#  '\\dfrac': 17,
#  'optimise': 17,
#  'I-20': 17,
#  'Mbappe': 17,
#  'Savitar': 17,
#  'hominem': 17,
#  'Zhihu': 17,
#  'centred': 17,
#  'ftre': 17,
#  'koinex': 17,
#  'devops': 17,
#  'mansplaining': 17,
#  'IPMAT': 17,
#  'icai': 17,
#  'molality': 17,
#  '220v': 17,
#  'PayTM': 16,
#  'I`m': 16,
#  '100s': 16,
#  'adaptor': 16,
#  '65k': 16,
#  '16k': 16,
#  'Elasticsearch': 16,
#  'neighbourhoods': 16,
#  'R&B': 16,
#  'Qidian': 16,
#  'Ahok': 16,
#  'Steemit': 16,
#  '\ufeff': 16,
#  'bhk': 16,
#  '1/n': 16,
#  'dasha': 16,
#  'Invento': 16,
#  'SSCBS': 16,
#  'monocot': 16,
#  'polarised': 16,
#  "don'TS": 16,
#  'e-': 16,
#  'better-': 16,
#  'cibil': 16,
#  'pKa': 16,
#  'MPPSC': 16,
#  '₹#': 16,
#  'LNCT': 16,
#  'uan': 16,
#  '1Z0': 16,
#  'subreddit': 16,
#  'Awdesh': 16,
#  'qouta': 16,
#  'UPESEAT': 16,
#  'x^': 16,
#  'C.S.': 16,
#  '11-year': 16,
#  'MoviePass': 16,
#  'paedophilia': 16,
#  '1600s': 16,
#  'Targaryens': 16,
#  'basicity': 16,
#  'cources': 16,
#  '100th': 16,
#  'XXXTentacion': 16,
#  '##-': 16,
#  'colourless': 16,
#  'Drogon': 16,
#  'A=': 16,
#  'edx': 16,
#  'Renly': 16,
#  'oyo': 16,
#  'Whyis': 16,
#  'cos(x': 16,
#  'generalised': 16,
#  '^-#': 16,
#  'USACO': 16,
#  'zerodha': 16,
#  'neutralise': 16,
#  'electronegative': 16,
#  'agartala': 16,
#  '22-year': 16,
#  'class11': 16,
#  'recognising': 16,
#  'Neuralink': 16,
#  'Indiegogo': 16,
#  'fulfil': 16,
#  'IFoS': 16,
#  'AIEEA': 16,
#  'electroscope': 16,
#  'powerbank': 15,
#  'B-': 15,
#  'boric': 15,
#  '500ml': 15,
#  'coulomb': 15,
#  'I.T.': 15,
#  'I´m': 15,
#  'J.R.R.': 15,
#  '75th': 15,
#  'theoritical': 15,
#  'Melkor': 15,
#  'Melisandre': 15,
#  'B.TECH': 15,
#  'antifa': 15,
#  '45th': 15,
#  'vibranium': 15,
#  'MSQE': 15,
#  'Devops': 15,
#  'nonbinary': 15,
#  'x^x': 15,
#  'analysed': 15,
#  'worshippers': 15,
#  'AILET': 15,
#  'T.V.': 15,
#  'specialise': 15,
#  '90k': 15,
#  '2k17': 15,
#  '####-': 15,
#  'OpenAI': 15,
#  'memorising': 15,
#  'ambivert': 15,
#  'Nagant': 15,
#  'Dhinchak': 15,
#  'smartwatches': 15,
#  'downvoting': 15,
#  'foetus': 15,
#  '=#': 15,
#  'Drumpf': 15,
#  'Codecademy': 15,
#  'A.D.': 15,
#  '#^': 15,
#  'Padmavat': 15,
#  '.What': 15,
#  'offences': 15,
#  'inlove': 15,
#  'Bitfinex': 15,
#  'VITMEE': 15,
#  'D5200': 15,
#  'decentralised': 15,
#  '.how': 15,
#  'PG-13': 15,
#  '\n': 15,
#  'doughnut': 14,
#  'i10': 14,
#  'Nirbhaya': 14,
#  '|x|': 14,
#  '24-hour': 14,
#  'Ketogenic': 14,
#  'Etherium': 14,
#  'b^2': 14,
#  ...}
